# %%
pwd
# Out:
# '/home/limseoyoung/debug'

# %%
import nibabel as nib
import numpy as np
import pandas as pd
import os
import glob
# Out:
# /tmp/ipykernel_1508754/1034284564.py:3: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
base_dir = '/mnt/drwelly1/Team_Planning/Brain_Volumetry/OASIS_after_swift'


def calculate_volume(nii_path):
    img = nib.load(nii_path) 
    data = img.get_fdata()
    header = img.header
    voxel_volume = np.prod(header.get_zooms())
    unique_elements, counts_elements = np.unique(data, return_counts=True)
    volumes = counts_elements * voxel_volume
    return dict(zip(unique_elements.astype(int), volumes))

# %%
import os
import pandas as pd



volume_data = []

for subject_dir in os.listdir(base_dir):
    full_subject_dir = os.path.join(base_dir, subject_dir)
    if not os.path.isdir(full_subject_dir) or 'FS222' not in subject_dir:
        continue
    
    double_subject_dir = os.path.join(full_subject_dir, subject_dir)
    if not os.path.isdir(double_subject_dir):
        continue
    
    mri_dir = os.path.join(double_subject_dir, 'mri')
    nii_path = os.path.join(mri_dir, 'aparc.DKTatlas+aseg.deep.nii.gz')
    
    if os.path.isfile(nii_path):
        try:
            vol_data = calculate_volume(nii_path)
            vol_data["subject"] = subject_dir
            volume_data.append(vol_data)
        except OSError as e:
            print(f"Error processing file {nii_path}, skipped  Error: {e}")
    else:
        print(f"File not found, skipped: {nii_path}")

volume_df = pd.DataFrame(volume_data)
# Out:
# Error processing file /mnt/drwelly1/Team_Planning/Brain_Volumetry/OASIS_after_swift/OAS1_0011_MR1_mpr-3_Tag_pr100_sr100_ppf100_spf100_ipf100_sipf179_FS222/OAS1_0011_MR1_mpr-3_Tag_pr100_sr100_ppf100_spf100_ipf100_sipf179_FS222/mri/aparc.DKTatlas+aseg.deep.nii.gz, skipped  Error: Expected 98055792 bytes, got 36546196 bytes from object
#  - could the file be damaged?

# %%
volume_df
# Out:
#                  0              2             4            5             7  \
# 0     1.578976e+07  191258.855075  17914.889726   776.208988   9140.263860
# 1     1.584043e+07  189664.934100  10014.227847   196.881997  10350.024842
# 2     1.600890e+07  156118.162613   9271.289858   550.171992  10636.429837
# 3     1.579672e+07  190517.289087   4600.315930   766.947988  10591.496838
# 4     1.594059e+07  151518.532683  19961.227695  1216.963981   8738.953866
# ...            ...            ...           ...          ...           ...
# 1682  1.592986e+07  184802.223174   8750.958866   384.502994   8987.285863
# 1683  1.584559e+07  186891.436142   4856.193926   372.154994  11506.277824
# 1684  1.596856e+07  150627.418697  16279.465751  1808.981972   8141.447875
# 1685  1.550495e+07  235144.675404   3054.757953   418.802994  14716.414775
# 1686  1.585007e+07  167891.294433  18537.434717  1015.622984  11892.495818
#
#                  8           10           11           12           13  ...  \
# 0     45066.083311  6891.212895  4772.844927  4758.095927  1711.912974  ...
# 1     44650.367317  6414.785902  3007.080954  4084.100938  1580.886976  ...
# 2     40140.603386  5775.090912  2373.559964  3807.642942  1460.836978  ...
# 3     50256.016231  7496.950885  3246.494950  5005.398923  1702.994974  ...
# 4     43782.234330  5708.205913  3342.877949  3682.447944  1582.601976  ...
# ...            ...          ...          ...          ...          ...  ...
# 1682  40606.054379  5847.463911  3050.641953  4140.352937  1554.475976  ...
# 1683  46155.794294  6817.124896  3275.649950  4375.307933  1732.149974  ...
# 1684  41056.413372  6032.683908  3337.389949  4351.297933  1479.701977  ...
# 1685  68111.223958  8532.810870  3960.963939  5755.196912  1938.292970  ...
# 1686  46913.824283  6215.502905  3405.989948  4134.178937  2065.202968  ...
#
#               2025         2026          2027          2028          2029  \
# 0      9002.034862  1701.622974   9186.225860  21096.900677   9329.942857
# 1      8058.441877  1746.212973  10423.083841  22748.788652   7571.381884
# 2      5816.593911  1614.500975   6867.888895  17054.302739   6849.366895
# 3      8311.918873  2324.853964  11889.065818  23840.214635  10421.025841
# 4      7423.891886  2467.541962   8082.794876  19964.657695   7858.815880
# ...            ...          ...           ...           ...           ...
# 1682   6798.602896  1661.834975   7768.263881  21084.552678   7778.553881
# 1683   9222.926859  1995.916969  10222.085844  25054.434617   9893.148849
# 1684   8032.030877  1852.199972   8197.699875  19022.779709   8711.170867
# 1685  11712.420821  3469.101947  16131.975753  33660.990485  11799.885820
# 1686   7262.681889  2398.941963   9853.360849  20675.010684   6771.848896
#
#               2030          2031         2034         2035  \
# 0     14940.393772   8517.718870   863.673987  5403.964917
# 1     12360.347811   7594.019884   787.527988  4659.311929
# 2      9746.687851   6361.277903   499.750992  4117.714937
# 3     15022.027770   9133.403860  1025.569984  4632.557929
# 4     12157.977814   7408.456887   666.791990  5292.489919
# ...            ...           ...          ...          ...
# 1682  11575.220823   5998.040908   679.482990  4383.539933
# 1683  12907.089803   8651.831868   711.381989  4717.278928
# 1684  11321.400827   7231.468889   677.081990  4727.911928
# 1685  17719.379729  10394.614841  1198.098982  6863.086895
# 1686  13486.759794   8669.667867   711.038989  6121.863906
#
#                                                 subject
# 0     OAS1_0112_MR1_mpr-3_Tag_pr100_sr100_ppf100_spf...
# 1     OAS1_0200_MR1_mpr-4_Tag_pr100_sr100_ppf100_spf...
# 2     OAS1_0240_MR1_mpr-3_Tag_pr100_sr100_ppf100_spf...
# 3     OAS1_0208_MR1_mpr-2_Tag_pr100_sr100_ppf100_spf...
# 4     OAS1_0217_MR1_mpr-3_Tag_pr100_sr100_ppf100_spf...
# ...                                                 ...
# 1682  OAS1_0066_MR1_mpr-4_Tag_pr100_sr100_ppf100_spf...
# 1683  OAS1_0192_MR1_mpr-3_Tag_pr100_sr100_ppf100_spf...
# 1684  OAS1_0270_MR1_mpr-4_Tag_pr100_sr100_ppf100_spf...
# 1685  OAS1_0359_MR1_mpr-4_Tag_pr100_sr100_ppf100_spf...
# 1686  OAS1_0362_MR1_mpr-1_Tag_pr100_sr100_ppf100_spf...
#
# [1687 rows x 97 columns]

# %%
volume_df['subject'] = volume_df['subject'].str.replace('_Tag_pr100_sr100_ppf100_spf100_ipf100_sipf179_FS222', '')

# %%
# 'mpr-x'에 따라 4개의 데이터프레임으로 분할
volume_df_mpr1 = volume_df[volume_df['subject'].str.contains('MR1_mpr-1')]
volume_df_mpr2 = volume_df[volume_df['subject'].str.contains('MR1_mpr-2')]
volume_df_mpr3 = volume_df[volume_df['subject'].str.contains('MR1_mpr-3')]
volume_df_mpr4 = volume_df[volume_df['subject'].str.contains('MR1_mpr-4')]

# %%
lut_path = '/mnt/drwelly1/Team_Planning/Brain_Volumetry/Algorithms/freesurfer/FreeSurferColorLUT.txt'

# %%
def load_freesurfer_lut(lut_path):
    lut = {}
    with open(lut_path, 'r') as file:
        for line in file:
            if line.strip() and not line.startswith('#'):
                parts = line.split()
                if parts[0].isdigit():
                    lut[int(parts[0])] = ' '.join(parts[1:])
    return lut

freesurfer_lut = load_freesurfer_lut(lut_path)

# %%
# 모든 컬럼 이름을 변경
new_columns = [freesurfer_lut.get(int(col), 'Unknown') if col != 'subject' else 'subject' for col in volume_df_mpr1 .columns]


volume_df_mpr1 .columns = new_columns

# %%
def extract_number(subj):
    parts = subj.split('_')  # '_'를 기준으로 문자열 분리
    if len(parts) > 1:
        number_part = parts[1]  # "OAS1_" 다음 오는 부분을 선택
        # 숫자만 추출
        numbers = ''.join(filter(str.isdigit, number_part))
        return int(numbers) if numbers.isdigit() else None
    return None

# %%
volume_df_mpr1 ['sort_key'] = volume_df_mpr1['subject'].apply(extract_number)  # 정렬 키 생성
volume_df_sorted1 = volume_df_mpr1 .sort_values(by='sort_key').drop(columns=['sort_key'])  # 정렬 및 정렬 키 컬럼 삭제
# Out:
# /tmp/ipykernel_1508754/3245932642.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   volume_df_mpr1 ['sort_key'] = volume_df_mpr1['subject'].apply(extract_number)  # 정렬 키 생성

# %%
# 모든 컬럼 이름을 변경
new_columns = [freesurfer_lut.get(int(col), 'Unknown') if col != 'subject' else 'subject' for col in volume_df_mpr2 .columns]


volume_df_mpr2.columns = new_columns

# %%
volume_df_mpr2 ['sort_key'] = volume_df_mpr2['subject'].apply(extract_number)  # 정렬 키 생성
volume_df_sorted2 = volume_df_mpr2.sort_values(by='sort_key').drop(columns=['sort_key'])  # 정렬 및 정렬 키 컬럼 삭제
# Out:
# /tmp/ipykernel_1508754/4065747069.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   volume_df_mpr2 ['sort_key'] = volume_df_mpr2['subject'].apply(extract_number)  # 정렬 키 생성

# %%
# 모든 컬럼 이름을 변경
new_columns = [freesurfer_lut.get(int(col), 'Unknown') if col != 'subject' else 'subject' for col in volume_df_mpr3.columns]


volume_df_mpr3.columns = new_columns

# %%
volume_df_mpr3['sort_key'] = volume_df_mpr3['subject'].apply(extract_number)  # 정렬 키 생성
volume_df_sorted3 = volume_df_mpr3.sort_values(by='sort_key').drop(columns=['sort_key'])  # 정렬 및 정렬 키 컬럼 삭제
# Out:
# /tmp/ipykernel_1508754/593579216.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   volume_df_mpr3['sort_key'] = volume_df_mpr3['subject'].apply(extract_number)  # 정렬 키 생성

# %%
volume_df_mpr4['sort_key'] = volume_df_mpr4['subject'].apply(extract_number)  # 정렬 키 생성
volume_df_sorted4 = volume_df_mpr4.sort_values(by='sort_key').drop(columns=['sort_key'])  # 정렬 및 정렬 키 컬럼 삭제
# Out:
# /tmp/ipykernel_1508754/3330656496.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   volume_df_mpr4['sort_key'] = volume_df_mpr4['subject'].apply(extract_number)  # 정렬 키 생성

# %%
all_data = pd.concat([volume_df_sorted1 ,volume_df_sorted2 ,volume_df_sorted3 ,volume_df_sorted4 ])
all_data_long = pd.melt(all_data, id_vars=["subject"], var_name="ROI", value_name="Volume")

# %%
all_data_long['Session'] = all_data_long['subject'].str.extract(r'(mpr-\d)')

all_data_long['ROI'] = all_data_long['ROI'].str.extract(r'([a-zA-Z-_]+)')[0]

# %%
all_data_long['Subject_ID'] = all_data_long['subject'].str.extract(r'(OAS1_\d+)')
all_data_long['Session'] = all_data_long['subject'].str.extract(r'(mpr-\d)')

# %%
roi_variance_within_subject = all_data_long.groupby(['Subject_ID', 'ROI'])['Volume'].var()


mean_variance_per_subject = roi_variance_within_subject.groupby('Subject_ID').mean()

# %%
pivot_table = roi_variance_within_subject.unstack(level='ROI')

# %%
cov_values = pivot_table.std() / pivot_table.mean()


cov_df = pd.DataFrame(cov_values, columns=['Coefficient_of_Variation']).reset_index()


cov_df.rename(columns={'index': 'ROI'}, inplace=True)

# %%
pivot_table
# Out:
# ROI            Brain-Stem         CSF  Left-Accumbens-area  Left-Amygdala  \
# Subject_ID
# OAS1_0001      336.280048  195.924795           224.278203    1286.648641
# OAS1_0002     6930.506296    2.470629             8.588377     520.753674
# OAS1_0003       77.805203  105.217419            66.628548     149.453442
# OAS1_0004    44631.362491   14.862990            31.098551     997.192894
# OAS1_0005    17276.676689  243.572639           376.045409     169.924367
# ...                   ...         ...                  ...            ...
# OAS1_0453   107874.835430   16.745374             9.686434     467.105732
# OAS1_0454   173696.625341  279.651664            29.686763    1120.606691
# OAS1_0455    10076.754191  188.591341           341.064441      74.236517
# OAS1_0456     2030.974625   11.764900           128.747218     274.867272
# OAS1_0457    29980.532969  136.355187            14.157096    7003.683972
#
# ROI         Left-Caudate  Left-Cerebellum-Cortex  \
# Subject_ID
# OAS1_0001      54.746000            3.443049e+04
# OAS1_0002      26.471024            5.875783e+02
# OAS1_0003      20.745440            1.636380e+03
# OAS1_0004     859.818082            1.000013e+05
# OAS1_0005     325.809287            6.247072e+04
# ...                  ...                     ...
# OAS1_0453     694.403593            9.171445e+03
# OAS1_0454    1333.472942            1.275993e+06
# OAS1_0455     619.578831            8.513356e+03
# OAS1_0456    1107.586868            6.870231e+03
# OAS1_0457    2037.719834            4.767408e+04
#
# ROI         Left-Cerebellum-White-Matter  Left-Cerebral-White-Matter  \
# Subject_ID
# OAS1_0001                   3.804674e+04                1.467616e+04
# OAS1_0002                   2.320795e+04                3.563400e+04
# OAS1_0003                   1.750186e+03                4.070612e+04
# OAS1_0004                   2.907852e+03                6.178612e+03
# OAS1_0005                   4.801283e+04                9.721176e+04
# ...                                  ...                         ...
# OAS1_0453                   2.090697e+04                1.116616e+05
# OAS1_0454                   1.122357e+06                1.642636e+06
# OAS1_0455                   6.014334e+03                5.164643e+05
# OAS1_0456                   6.827563e+01                4.668587e+03
# OAS1_0457                   2.080552e+04                9.273687e+05
#
# ROI         Left-Hippocampus  Left-Inf-Lat-Vent  ...  ctx-rh-precuneus  \
# Subject_ID                                       ...
# OAS1_0001        2813.497316         304.750117  ...       6927.996451
# OAS1_0002          74.471815         190.865888  ...        988.251570
# OAS1_0003           2.235331          85.922984  ...       2815.575782
# OAS1_0004         244.043235          65.412842  ...       3256.994816
# OAS1_0005          30.157359          44.745835  ...       8942.304135
# ...                      ...                ...  ...               ...
# OAS1_0453        1474.651737         720.521670  ...       3511.273514
# OAS1_0454        5153.182908         184.277545  ...      14588.514770
# OAS1_0455         415.575472         234.827397  ...       6474.969382
# OAS1_0456         157.532006          61.451992  ...      14359.805121
# OAS1_0457        1324.374752         336.123183  ...      20297.314672
#
# ROI         ctx-rh-rostralanteriorcingulate  ctx-rh-rostralmiddlefrontal  \
# Subject_ID
# OAS1_0001                        608.755124                  7635.576732
# OAS1_0002                         15.804182                  6742.267902
# OAS1_0003                          9.294271                   102.393843
# OAS1_0004                        728.286504                  8226.606073
# OAS1_0005                       3712.806245                 29199.069119
# ...                                     ...                          ...
# OAS1_0453                       4663.763083                  1504.377717
# OAS1_0454                        328.358349                   564.872048
# OAS1_0455                          1.215706                   291.926376
# OAS1_0456                       1699.596618                  5457.031049
# OAS1_0457                        555.577777                   998.408600
#
# ROI         ctx-rh-superiorfrontal  ctx-rh-superiorparietal  \
# Subject_ID
# OAS1_0001              3829.239535              1439.592336
# OAS1_0002              3991.281419                44.745835
# OAS1_0003              3646.765941              1148.528719
# OAS1_0004             50298.749946             11294.774251
# OAS1_0005             51524.025027             32207.942202
# ...                            ...                      ...
# OAS1_0453              4350.189291               558.166055
# OAS1_0454              3022.677232              9603.020899
# OAS1_0455             32103.156162              3457.468706
# OAS1_0456               986.643700              5514.561408
# OAS1_0457              3424.644636             65298.996987
#
# ROI         ctx-rh-superiortemporal  ctx-rh-supramarginal  \
# Subject_ID
# OAS1_0001               1069.547026           1276.373962
# OAS1_0002               9430.861201           1986.385655
# OAS1_0003                159.571255           1591.202676
# OAS1_0004               8280.254016            696.638924
# OAS1_0005              69572.008537           8885.479670
# ...                             ...                   ...
# OAS1_0453               2903.694880             58.863715
# OAS1_0454              53131.737779          20732.145362
# OAS1_0455               8552.415361            788.601223
# OAS1_0456               1245.471492           2036.621777
# OAS1_0457              16389.132660            575.225160
#
# ROI         ctx-rh-transversetemporal  rd-Ventricle  th-Ventricle
# Subject_ID
# OAS1_0001                  412.516598     76.746362   3282.093269
# OAS1_0002                  139.178763     32.588772     69.687422
# OAS1_0003                  241.415741     11.764900    306.397203
# OAS1_0004                  232.631282     36.824136    271.416235
# OAS1_0005                  414.281333    102.393843    961.231517
# ...                               ...           ...           ...
# OAS1_0453                  752.953577    161.414423    265.925948
# OAS1_0454                  214.866284     79.334640   2965.578252
# OAS1_0455                  136.943432    294.397005     17.294402
# OAS1_0456                   12.706092    288.122392    445.536749
# OAS1_0457                 2700.083684    303.808925   1699.126022
#
# [416 rows x 96 columns]

# %%
cov_df
# Out:
#                           ROI  Coefficient_of_Variation
# 0                  Brain-Stem                  5.880035
# 1                         CSF                  2.003314
# 2         Left-Accumbens-area                  1.359612
# 3               Left-Amygdala                  1.765457
# 4                Left-Caudate                  2.041615
# ..                        ...                       ...
# 91    ctx-rh-superiortemporal                  1.972153
# 92       ctx-rh-supramarginal                  2.648236
# 93  ctx-rh-transversetemporal                  1.284254
# 94               rd-Ventricle                  4.254888
# 95               th-Ventricle                 10.933132
#
# [96 rows x 2 columns]
