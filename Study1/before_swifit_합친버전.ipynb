# %%
pwd
# Out:
# '/home/limseoyoung/debug'

# %%
combined_roi_dict = {
    'Left-Cingulate': {
        'ctx-lh-caudalanteriorcingulate',
        'ctx-lh-rostralanteriorcingulate',
        'ctx-lh-isthmuscingulate',
        'ctx-lh-posteriorcingulate',
    },
    'Right-Cingulate': {
        'ctx-rh-caudalanteriorcingulate',
        'ctx-rh-rostralanteriorcingulate',
        'ctx-rh-isthmuscingulate',
        'ctx-rh-posteriorcingulate',
    },
    'Left-Frontal': {
        'ctx-lh-caudalmiddlefrontal',
        'ctx-lh-lateralorbitofrontal',
        'ctx-lh-medialorbitofrontal',
        'ctx-lh-parsopercularis',
        'ctx-lh-parsorbitalis',
        'ctx-lh-parstriangularis',
        'ctx-lh-precentral',
        'ctx-lh-rostralmiddlefrontal',
        'ctx-lh-superiorfrontal',
        'ctx-lh-paracentral'
    },
    'Right-Frontal': {
        'ctx-rh-caudalmiddlefrontal',
        'ctx-rh-lateralorbitofrontal',
        'ctx-rh-medialorbitofrontal',
        'ctx-rh-parsopercularis',
        'ctx-rh-parsorbitalis',
        'ctx-rh-parstriangularis',
        'ctx-rh-precentral',
        'ctx-rh-rostralmiddlefrontal',
        'ctx-rh-superiorfrontal',
        'ctx-rh-paracentral'
    },
    'Left-Temporal': {
        'ctx-lh-entorhinal',
        'ctx-lh-fusiform',
        'ctx-lh-inferiortemporal',
        'ctx-lh-middletemporal',
        'ctx-lh-superiortemporal',
        'ctx-lh-transversetemporal',
        'ctx-lh-parahippocampal',
        
    },
    'Right-Temporal': {
        'ctx-rh-entorhinal',
        'ctx-rh-fusiform',
        'ctx-rh-inferiortemporal',
        'ctx-rh-middletemporal',
        'ctx-rh-superiortemporal',
        'ctx-rh-transversetemporal',
        'ctx-rh-parahippocampal',
     
    },
    'Left-Parietal': {
        'ctx-lh-inferiorparietal',
        'ctx-lh-postcentral',
        'ctx-lh-superiorparietal',
        'ctx-lh-supramarginal',
        'ctx-lh-precuneus'
    },
    'Right-Parietal': {
        'ctx-rh-inferiorparietal',
        'ctx-rh-postcentral',
        'ctx-rh-superiorparietal',
        'ctx-rh-supramarginal',
        'ctx-rh-precuneus'
    },
    'Left-Occipital': {
        'ctx-lh-cuneus',
        'ctx-lh-lateraloccipital',
        'ctx-lh-lingual',
        'ctx-lh-pericalcarine'
    },
    'Right-Occipital': {
        'ctx-rh-cuneus',
        'ctx-rh-lateraloccipital',
        'ctx-rh-lingual',
        'ctx-rh-pericalcarine'
    },
    'Left-Insula':{
        'ctx-lh-insula'
    },
    'Right-Insula': {
        'ctx-rh-insula'
    },
    'Left-Cerebellum':{
        'Left-Cerebellum-White-Matter',
        'Left-Cerebellum-Cortex'
    },
    'Right-Cerebellum': {
        'Right-Cerebellum-White-Matter',
        'Right-Cerebellum-Cortex'
    },
    'Left-Combined-Cerebral-WM': {
        'Left-Cerebral-White-Matter',
        'Left-WM-hypointensities'
    },
    'Right-Combined-Cerebral-WM': {
        'Right-Cerebral-White-Matter',
        'Right-WM-hypointensities'
    },
    'Left-Total-Lateral-Ventricle': {
        'Left-Lateral-Ventricle',
        'Left-Inf-Lat-Vent'
    },
    'Right-Total-Lateral-Ventricle': {
        'Right-Lateral-Ventricle',
        'Right-Inf-Lat-Vent'
    },
}

# %%
import nibabel as nib
import numpy as np
import pandas as pd
import os

import glob
# Out:
# /tmp/ipykernel_3423736/1519263294.py:3: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
base_dir = '/mnt/drwelly1/Team_Planning/Brain_Volumetry/OASIS1_before_swift_20240405'


def calculate_volume(nii_path):
    img = nib.load(nii_path) 
    data = img.get_fdata()
    header = img.header
    voxel_volume = np.prod(header.get_zooms())
    unique_elements, counts_elements = np.unique(data, return_counts=True)
    volumes = counts_elements * voxel_volume
    return dict(zip(unique_elements.astype(int), volumes))

# %%
pwd
# Out:
# '/home/limseoyoung/debug'

# %%
volume_df = pd.read_csv("before_swift_Volume_df.csv")

# %%
volume_df
# Out:
#       Unnamed: 0             0              2             4            5  \
# 0              0  1.576330e+07  193835.471036  18851.622712   841.721987
# 1              1  1.581899e+07  191857.733066  10464.586840   203.398997
# 2              2  1.598947e+07  154562.314636   9704.155852   586.529991
# 3              3  1.577627e+07  193660.541039   4914.503925   815.653988
# 4              4  1.592127e+07  149282.515717  20843.080681  1269.785981
# ...          ...           ...            ...           ...          ...
# 1683        1683  1.591101e+07  184878.026173   9188.626859   431.150993
# 1684        1684  1.582470e+07  189612.112100   5133.680921   402.681994
# 1685        1685  1.594665e+07  148899.041723  17100.264739  1894.045971
# 1686        1686  1.550678e+07  234926.184407   3355.568949   471.967993
# 1687        1687  1.582332e+07  166761.452450  19495.090702  1043.062984
#
#                  7             8           10           11           12  ...  \
# 0      9108.021861  46701.850286  7298.353888  4940.914924  5030.780923  ...
# 1     10115.412845  46094.054295  6863.772895  3193.672951  4341.350934  ...
# 2     10413.822841  41314.692368  6195.265905  2548.489961  4079.984938  ...
# 3     10290.342843  51949.750206  7979.208878  3393.298948  5295.233919  ...
# 4      8566.081869  44532.718319  6016.219908  3492.082947  3882.416941  ...
# ...            ...           ...          ...          ...          ...  ...
# 1683   8553.047869  42137.549356  6203.154905  3213.566951  4288.871934  ...
# 1684  11595.114823  47859.475268  7320.991888  3452.637947  4670.973929  ...
# 1685   7942.164879  41890.932359  6393.519902  3437.545947  4493.642931  ...
# 1686  14221.122783  70301.621925  9151.239860  4083.071938  6051.891907  ...
# 1687  12124.706815  48787.290254  6529.347900  3566.170945  4438.076932  ...
#
#               2025         2026          2027          2028          2029  \
# 0      9399.228856  1734.550973   9419.122856  21965.719664   9822.490850
# 1      8353.078872  1782.227973  10734.870836  23377.164643   7917.811879
# 2      6202.468905  1694.076974   7284.976889  18051.060724   7328.194888
# 3      8652.860868  2316.278965  12168.953814  24795.126621  10795.238835
# 4      7975.778878  2615.031960   8377.431872  21415.890673   8525.950870
# ...            ...          ...           ...           ...           ...
# 1683   7159.095891  1670.409974   8257.038874  22278.192659   8247.091874
# 1684   9510.017855  1958.872970  10371.976841  25621.756608  10392.213841
# 1685   8429.910871  1831.276972   8671.039867  20103.572693   9385.851856
# 1686  11965.211817  3133.990952  16136.434753  34343.903475  12218.002813
# 1687   7618.029884  2351.607964  10525.297839  21901.235665   7264.739889
#
#               2030          2031         2034         2035  \
# 0     15317.007766   8839.452865   934.331986  5585.411915
# 1     12562.717808   7780.268881   849.953987  4746.090927
# 2     10149.369845   6581.483899   552.572992  4400.346933
# 3     14645.413776   9278.492858  1067.758984  4676.118928
# 4     12502.006809   7610.140884   735.391989  5513.724916
# ...            ...           ...          ...          ...
# 1683  11714.821821   6243.971905   744.309989  4602.373930
# 1684  12841.233804   8813.041865   791.986988  4831.497926
# 1685  11777.933820   7660.561883   767.976988  4995.108924
# 1686  16699.640745  10364.773842  1176.146982  6361.963903
# 1687  13799.575789   8935.835863   765.575988  6242.599905
#
#                   subject
# 0     OAS1_0112_MR1_mpr-3
# 1     OAS1_0200_MR1_mpr-4
# 2     OAS1_0240_MR1_mpr-3
# 3     OAS1_0208_MR1_mpr-2
# 4     OAS1_0217_MR1_mpr-3
# ...                   ...
# 1683  OAS1_0066_MR1_mpr-4
# 1684  OAS1_0192_MR1_mpr-3
# 1685  OAS1_0270_MR1_mpr-4
# 1686  OAS1_0359_MR1_mpr-4
# 1687  OAS1_0362_MR1_mpr-1
#
# [1688 rows x 98 columns]

# %%
volume_df = volume_df.drop('Unnamed: 0', axis = 1)

# %%
volume_df['subject'] = volume_df['subject'].str.replace('_Tag_pr100_sr100_ppf100_spf100_ipf100_sipf179_FS222', '')

# %%
# 'mpr-x'에 따라 4개의 데이터프레임으로 분할
volume_df_mpr1 = volume_df[volume_df['subject'].str.contains('MR1_mpr-1')]
volume_df_mpr2 = volume_df[volume_df['subject'].str.contains('MR1_mpr-2')]
volume_df_mpr3 = volume_df[volume_df['subject'].str.contains('MR1_mpr-3')]
volume_df_mpr4 = volume_df[volume_df['subject'].str.contains('MR1_mpr-4')]

# %%
# Path to the FreeSurfer Look-Up Table (LUT)
lut_path = '/mnt/drwelly1/Team_Planning/Brain_Volumetry/Algorithms/freesurfer/FreeSurferColorLUT.txt'

# %%
def load_freesurfer_lut(lut_path):
    lut = {}
    with open(lut_path, 'r') as file:
        for line in file:
            if line.strip() and not line.startswith('#'):
                parts = line.split()
                if parts[0].isdigit():
                    lut[int(parts[0])] = ' '.join(parts[1:])
    return lut

freesurfer_lut = load_freesurfer_lut(lut_path)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[11], line 11
#       8                     lut[int(parts[0])] = ' '.join(parts[1:])
#       9     return lut
# ---> 11 freesurfer_lut = load_freesurfer_lut(lut_path)
#
# Cell In[11], line 3, in load_freesurfer_lut(lut_path)
#       1 def load_freesurfer_lut(lut_path):
#       2     lut = {}
# ----> 3     with open(lut_path, 'r') as file:
#       4         for line in file:
#       5             if line.strip() and not line.startswith('#'):
#
# File ~/fsl/lib/python3.11/site-packages/IPython/core/interactiveshell.py:308, in _modified_open(file, *args, **kwargs)
#     301 if file in {0, 1, 2}:
#     302     raise ValueError(
#     303         f"IPython won't let you open fd={file} by default "
#     304         "as it is likely to crash IPython. If you know what you are doing, "
#     305         "you can use builtins' open."
#     306     )
# --> 308 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'DrWelly_Volumetry_Colorcode.xlsx'

# %%
# 모든 컬럼 이름을 변경
new_columns = [freesurfer_lut.get(int(col), 'Unknown') if col != 'subject' else 'subject' for col in volume_df_mpr1 .columns]


volume_df_mpr1 .columns = new_columns

# %%
def extract_number(subj):
    parts = subj.split('_')  
    if len(parts) > 1:
        number_part = parts[1]  
       
        numbers = ''.join(filter(str.isdigit, number_part))
        return int(numbers) if numbers.isdigit() else None
    return None

# %%
volume_df_mpr1 ['sort_key'] = volume_df_mpr1['subject'].apply(extract_number)  # 정렬 키 생성
volume_df_sorted1 = volume_df_mpr1 .sort_values(by='sort_key').drop(columns=['sort_key'])  # 정렬 및 정렬 키 컬럼 삭제
# Out:
# /tmp/ipykernel_2381762/3245932642.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   volume_df_mpr1 ['sort_key'] = volume_df_mpr1['subject'].apply(extract_number)  # 정렬 키 생성

# %%
# 모든 컬럼 이름을 변경
new_columns = [freesurfer_lut.get(int(col), 'Unknown') if col != 'subject' else 'subject' for col in volume_df_mpr2 .columns]


volume_df_mpr2.columns = new_columns

# %%
volume_df_mpr2 ['sort_key'] = volume_df_mpr2['subject'].apply(extract_number)  # 정렬 키 생성
volume_df_sorted2 = volume_df_mpr2.sort_values(by='sort_key').drop(columns=['sort_key'])  # 정렬 및 정렬 키 컬럼 삭제
# Out:
# /tmp/ipykernel_2381762/4065747069.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   volume_df_mpr2 ['sort_key'] = volume_df_mpr2['subject'].apply(extract_number)  # 정렬 키 생성

# %%
new_columns = [freesurfer_lut.get(int(col), 'Unknown') if col != 'subject' else 'subject' for col in volume_df_mpr3.columns]


volume_df_mpr3.columns = new_columns

# %%
volume_df_mpr3['sort_key'] = volume_df_mpr3['subject'].apply(extract_number)  
volume_df_sorted3 = volume_df_mpr3.sort_values(by='sort_key').drop(columns=['sort_key'])
# Out:
# /tmp/ipykernel_2381762/593579216.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   volume_df_mpr3['sort_key'] = volume_df_mpr3['subject'].apply(extract_number)  # 정렬 키 생성

# %%
new_columns = [freesurfer_lut.get(int(col), 'Unknown') if col != 'subject' else 'subject' for col in volume_df_mpr4.columns]


volume_df_mpr4.columns = new_columns

# %%
volume_df_mpr4['sort_key'] = volume_df_mpr4['subject'].apply(extract_number)  
volume_df_sorted4 = volume_df_mpr4.sort_values(by='sort_key').drop(columns=['sort_key'])
# Out:
# /tmp/ipykernel_2381762/3330656496.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   volume_df_mpr4['sort_key'] = volume_df_mpr4['subject'].apply(extract_number)  # 정렬 키 생성

# %%
volume_df_mpr1
# Out:
#       Unknown 0 0 0 0  Left-Cerebral-White-Matter 245 245 245 0  \
# 7        1.558313e+07                             217530.253673
# 8        1.567757e+07                             220057.820635
# 17       1.582827e+07                             178993.861263
# 18       1.554600e+07                             253014.632131
# 23       1.568635e+07                             208315.558814
# ...               ...                                       ...
# 1661     1.566617e+07                             224766.867563
# 1662     1.587461e+07                             183522.833194
# 1676     1.580257e+07                             189422.433103
# 1678     1.586053e+07                             182054.107216
# 1687     1.582332e+07                             166761.452450
#
#       Left-Lateral-Ventricle 120 18 134 0  Left-Inf-Lat-Vent 196 58 250 0  \
# 7                            34133.644478                     1288.307980
# 8                             4223.358935                      325.163995
# 17                            4380.452933                      367.009994
# 18                            4794.796927                      319.332995
# 23                            6483.728901                      318.303995
# ...                                   ...                             ...
# 1661                         11258.974828                      407.826994
# 1662                         19409.340703                      885.625986
# 1676                          8200.786875                      372.497994
# 1678                         13703.535790                      453.102993
# 1687                         19495.090702                     1043.062984
#
#       Left-Cerebellum-White-Matter 220 248 164 0  \
# 7                                    9771.726851
# 8                                   10740.358836
# 17                                  10677.932837
# 18                                  14071.231785
# 23                                  12264.993812
# ...                                          ...
# 1661                                12858.726803
# 1662                                12149.059814
# 1676                                10115.412845
# 1678                                10552.051839
# 1687                                12124.706815
#
#       Left-Cerebellum-Cortex 230 148 34 0  Left-Thalamus 0 118 14 0  \
# 7                            49109.710249               7410.857887
# 8                            48819.532253               8743.755866
# 17                           50102.352234               8006.305878
# 18                           58277.757109               9177.307860
# 23                           55706.972148               8488.220870
# ...                                   ...                       ...
# 1661                         49768.956239               8446.031871
# 1662                         46507.712289               6118.090906
# 1676                         48378.777260               7275.372889
# 1678                         42980.300343               6354.074903
# 1687                         48787.290254               6529.347900
#
#       Left-Caudate 122 186 220 0  Left-Putamen 236 13 176 0  \
# 7                    5281.513919                7574.468884
# 8                    4034.022938                6862.057895
# 17                   3612.818945                5460.559916
# 18                   3143.251952                5153.574921
# 23                   3893.392940                5919.150909
# ...                          ...                        ...
# 1661                 3966.794939                5743.877912
# 1662                 2655.848959                4166.763936
# 1676                 2918.243955                5212.227920
# 1678                 3105.864953                4057.689938
# 1687                 3566.170945                4438.076932
#
#       Left-Pallidum 12 48 255 0  ...  \
# 7                   2501.155962  ...
# 8                   2206.175966  ...
# 17                  1887.185971  ...
# 18                  1876.895971  ...
# 23                  2097.787968  ...
# ...                         ...  ...
# 1661                1959.901970  ...
# 1662                1716.028974  ...
# 1676                1881.354971  ...
# 1678                1648.800975  ...
# 1687                2151.981967  ...
#
#       ctx-rh-rostralanteriorcingulate 80 20 140 0  \
# 7                                     2834.208957
# 8                                     1999.689969
# 17                                    1930.746970
# 18                                    2002.090969
# 23                                    2542.315961
# ...                                           ...
# 1661                                  2019.240969
# 1662                                  1580.543976
# 1676                                  3048.583953
# 1678                                  2152.667967
# 1687                                  2351.607964
#
#       ctx-rh-rostralmiddlefrontal 75 50 125 0  \
# 7                                12806.247804
# 8                                14615.572776
# 17                               11452.426825
# 18                               14675.254776
# 23                               11900.041818
# ...                                       ...
# 1661                             10432.344840
# 1662                              8133.215876
# 1676                              9623.893853
# 1678                              9099.789861
# 1687                             10525.297839
#
#       ctx-rh-superiorfrontal 20 220 160 0  \
# 7                            29312.093552
# 8                            26371.897597
# 17                           24921.693619
# 18                           31910.661512
# 23                           26993.756587
# ...                                   ...
# 1661                         26388.018596
# 1662                         17945.416726
# 1676                         26911.436588
# 1678                         20880.124681
# 1687                         21901.235665
#
#       ctx-rh-superiorparietal 20 180 140 0  \
# 7                             13177.716798
# 8                             12262.935812
# 17                            10527.012839
# 18                            12653.955806
# 23                            13461.034794
# ...                                    ...
# 1661                          10367.517841
# 1662                          10173.036844
# 1676                           8838.080865
# 1678                           7537.081885
# 1687                           7264.739889
#
#       ctx-rh-superiortemporal 140 220 220 0  ctx-rh-supramarginal 80 160 20 0  \
# 7                              16690.379745                       9172.505860
# 8                              13511.455793                       8435.055871
# 17                             12650.525807                       8324.609873
# 18                             15276.533766                      11500.103824
# 23                             14956.857771                      10569.544838
# ...                                     ...                               ...
# 1661                           15961.847756                       9405.059856
# 1662                           10227.916844                       7524.390885
# 1676                           13895.958788                       9206.119859
# 1678                           12209.770813                       7079.176892
# 1687                           13799.575789                       8935.835863
#
#       ctx-rh-transversetemporal 150 150 200 0  ctx-rh-insula 255 192 32 0  \
# 7                                 1028.656984                 7177.274890
# 8                                  908.949986                 5449.240917
# 17                                 736.763989                 4725.510928
# 18                                 983.037985                 5813.849911
# 23                                1112.005983                 5079.486922
# ...                                       ...                         ...
# 1661                               913.065986                 5321.644919
# 1662                               728.874989                 5083.259922
# 1676                               803.305988                 5632.745914
# 1678                               754.942988                 5313.412919
# 1687                               765.575988                 6242.599905
#
#                   subject  sort_key
# 7     OAS1_0365_MR1_mpr-1       365
# 8     OAS1_0403_MR1_mpr-1       403
# 17    OAS1_0081_MR1_mpr-1        81
# 18    OAS1_0385_MR1_mpr-1       385
# 23    OAS1_0410_MR1_mpr-1       410
# ...                   ...       ...
# 1661  OAS1_0313_MR1_mpr-1       313
# 1662  OAS1_0220_MR1_mpr-1       220
# 1676  OAS1_0114_MR1_mpr-1       114
# 1678  OAS1_0203_MR1_mpr-1       203
# 1687  OAS1_0362_MR1_mpr-1       362
#
# [416 rows x 98 columns]

# %%
volume_df_mpr1.shape
# Out:
# (416, 98)

# %%
# 함수 실행하여 데이터프레임 업데이트
#new_df1 = update_df_columns(volume_df_mpr1.copy(), combined_roi_dict)
#new_df2 = update_df_columns(volume_df_mpr2.copy(), combined_roi_dict)
#new_df3 = update_df_columns(volume_df_mpr3.copy(), combined_roi_dict)
#new_df4 = update_df_columns(volume_df_mpr4.copy(), combined_roi_dict)

# %%
def update_df_columns_keep_subject(df, roi_dict):
    
    columns_to_remove = []
    
   
    protected_columns = ['subject']
    

    for roi, sub_columns in roi_dict.items():
      
        relevant_columns = [col for col in df.columns if col.split(' ')[0] in sub_columns and col not in protected_columns]
        
    
        if relevant_columns:
         
            df[roi] = df[relevant_columns].fillna(0).sum(axis=1)
          
            columns_to_remove.extend(relevant_columns)
 
    df = df.drop(columns=[col for col in columns_to_remove if col not in protected_columns], errors='ignore')
    
    return df

# 함수 실행하여 데이터프레임 업데이트, 'subject' 컬럼 유지
new_df1 = update_df_columns_keep_subject(volume_df_mpr1.copy(), combined_roi_dict)
new_df2 = update_df_columns_keep_subject(volume_df_mpr2.copy(), combined_roi_dict)

new_df3 = update_df_columns_keep_subject(volume_df_mpr3.copy(), combined_roi_dict)
new_df4 = update_df_columns_keep_subject(volume_df_mpr4.copy(), combined_roi_dict)

# %%
new_df2.columns
# Out:
# Index(['Unknown 0 0 0 0', 'Left-Thalamus 0 118 14 0',
#        'Left-Caudate 122 186 220 0', 'Left-Putamen 236 13 176 0',
#        'Left-Pallidum 12 48 255 0', '3rd-Ventricle 204 182 142 0',
#        '4th-Ventricle 42 204 164 0', 'Brain-Stem 119 159 176 0',
#        'Left-Hippocampus 220 216 20 0', 'Left-Amygdala 103 255 255 0',
#        'CSF 60 60 60 0', 'Left-Accumbens-area 255 165 0 0',
#        'Left-VentralDC 165 42 42 0', 'Left-choroid-plexus 0 200 200 0',
#        'Right-Thalamus 0 118 14 0', 'Right-Caudate 122 186 220 0',
#        'Right-Putamen 236 13 176 0', 'Right-Pallidum 13 48 255 0',
#        'Right-Hippocampus 220 216 20 0', 'Right-Amygdala 103 255 255 0',
#        'Right-Accumbens-area 255 165 0 0', 'Right-VentralDC 165 42 42 0',
#        'Right-choroid-plexus 0 200 221 0', 'WM-hypointensities 200 70 255 0',
#        'subject', 'sort_key', 'Left-Cingulate', 'Right-Cingulate',
#        'Left-Frontal', 'Right-Frontal', 'Left-Temporal', 'Right-Temporal',
#        'Left-Parietal', 'Right-Parietal', 'Left-Occipital', 'Right-Occipital',
#        'Left-Insula', 'Right-Insula', 'Left-Cerebellum', 'Right-Cerebellum',
#        'Left-Combined-Cerebral-WM', 'Right-Combined-Cerebral-WM',
#        'Left-Total-Lateral-Ventricle', 'Right-Total-Lateral-Ventricle'],
#       dtype='object')

# %%
brain_areas = set()
left_right_columns = []

for col in new_df1.columns:
    if col.startswith('Left-') or col.startswith('Right-'):
        left_right_columns.append(col)
        brain_area = col.split('-', 1)[1]
        brain_areas.add(brain_area)


for area in brain_areas:
    left_col = f'Left-{area}'
    right_col = f'Right-{area}'
    new_df1[area] = new_df1.get(left_col, 0) + new_df1.get(right_col, 0)

volume_df_sorted1_final = new_df1.drop(columns=[col for col in left_right_columns if col not in ['subject']])

# %%
volume_df_sorted1_final= volume_df_sorted1_final.drop(columns = ['sort_key','Unknown 0 0 0 0','choroid-plexus 0 200 200 0','choroid-plexus 0 200 221 0','WM-hypointensities 200 70 255 0'])

# %%
brain_areas = set()
left_right_columns = []

for col in new_df2.columns:
    if col.startswith('Left-') or col.startswith('Right-'):
        left_right_columns.append(col)
        brain_area = col.split('-', 1)[1]
        brain_areas.add(brain_area)


for area in brain_areas:
    left_col = f'Left-{area}'
    right_col = f'Right-{area}'
    new_df2[area] = new_df2.get(left_col, 0) + new_df2.get(right_col, 0)

volume_df_sorted2_final = new_df2.drop(columns=[col for col in left_right_columns if col not in ['subject']])

# %%
volume_df_sorted2_final= volume_df_sorted2_final.drop(columns = ['sort_key','Unknown 0 0 0 0','choroid-plexus 0 200 200 0','choroid-plexus 0 200 221 0','WM-hypointensities 200 70 255 0'])

# %%
brain_areas = set()
left_right_columns = []

for col in new_df3.columns:
    if col.startswith('Left-') or col.startswith('Right-'):
        left_right_columns.append(col)
        brain_area = col.split('-', 1)[1]
        brain_areas.add(brain_area)


for area in brain_areas:
    left_col = f'Left-{area}'
    right_col = f'Right-{area}'
    new_df3[area] = new_df3.get(left_col, 0) + new_df3.get(right_col, 0)

volume_df_sorted3_final = new_df3.drop(columns=[col for col in left_right_columns if col not in ['subject']])

# %%
volume_df_sorted3_final= volume_df_sorted3_final.drop(columns = ['sort_key','Unknown 0 0 0 0','choroid-plexus 0 200 200 0','choroid-plexus 0 200 221 0','WM-hypointensities 200 70 255 0'])

# %%
brain_areas = set()
left_right_columns = []

for col in new_df4.columns:
    if col.startswith('Left-') or col.startswith('Right-'):
        left_right_columns.append(col)
        brain_area = col.split('-', 1)[1]
        brain_areas.add(brain_area)


for area in brain_areas:
    left_col = f'Left-{area}'
    right_col = f'Right-{area}'
    new_df4[area] = new_df4.get(left_col, 0) + new_df4.get(right_col, 0)

volume_df_sorted4_final = new_df4.drop(columns=[col for col in left_right_columns if col not in ['subject']])

# %%
volume_df_sorted4_final= volume_df_sorted4_final.drop(columns = ['sort_key','Unknown 0 0 0 0','choroid-plexus 0 200 200 0','choroid-plexus 0 200 221 0','WM-hypointensities 200 70 255 0'])

# %%
all_data = pd.concat([volume_df_sorted1_final,volume_df_sorted2_final,volume_df_sorted3_final,volume_df_sorted4_final])
all_data_long = pd.melt(all_data, id_vars=["subject"], var_name="ROI", value_name="Volume")

# %%
all_data_long
# Out:
#                    subject                          ROI         Volume
# 0      OAS1_0365_MR1_mpr-1  3rd-Ventricle 204 182 142 0    1848.426972
# 1      OAS1_0403_MR1_mpr-1  3rd-Ventricle 204 182 142 0     906.205986
# 2      OAS1_0081_MR1_mpr-1  3rd-Ventricle 204 182 142 0     711.038989
# 3      OAS1_0385_MR1_mpr-1  3rd-Ventricle 204 182 142 0     813.252988
# 4      OAS1_0410_MR1_mpr-1  3rd-Ventricle 204 182 142 0     749.454989
# ...                    ...                          ...            ...
# 35305  OAS1_0237_MR1_mpr-4                      Frontal  130259.393008
# 35306  OAS1_0147_MR1_mpr-4                      Frontal  182532.935209
# 35307  OAS1_0066_MR1_mpr-4                      Frontal  129508.566020
# 35308  OAS1_0270_MR1_mpr-4                      Frontal  129829.271015
# 35309  OAS1_0359_MR1_mpr-4                      Frontal  207780.478823
#
# [35310 rows x 3 columns]

# %%
all_data_long['Session'] = all_data_long['subject'].str.extract(r'(mpr-\d)')

all_data_long['ROI'] = all_data_long['ROI'].str.extract(r'([a-zA-Z-_]+)')[0]

# %%
all_data_long['Subject_ID'] = all_data_long['subject'].str.extract(r'(OAS1_\d+)')
all_data_long['Session'] = all_data_long['subject'].str.extract(r'(mpr-\d)')

# %%
re_long= all_data_long.dropna(subset=['Volume'])


grouped = re_long.groupby(['Subject_ID', 'ROI'])['Volume'].agg(['mean', 'var','std']).reset_index()

grouped
# Out:
#      Subject_ID                      ROI          mean          var        std
# 0     OAS1_0001           Accumbens-area    785.984488   166.081167  12.887248
# 1     OAS1_0001                 Amygdala   2532.626211  6404.056450  80.025349
# 2     OAS1_0001               Brain-Stem  17619.566731  4402.739176  66.353140
# 3     OAS1_0001                      CSF   1663.206975   449.497599  21.201358
# 4     OAS1_0001                  Caudate   7020.695393    74.236517   8.616062
# ...         ...                      ...           ...          ...        ...
# 8731  OAS1_0457                 Thalamus  13627.961458  1765.715354  42.020416
# 8732  OAS1_0457  Total-Lateral-Ventricle  21309.332007    43.098749   6.564964
# 8733  OAS1_0457                VentralDC   6322.747570  1365.944065  36.958681
# 8734  OAS1_0457             rd-Ventricle   1091.997650   251.455122  15.857337
# 8735  OAS1_0457             th-Ventricle   1730.434974  1814.265174  42.594192
#
# [8736 rows x 5 columns]

# %%
-
# Out:
#      Subject_ID                      ROI          mean          var  \
# 0     OAS1_0001           Accumbens-area    785.984488   166.081167
# 1     OAS1_0001                 Amygdala   2532.626211  6404.056450
# 2     OAS1_0001               Brain-Stem  17619.566731  4402.739176
# 3     OAS1_0001                      CSF   1663.206975   449.497599
# 4     OAS1_0001                  Caudate   7020.695393    74.236517
# ...         ...                      ...           ...          ...
# 9147  OAS1_0457  Total-Lateral-Ventricle  21309.332007    43.098749
# 9148  OAS1_0457                VentralDC   6322.747570  1365.944065
# 9149  OAS1_0457             rd-Ventricle   1091.997650   251.455122
# 9150  OAS1_0457                 sort_key    457.000000     0.000000
# 9151  OAS1_0457             th-Ventricle   1730.434974  1814.265174
#
#             std        CV
# 0     12.887248  0.016396
# 1     80.025349  0.031598
# 2     66.353140  0.003766
# 3     21.201358  0.012747
# 4      8.616062  0.001227
# ...         ...       ...
# 9147   6.564964  0.000308
# 9148  36.958681  0.005845
# 9149  15.857337  0.014521
# 9150   0.000000  0.000000
# 9151  42.594192  0.024615
#
# [9152 rows x 6 columns]

# %%
grouped['CV'] = grouped['std'] / grouped['mean']
grouped
# Out:
#      Subject_ID                      ROI          mean          var  \
# 0     OAS1_0001           Accumbens-area    785.984488   166.081167
# 1     OAS1_0001                 Amygdala   2532.626211  6404.056450
# 2     OAS1_0001               Brain-Stem  17619.566731  4402.739176
# 3     OAS1_0001                      CSF   1663.206975   449.497599
# 4     OAS1_0001                  Caudate   7020.695393    74.236517
# ...         ...                      ...           ...          ...
# 8731  OAS1_0457                 Thalamus  13627.961458  1765.715354
# 8732  OAS1_0457  Total-Lateral-Ventricle  21309.332007    43.098749
# 8733  OAS1_0457                VentralDC   6322.747570  1365.944065
# 8734  OAS1_0457             rd-Ventricle   1091.997650   251.455122
# 8735  OAS1_0457             th-Ventricle   1730.434974  1814.265174
#
#             std        CV
# 0     12.887248  0.016396
# 1     80.025349  0.031598
# 2     66.353140  0.003766
# 3     21.201358  0.012747
# 4      8.616062  0.001227
# ...         ...       ...
# 8731  42.020416  0.003083
# 8732   6.564964  0.000308
# 8733  36.958681  0.005845
# 8734  15.857337  0.014521
# 8735  42.594192  0.024615
#
# [8736 rows x 6 columns]

# %%
grouped.to_csv("individual_before_fastsurfer_swift_20240415.csv")

# %%
roi_mean_cv = grouped.groupby('ROI')['CV'].mean().reset_index()
roi_mean_cv.rename(columns={'CV': 'Mean_CV'}, inplace=True)

roi_mean_cv
# Out:
#                               ROI   Mean_CV
# 0                      Brain-Stem  0.010885
# 1                             CSF  0.019460
# 2             Left-Accumbens-area  0.029916
# 3                    Left-Caudate  0.007575
# 4                 Left-Cerebellum  0.007581
# 5                  Left-Cingulate  0.011359
# 6       Left-Combined-Cerebral-WM  0.005834
# 7                    Left-Frontal  0.006847
# 8                     Left-Insula  0.013066
# 9                  Left-Occipital  0.016925
# 10                  Left-Pallidum  0.015750
# 11                  Left-Parietal  0.007941
# 12                   Left-Putamen  0.010744
# 13                  Left-Temporal  0.013175
# 14                  Left-Thalamus  0.007891
# 15   Left-Total-Lateral-Ventricle  0.006663
# 16                 Left-VentralDC  0.013627
# 17            Left-choroid-plexus  0.029319
# 18           Right-Accumbens-area  0.026240
# 19                  Right-Caudate  0.007533
# 20               Right-Cerebellum  0.008527
# 21                Right-Cingulate  0.011370
# 22     Right-Combined-Cerebral-WM  0.005964
# 23                  Right-Frontal  0.006991
# 24                   Right-Insula  0.014614
# 25                Right-Occipital  0.014188
# 26                 Right-Pallidum  0.016175
# 27                 Right-Parietal  0.008166
# 28                  Right-Putamen  0.011143
# 29                 Right-Temporal  0.014300
# 30                 Right-Thalamus  0.008033
# 31  Right-Total-Lateral-Ventricle  0.006955
# 32                Right-VentralDC  0.013715
# 33           Right-choroid-plexus  0.026192
# 34                        Unknown  0.000366
# 35             WM-hypointensities  0.042387
# 36                   rd-Ventricle  0.017013
# 37                       sort_key  0.000000
# 38                   th-Ventricle  0.027230

# %%
from scipy import stats
import numpy as np
from scipy.stats import sem, t
from numpy import sqrt

# %%
def calculate_mean_ci(group):

    cv_data = group['CV']
    n = len(cv_data) 
    mean_cv = cv_data.mean()  
    se = sem(cv_data, nan_policy='omit')  
    h = se * t.ppf((1 + 0.95) / 2., n-1) 

    return pd.Series({
        'Mean_CV': mean_cv,
        'CI_Lower': mean_cv - h,
        'CI_Upper': mean_cv + h
    })

# %%
roi_mean_ci = grouped.groupby('ROI').apply(calculate_mean_ci).reset_index()

roi_mean_ci
# Out:
# /tmp/ipykernel_2381762/4097598325.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   roi_mean_ci = grouped.groupby('ROI').apply(calculate_mean_ci).reset_index()
#                               ROI   Mean_CV  CI_Lower  CI_Upper
# 0                      Brain-Stem  0.010885  0.009295  0.012476
# 1                             CSF  0.019460  0.018242  0.020678
# 2             Left-Accumbens-area  0.029916  0.027914  0.031919
# 3                    Left-Caudate  0.007575  0.006877  0.008273
# 4                 Left-Cerebellum  0.007581  0.006473  0.008689
# 5                  Left-Cingulate  0.011359  0.010434  0.012284
# 6       Left-Combined-Cerebral-WM  0.005834  0.004965  0.006702
# 7                    Left-Frontal  0.006847  0.005817  0.007878
# 8                     Left-Insula  0.013066  0.011986  0.014145
# 9                  Left-Occipital  0.016925  0.011410  0.022439
# 10                  Left-Pallidum  0.015750  0.014916  0.016584
# 11                  Left-Parietal  0.007941  0.006811  0.009071
# 12                   Left-Putamen  0.010744  0.009348  0.012141
# 13                  Left-Temporal  0.013175  0.011694  0.014656
# 14                  Left-Thalamus  0.007891  0.007447  0.008336
# 15   Left-Total-Lateral-Ventricle  0.006663  0.005934  0.007392
# 16                 Left-VentralDC  0.013627  0.012819  0.014435
# 17            Left-choroid-plexus  0.029319  0.027724  0.030914
# 18           Right-Accumbens-area  0.026240  0.024839  0.027641
# 19                  Right-Caudate  0.007533  0.006944  0.008122
# 20               Right-Cerebellum  0.008527  0.006956  0.010097
# 21                Right-Cingulate  0.011370  0.010398  0.012342
# 22     Right-Combined-Cerebral-WM  0.005964  0.005042  0.006885
# 23                  Right-Frontal  0.006991  0.006162  0.007820
# 24                   Right-Insula  0.014614  0.013283  0.015944
# 25                Right-Occipital  0.014188  0.009034  0.019341
# 26                 Right-Pallidum  0.016175  0.014680  0.017669
# 27                 Right-Parietal  0.008166  0.006827  0.009504
# 28                  Right-Putamen  0.011143  0.009039  0.013247
# 29                 Right-Temporal  0.014300  0.012591  0.016009
# 30                 Right-Thalamus  0.008033  0.007548  0.008518
# 31  Right-Total-Lateral-Ventricle  0.006955  0.006277  0.007634
# 32                Right-VentralDC  0.013715  0.012909  0.014521
# 33           Right-choroid-plexus  0.026192  0.024694  0.027689
# 34                        Unknown  0.000366  0.000314  0.000418
# 35             WM-hypointensities  0.042387  0.036840  0.047935
# 36                   rd-Ventricle  0.017013  0.015853  0.018172
# 37                       sort_key  0.000000  0.000000  0.000000
# 38                   th-Ventricle  0.027230  0.019426  0.035034

# %%
roi_mean_ci = roi_mean_ci.round(3)

# %%
roi_mean_ci
# Out:
#                               ROI  Mean_CV  CI_Lower  CI_Upper
# 0                      Brain-Stem    0.011     0.009     0.012
# 1                             CSF    0.019     0.018     0.021
# 2             Left-Accumbens-area    0.030     0.028     0.032
# 3                    Left-Caudate    0.008     0.007     0.008
# 4                 Left-Cerebellum    0.008     0.006     0.009
# 5                  Left-Cingulate    0.011     0.010     0.012
# 6       Left-Combined-Cerebral-WM    0.006     0.005     0.007
# 7                    Left-Frontal    0.007     0.006     0.008
# 8                     Left-Insula    0.013     0.012     0.014
# 9                  Left-Occipital    0.017     0.011     0.022
# 10                  Left-Pallidum    0.016     0.015     0.017
# 11                  Left-Parietal    0.008     0.007     0.009
# 12                   Left-Putamen    0.011     0.009     0.012
# 13                  Left-Temporal    0.013     0.012     0.015
# 14                  Left-Thalamus    0.008     0.007     0.008
# 15   Left-Total-Lateral-Ventricle    0.007     0.006     0.007
# 16                 Left-VentralDC    0.014     0.013     0.014
# 17            Left-choroid-plexus    0.029     0.028     0.031
# 18           Right-Accumbens-area    0.026     0.025     0.028
# 19                  Right-Caudate    0.008     0.007     0.008
# 20               Right-Cerebellum    0.009     0.007     0.010
# 21                Right-Cingulate    0.011     0.010     0.012
# 22     Right-Combined-Cerebral-WM    0.006     0.005     0.007
# 23                  Right-Frontal    0.007     0.006     0.008
# 24                   Right-Insula    0.015     0.013     0.016
# 25                Right-Occipital    0.014     0.009     0.019
# 26                 Right-Pallidum    0.016     0.015     0.018
# 27                 Right-Parietal    0.008     0.007     0.010
# 28                  Right-Putamen    0.011     0.009     0.013
# 29                 Right-Temporal    0.014     0.013     0.016
# 30                 Right-Thalamus    0.008     0.008     0.009
# 31  Right-Total-Lateral-Ventricle    0.007     0.006     0.008
# 32                Right-VentralDC    0.014     0.013     0.015
# 33           Right-choroid-plexus    0.026     0.025     0.028
# 34                        Unknown    0.000     0.000     0.000
# 35             WM-hypointensities    0.042     0.037     0.048
# 36                   rd-Ventricle    0.017     0.016     0.018
# 37                       sort_key    0.000     0.000     0.000
# 38                   th-Ventricle    0.027     0.019     0.035

# %%
#roi_mean_cv.to_csv("before_swift_combinedroi_20240411.csv")

# %%
import pandas as pd
import pingouin as pg


def calculate_icc_for_roi(df):

    icc_results = []


    for roi in df['ROI'].unique():

        df_subset = df[df['ROI'] == roi]
        

        icc = pg.intraclass_corr(data=df_subset, targets='Subject_ID', raters='Session', ratings='Volume', nan_policy='omit')
        

        icc_row = icc[icc['Type'] == 'ICC3k'].iloc[0]
        icc_results.append({
            'ROI': roi,
            'ICC': icc_row['ICC'],
            '95% CI': icc_row['CI95%'],
            'F': icc_row['F'],
            'df1': icc_row['df1'],
            'df2': icc_row['df2'],
            'p-value': icc_row['pval']
        })

    icc_df = pd.DataFrame(icc_results)

    return icc_df

# %%
icc_df = calculate_icc_for_roi(all_data_long)
# Out:
# /home/limseoyoung/fsl/lib/python3.11/site-packages/pingouin/parametric.py:1008: RuntimeWarning: divide by zero encountered in scalar divide
#   fval = msbetween / mserror
# /home/limseoyoung/fsl/lib/python3.11/site-packages/pingouin/reliability.py:320: RuntimeWarning: divide by zero encountered in scalar divide
#   f1k = msb / msw
# /home/limseoyoung/fsl/lib/python3.11/site-packages/pingouin/reliability.py:325: RuntimeWarning: divide by zero encountered in scalar divide
#   f2k = f3k = msb / mse
# /home/limseoyoung/fsl/lib/python3.11/site-packages/pingouin/reliability.py:354: RuntimeWarning: invalid value encountered in scalar divide
#   l1 = (f1l - 1) / (f1l + (k - 1))
# /home/limseoyoung/fsl/lib/python3.11/site-packages/pingouin/reliability.py:355: RuntimeWarning: invalid value encountered in scalar divide
#   u1 = (f1u - 1) / (f1u + (k - 1))
# /home/limseoyoung/fsl/lib/python3.11/site-packages/pingouin/reliability.py:358: RuntimeWarning: invalid value encountered in scalar divide
#   l3 = (f3l - 1) / (f3l + (k - 1))
# /home/limseoyoung/fsl/lib/python3.11/site-packages/pingouin/reliability.py:359: RuntimeWarning: invalid value encountered in scalar divide
#   u3 = (f3u - 1) / (f3u + (k - 1))
# /home/limseoyoung/fsl/lib/python3.11/site-packages/pingouin/reliability.py:361: RuntimeWarning: invalid value encountered in scalar divide
#   fj = msj / mse

# %%
icc_df
# Out:
#                               ROI       ICC        95% CI            F  df1  \
# 0                         Unknown  0.998432    [1.0, 1.0]   637.569008  356
# 1                   Left-Thalamus  0.999189    [1.0, 1.0]  1232.752352  356
# 2                    Left-Caudate  0.999017    [1.0, 1.0]  1017.364850  356
# 3                    Left-Putamen  0.998300    [1.0, 1.0]   588.154394  356
# 4                   Left-Pallidum  0.995108   [0.99, 1.0]   204.410874  356
# 5                    rd-Ventricle  0.999656    [1.0, 1.0]  2907.892216  356
# 6                    th-Ventricle  0.993325  [0.99, 0.99]   149.815553  356
# 7                      Brain-Stem  0.994589   [0.99, 1.0]   184.795009  356
# 8                             CSF  0.998866    [1.0, 1.0]   881.869443  356
# 9             Left-Accumbens-area  0.994704   [0.99, 1.0]   188.839245  356
# 10                 Left-VentralDC  0.996796    [1.0, 1.0]   312.142788  356
# 11            Left-choroid-plexus  0.995338   [0.99, 1.0]   214.515547  356
# 12                 Right-Thalamus  0.999019    [1.0, 1.0]  1019.512190  356
# 13                  Right-Caudate  0.999115    [1.0, 1.0]  1129.422404  356
# 14                  Right-Putamen  0.998241    [1.0, 1.0]   568.347075  356
# 15                 Right-Pallidum  0.995378   [0.99, 1.0]   216.355321  356
# 16           Right-Accumbens-area  0.995092   [0.99, 1.0]   203.752964  356
# 17                Right-VentralDC  0.996623    [1.0, 1.0]   296.152884  356
# 18           Right-choroid-plexus  0.994060   [0.99, 1.0]   168.364191  356
# 19             WM-hypointensities  0.999527    [1.0, 1.0]  2115.186155  356
# 20                       sort_key  1.000000    [1.0, 1.0]          inf  356
# 21                 Left-Cingulate  0.997235    [1.0, 1.0]   361.692743  356
# 22                Right-Cingulate  0.997663    [1.0, 1.0]   427.828804  356
# 23                   Left-Frontal  0.998976    [1.0, 1.0]   976.766959  356
# 24                  Right-Frontal  0.998640    [1.0, 1.0]   735.199265  356
# 25                  Left-Temporal  0.996575    [1.0, 1.0]   291.963041  356
# 26                 Right-Temporal  0.995522   [0.99, 1.0]   223.327431  356
# 27                  Left-Parietal  0.998201    [1.0, 1.0]   555.756599  356
# 28                 Right-Parietal  0.997701    [1.0, 1.0]   435.053233  356
# 29                 Left-Occipital  0.990433  [0.99, 0.99]   104.520736  356
# 30                Right-Occipital  0.992363  [0.99, 0.99]   130.937450  356
# 31                    Left-Insula  0.996657    [1.0, 1.0]   299.108935  356
# 32                   Right-Insula  0.995044   [0.99, 1.0]   201.759463  356
# 33                Left-Cerebellum  0.998468    [1.0, 1.0]   652.633223  356
# 34               Right-Cerebellum  0.997216    [1.0, 1.0]   359.172632  356
# 35      Left-Combined-Cerebral-WM  0.999049    [1.0, 1.0]  1051.110289  356
# 36     Right-Combined-Cerebral-WM  0.998918    [1.0, 1.0]   923.862285  356
# 37   Left-Total-Lateral-Ventricle  0.999708    [1.0, 1.0]  3419.195698  356
# 38  Right-Total-Lateral-Ventricle  0.999809    [1.0, 1.0]  5230.429996  356
#
#      df2  p-value
# 0   1068      0.0
# 1   1068      0.0
# 2   1068      0.0
# 3   1068      0.0
# 4   1068      0.0
# 5   1068      0.0
# 6   1068      0.0
# 7   1068      0.0
# 8   1068      0.0
# 9   1068      0.0
# 10  1068      0.0
# 11  1068      0.0
# 12  1068      0.0
# 13  1068      0.0
# 14  1068      0.0
# 15  1068      0.0
# 16  1068      0.0
# 17  1068      0.0
# 18  1068      0.0
# 19  1068      0.0
# 20  1068      0.0
# 21  1068      0.0
# 22  1068      0.0
# 23  1068      0.0
# 24  1068      0.0
# 25  1068      0.0
# 26  1068      0.0
# 27  1068      0.0
# 28  1068      0.0
# 29  1068      0.0
# 30  1068      0.0
# 31  1068      0.0
# 32  1068      0.0
# 33  1068      0.0
# 34  1068      0.0
# 35  1068      0.0
# 36  1068      0.0
# 37  1068      0.0
# 38  1068      0.0

# %%
import numpy as np
import pandas as pd
from scipy.stats import ttest_rel

# Assuming all_data_long is already loaded
unique_sessions = all_data_long['Session'].unique()

results = []

# Iterate over each ROI
for roi in all_data_long['ROI'].unique():
    roi_data = all_data_long[all_data_long['ROI'] == roi]
    
    # Iterate over each subject within this ROI
    for subject in roi_data['Subject_ID'].unique():
        subject_data = roi_data[roi_data['Subject_ID'] == subject]
        all_volumes = subject_data['Volume'].dropna()  # Collect all volumes across sessions

        if len(all_volumes) > 1:
            overall_std = all_volumes.std()  # Pooled standard deviation across all sessions
            #print(f"Subject: {subject}, ROI: {roi}, Overall Std: {overall_std}")

            effect_sizes = []

            # Compare all possible session pairs
            for i in range(len(unique_sessions)):
                for j in range(i+1, len(unique_sessions)):
                    session1_data = subject_data[subject_data['Session'] == unique_sessions[i]]
                    session2_data = subject_data[subject_data['Session'] == unique_sessions[j]]

                    if not session1_data.empty and not session2_data.empty:
                        mean1 = session1_data['Volume'].mean()
                        mean2 = session2_data['Volume'].mean()

                        if overall_std > 0:
                            effect_size_d = (mean2 - mean1) / overall_std
                            effect_sizes.append(effect_size_d)
                            #print(f"Effect Size D between {unique_sessions[i]} and {unique_sessions[j]}: {effect_size_d}")
                        else:
                            print("Skipping due to zero overall standard deviation.")

            # Calculate and store the mean effect size for this subject and ROI
            if effect_sizes:
                mean_effect_size_d = np.mean(effect_sizes)
                results.append({
                    'Subject_ID': subject,
                    'ROI': roi,
                    'Mean Effect Size D': mean_effect_size_d
                })

# Convert results to DataFrame and print
results_df = pd.DataFrame(results)
# Out:
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# ...
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.
# Skipping due to zero overall standard deviation.

# %%
results_df
# Out:
#       Subject_ID                            ROI  Mean Effect Size D
# 0      OAS1_0365                        Unknown            1.072183
# 1      OAS1_0403                        Unknown           -1.281846
# 2      OAS1_0081                        Unknown           -1.032931
# 3      OAS1_0385                        Unknown            0.263687
# 4      OAS1_0410                        Unknown           -0.412454
# ...          ...                            ...                 ...
# 15803  OAS1_0313  Right-Total-Lateral-Ventricle           -0.334513
# 15804  OAS1_0220  Right-Total-Lateral-Ventricle            1.020073
# 15805  OAS1_0114  Right-Total-Lateral-Ventricle           -1.100187
# 15806  OAS1_0203  Right-Total-Lateral-Ventricle           -1.282378
# 15807  OAS1_0362  Right-Total-Lateral-Ventricle            0.650935
#
# [15808 rows x 3 columns]

# %%
grouped_results = results_df.groupby('ROI')['Mean Effect Size D'].mean().reset_index()

# %%
grouped_results
# Out:
#                               ROI  Mean Effect Size D
# 0                      Brain-Stem           -0.035116
# 1                             CSF            0.076709
# 2             Left-Accumbens-area           -0.061613
# 3                    Left-Caudate           -0.060282
# 4                 Left-Cerebellum            0.051201
# 5                  Left-Cingulate            0.033860
# 6       Left-Combined-Cerebral-WM           -0.179513
# 7                    Left-Frontal            0.050410
# 8                     Left-Insula            0.055959
# 9                  Left-Occipital            0.022520
# 10                  Left-Pallidum            0.025403
# 11                  Left-Parietal            0.021491
# 12                   Left-Putamen           -0.084005
# 13                  Left-Temporal           -0.041035
# 14                  Left-Thalamus            0.021358
# 15   Left-Total-Lateral-Ventricle            0.113013
# 16                 Left-VentralDC           -0.096591
# 17            Left-choroid-plexus           -0.084503
# 18           Right-Accumbens-area           -0.025865
# 19                  Right-Caudate            0.051835
# 20               Right-Cerebellum            0.006404
# 21                Right-Cingulate           -0.039190
# 22     Right-Combined-Cerebral-WM           -0.154542
# 23                  Right-Frontal            0.039905
# 24                   Right-Insula            0.052379
# 25                Right-Occipital           -0.007139
# 26                 Right-Pallidum           -0.008290
# 27                 Right-Parietal           -0.015272
# 28                  Right-Putamen           -0.093215
# 29                 Right-Temporal           -0.083494
# 30                 Right-Thalamus           -0.003761
# 31  Right-Total-Lateral-Ventricle            0.193858
# 32                Right-VentralDC           -0.061530
# 33           Right-choroid-plexus           -0.114826
# 34                        Unknown            0.031890
# 35             WM-hypointensities            0.148176
# 36                   rd-Ventricle            0.080805
# 37                   th-Ventricle            0.018110

# %%
pwd
# Out:
# '/home/limseoyoung/debug'
