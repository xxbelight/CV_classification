# %%
combined_roi_dict = {
    'Left-Cingulate': {
        'ctx-lh-caudalanteriorcingulate',
        'ctx-lh-rostralanteriorcingulate',
        'ctx-lh-isthmuscingulate',
        'ctx-lh-posteriorcingulate',
    },
    'Right-Cingulate': {
        'ctx-rh-caudalanteriorcingulate',
        'ctx-rh-rostralanteriorcingulate',
        'ctx-rh-isthmuscingulate',
        'ctx-rh-posteriorcingulate',
    },
    'Left-Frontal': {
        'ctx-lh-caudalmiddlefrontal',
        'ctx-lh-lateralorbitofrontal',
        'ctx-lh-medialorbitofrontal',
        'ctx-lh-parsopercularis',
        'ctx-lh-parsorbitalis',
        'ctx-lh-parstriangularis',
        'ctx-lh-precentral',
        'ctx-lh-rostralmiddlefrontal',
        'ctx-lh-superiorfrontal',
        'ctx-lh-paracentral'
    },
    'Right-Frontal': {
        'ctx-rh-caudalmiddlefrontal',
        'ctx-rh-lateralorbitofrontal',
        'ctx-rh-medialorbitofrontal',
        'ctx-rh-parsopercularis',
        'ctx-rh-parsorbitalis',
        'ctx-rh-parstriangularis',
        'ctx-rh-precentral',
        'ctx-rh-rostralmiddlefrontal',
        'ctx-rh-superiorfrontal',
        'ctx-rh-paracentral'
    },
    'Left-Temporal': {
        'ctx-lh-entorhinal',
        'ctx-lh-fusiform',
        'ctx-lh-inferiortemporal',
        'ctx-lh-middletemporal',
        'ctx-lh-superiortemporal',
        'ctx-lh-transversetemporal',
        'ctx-lh-parahippocampal',
        
    },
    'Right-Temporal': {
        'ctx-rh-entorhinal',
        'ctx-rh-fusiform',
        'ctx-rh-inferiortemporal',
        'ctx-rh-middletemporal',
        'ctx-rh-superiortemporal',
        'ctx-rh-transversetemporal',
        'ctx-rh-parahippocampal',
     
    },
    'Left-Parietal': {
        'ctx-lh-inferiorparietal',
        'ctx-lh-postcentral',
        'ctx-lh-superiorparietal',
        'ctx-lh-supramarginal',
        'ctx-lh-precuneus'
    },
    'Right-Parietal': {
        'ctx-rh-inferiorparietal',
        'ctx-rh-postcentral',
        'ctx-rh-superiorparietal',
        'ctx-rh-supramarginal',
        'ctx-rh-precuneus'
    },
    'Left-Occipital': {
        'ctx-lh-cuneus',
        'ctx-lh-lateraloccipital',
        'ctx-lh-lingual',
        'ctx-lh-pericalcarine'
    },
    'Right-Occipital': {
        'ctx-rh-cuneus',
        'ctx-rh-lateraloccipital',
        'ctx-rh-lingual',
        'ctx-rh-pericalcarine'
    },
    'Left-Insula':{
        'ctx-lh-insula'
    },
    'Right-Insula': {
        'ctx-rh-insula'
    },
    'Left-Cerebellum':{
        'Left-Cerebellum-White-Matter',
        'Left-Cerebellum-Cortex'
    },
    'Right-Cerebellum': {
        'Right-Cerebellum-White-Matter',
        'Right-Cerebellum-Cortex'
    },
    'Left-Combined-Cerebral-WM': {
        'Left-Cerebral-White-Matter',
        'Left-WM-hypointensities'
    },
    'Right-Combined-Cerebral-WM': {
        'Right-Cerebral-White-Matter',
        'Right-WM-hypointensities'
    },
    'Left-Total-Lateral-Ventricle': {
        'Left-Lateral-Ventricle',
        'Left-Inf-Lat-Vent'
    },
    'Right-Total-Lateral-Ventricle': {
        'Right-Lateral-Ventricle',
        'Right-Inf-Lat-Vent'
    },
}
gray_matter_index = {
    'left_cortical_gm': {
        'left_cingulate',
        'left_frontal',
        'left_temporal',
        'left_parietal',
        'left_occipital',
        'left_insula'
    },
    'right_cortical_gm': {
        'right_cingulate',
        'right_frontal',
        'right_temporal',
        'right_parietal',
        'right_occipital',
        'right_insula'
    }
}

combined_roi_display_dict = {
    'Left-Cingulate': {
        'ctx-lh-caudalanteriorcingulate',
        'ctx-lh-rostralanteriorcingulate',
        'ctx-lh-isthmuscingulate',
        'ctx-lh-posteriorcingulate',
    },
    'Right-Cingulate': {
        'ctx-rh-caudalanteriorcingulate',
        'ctx-rh-rostralanteriorcingulate',
        'ctx-rh-isthmuscingulate',
        'ctx-rh-posteriorcingulate',
    },
    'Left-Frontal': {
        'ctx-lh-caudalmiddlefrontal',
        'ctx-lh-lateralorbitofrontal',
        'ctx-lh-medialorbitofrontal',
        'ctx-lh-parsopercularis',
        'ctx-lh-parsorbitalis',
        'ctx-lh-parstriangularis',
        'ctx-lh-precentral',
        'ctx-lh-rostralmiddlefrontal',
        'ctx-lh-superiorfrontal',
        'ctx-lh-paracentral'
    },
    'Right-Frontal': {
        'ctx-rh-caudalmiddlefrontal',
        'ctx-rh-lateralorbitofrontal',
        'ctx-rh-medialorbitofrontal',
        'ctx-rh-parsopercularis',
        'ctx-rh-parsorbitalis',
        'ctx-rh-parstriangularis',
        'ctx-rh-precentral',
        'ctx-rh-rostralmiddlefrontal',
        'ctx-rh-superiorfrontal',
        'ctx-rh-paracentral'
    },
    'Left-Temporal': {
        'ctx-lh-entorhinal',
        'ctx-lh-fusiform',
        'ctx-lh-inferiortemporal',
        'ctx-lh-middletemporal',
        'ctx-lh-superiortemporal',
        'ctx-lh-transversetemporal',
        'ctx-lh-parahippocampal',
    },
    'Right-Temporal': {
        'ctx-rh-entorhinal',
        'ctx-rh-fusiform',
        'ctx-rh-inferiortemporal',
        'ctx-rh-middletemporal',
        'ctx-rh-superiortemporal',
        'ctx-rh-transversetemporal',
        'ctx-rh-parahippocampal',
    },
    'Left-Parietal': {
        'ctx-lh-inferiorparietal',
        'ctx-lh-postcentral',
        'ctx-lh-superiorparietal',
        'ctx-lh-supramarginal',
        'ctx-lh-precuneus'
    },
    'Right-Parietal': {
        'ctx-rh-inferiorparietal',
        'ctx-rh-postcentral',
        'ctx-rh-superiorparietal',
        'ctx-rh-supramarginal',
        'ctx-rh-precuneus'
    },
    'Left-Occipital': {
        'ctx-lh-cuneus',
        'ctx-lh-lateraloccipital',
        'ctx-lh-lingual',
        'ctx-lh-pericalcarine'
    },
    'Right-Occipital': {
        'ctx-rh-cuneus',
        'ctx-rh-lateraloccipital',
        'ctx-rh-lingual',
        'ctx-rh-pericalcarine'
    },
    'Left-Insula':{
        'ctx-lh-insula'
    },
    'Right-Insula': {
        'ctx-rh-insula'
    },
    'Left-Cerebellum':{
        'Left-Cerebellum-White-Matter',
        'Left-Cerebellum-Cortex'
    },
    'Right-Cerebellum': {
        'Right-Cerebellum-White-Matter',
        'Right-Cerebellum-Cortex'
    },
    'Left-Combined-Cerebral-WM': {
        'Left-Cerebral-White-Matter',
        'Left-WM-hypointensities'
    },
    'Right-Combined-Cerebral-WM': {
        'Right-Cerebral-White-Matter',
        'Right-WM-hypointensities'
    }
}

# %%
import pandas as pd
import pickle
import argparse
import os
import glob
import pydicom
import sys
# Out:
# /tmp/ipykernel_3256894/1002562574.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
# 경로만 지정!
base_dir = '/home/limseoyoung/drwelly1/SeoyoungLim/drwelly-debug/drwelly_simence_SWU1_before'


def calculate_volume(nii_path):
    img = nib.load(nii_path) 
    data = img.get_fdata()
    header = img.header
    voxel_volume = np.prod(header.get_zooms())
    unique_elements, counts_elements = np.unique(data, return_counts=True)
    volumes = counts_elements * voxel_volume
    return dict(zip(unique_elements.astype(int), volumes))

# %%
import os
import pandas as pd
import pickle

def load_pickle_file(file_path):
    with open(file_path, 'rb') as file:
        return pickle.load(file)
        
def find_volumes_files(root_path):
    volumes_files = []
    for root, dirs, files in os.walk(root_path):
        for file in files:
            if file == 'volumes.pickle':
                volumes_files.append(os.path.join(root, file))
    return volumes_files

def extract_subject_data(volumes_file_path):
    subject_name = os.path.dirname(volumes_file_path).split(os.sep)[-3]
    volumes_data = load_pickle_file(volumes_file_path)
    volumes_data['subject'] = subject_name
    return volumes_data

def compile_data(volumes_files):
    data = []
    for volumes_file in volumes_files:
        subject_data = extract_subject_data(volumes_file)
        data.append(subject_data)
    df = pd.DataFrame(data)
    # You might need to adjust the DataFrame to ensure it has the structure you want
    return df

root_path = '/home/limseoyoung/drwelly1/SeoyoungLim/drwelly-debug/drwelly_simence_SWU1_before'
volumes_files = find_volumes_files(root_path)
df = compile_data(volumes_files)

# %%
df
# Out:
#     total_intracranial_volume       unknown  left_cerebral_white_matter  \
# 0                1.491553e+06  1.437847e+07               228959.691303
# 1                1.605587e+06  1.426443e+07               231578.839169
# 2                1.562897e+06  1.430712e+07               254840.754980
# 3                1.394619e+06  1.447540e+07               219874.307767
# 4                1.499385e+06  1.437063e+07               227979.054353
# ..                        ...           ...                         ...
# 87               1.545878e+06  1.432414e+07               228019.871351
# 88               1.510856e+06  1.435916e+07               219403.025791
# 89               1.311555e+06  1.455846e+07               189739.701306
# 90               1.316961e+06  1.455306e+07               188719.962358
# 91               1.561950e+06  1.430807e+07               254559.151995
#
#     left_lateral_ventricle  left_inf_lat_vent  left_cerebellum_white_matter  \
# 0              6047.775691         533.021973                  13579.712306
# 1              7208.144632         646.554967                  15415.791212
# 2              3768.540807         476.426976                  16953.117134
# 3              3622.765815         397.193980                  14112.048279
# 4              4530.343769         924.727953                  13149.247328
# ..                     ...                ...                           ...
# 87             6288.218679         796.445959                  15404.129213
# 88             8430.596569         356.719982                  13882.924291
# 89             3664.611813         577.268971                  14325.051268
# 90             3643.002814         574.867971                  14495.522259
# 91             3744.187809         502.151974                  16900.638137
#
#     left_cerebellum_cortex  left_thalamus  left_caudate  left_putamen  ...  \
# 0             57680.249053    9353.952522   3530.841820   5551.797716  ...
# 1             59855.554942    8980.768541   3789.120806   6437.423671  ...
# 2             58847.820993    9972.381491   3826.850804   5503.777719  ...
# 3             52332.879326    9134.775533   3359.684828   5333.992727  ...
# 4             51317.256378    9420.837519   3508.546821   5645.436712  ...
# ..                     ...            ...           ...           ...  ...
# 87            58872.173992    8658.691558   3958.905798   5358.688726  ...
# 88            50876.158401    8162.713583   3048.926844   4686.751761  ...
# 89            54601.138210    8448.432568   3275.992833   5180.328735  ...
# 90            54326.395224    8385.663572   3306.862831   5238.295732  ...
# 91            58177.599028   10004.623489   3823.420805   5496.231719  ...
#
#        cerebellum  cerebellum_white_matter  cerebellum_cortex  \
# 0   141950.542748             26640.122639      115310.420109
# 1   152043.660232             30363.387449      121680.272783
# 2   150253.543324             33036.729312      117216.814011
# 3   132186.019247             27829.303578      104356.715668
# 4   127885.485466             26116.361666      101769.123801
# ..            ...                      ...                ...
# 87  147704.367454             30475.205443      117229.162011
# 88  128631.510428             27067.500617      101564.009811
# 89  136435.789030             27728.804583      108706.984446
# 90  136187.114042             27941.464572      108245.649470
# 91  149128.503381             32728.029328      116400.474053
#
#     lateral_ventricle  inf_lat_vent  total_lateral_ventricle  \
# 0        10541.418461    915.466953             11456.885415
# 1        14813.826243   1264.297935             16078.124179
# 2         9559.066512   1270.814935             10829.881447
# 3         6748.181655    796.445959              7544.627615
# 4         7271.599628   1370.627930              8642.227558
# ..                ...           ...                      ...
# 87       14201.914274   1386.748929             15588.663204
# 88       14674.911250    831.088958             15506.000208
# 89        7437.954620   1022.825948              8460.780568
# 90        7424.234621   1039.975947              8464.210568
# 91        9507.959514   1304.428933             10812.388448
#
#     wm_hypointensities  HippocampusOccupancyScore  HippocampusAsymmetryIndex  \
# 0          1107.889943                   0.902688                   0.009746
# 1          1024.197948                   0.873138                   0.033573
# 2          1361.366930                   0.881496                   0.012642
# 3          1208.045938                   0.911262                   0.019369
# 4          1071.874945                   0.845898                   0.094129
# ..                 ...                        ...                        ...
# 87          925.756953                   0.845056                   0.012950
# 88          869.161956                   0.902210                   0.042133
# 89          984.409950                   0.885830                   0.007313
# 90          969.317950                   0.884677                   0.006196
# 91         1386.748929                   0.877425                   0.007960
#
#                                               subject
# 0   0027221_session_2_anat_2_Tag_pr100_sr100_ppf10...
# 1   0027222_session_1_anat_2_Tag_pr100_sr100_ppf10...
# 2   0027203_session_1_anat_1_Tag_pr100_sr100_ppf10...
# 3   0027206_session_2_anat_1_Tag_pr100_sr100_ppf10...
# 4   0027212_session_1_anat_2_Tag_pr100_sr100_ppf10...
# ..                                                ...
# 87  0027220_session_2_anat_1_Tag_pr100_sr100_ppf10...
# 88  0027210_session_1_anat_1_Tag_pr100_sr100_ppf10...
# 89  0027215_session_1_anat_2_Tag_pr100_sr100_ppf10...
# 90  0027215_session_2_anat_1_Tag_pr100_sr100_ppf10...
# 91  0027203_session_2_anat_2_Tag_pr100_sr100_ppf10...
#
# [92 rows x 144 columns]

# %%
df['subject'] = df['subject'].str.replace('_Tag_pr100_sr100_ppf100_spf100_ipf100_sipf143', '')

# %%
df
# Out:
#     total_intracranial_volume       unknown  left_cerebral_white_matter  \
# 0                1.491553e+06  1.437847e+07               228959.691303
# 1                1.605587e+06  1.426443e+07               231578.839169
# 2                1.562897e+06  1.430712e+07               254840.754980
# 3                1.394619e+06  1.447540e+07               219874.307767
# 4                1.499385e+06  1.437063e+07               227979.054353
# ..                        ...           ...                         ...
# 87               1.545878e+06  1.432414e+07               228019.871351
# 88               1.510856e+06  1.435916e+07               219403.025791
# 89               1.311555e+06  1.455846e+07               189739.701306
# 90               1.316961e+06  1.455306e+07               188719.962358
# 91               1.561950e+06  1.430807e+07               254559.151995
#
#     left_lateral_ventricle  left_inf_lat_vent  left_cerebellum_white_matter  \
# 0              6047.775691         533.021973                  13579.712306
# 1              7208.144632         646.554967                  15415.791212
# 2              3768.540807         476.426976                  16953.117134
# 3              3622.765815         397.193980                  14112.048279
# 4              4530.343769         924.727953                  13149.247328
# ..                     ...                ...                           ...
# 87             6288.218679         796.445959                  15404.129213
# 88             8430.596569         356.719982                  13882.924291
# 89             3664.611813         577.268971                  14325.051268
# 90             3643.002814         574.867971                  14495.522259
# 91             3744.187809         502.151974                  16900.638137
#
#     left_cerebellum_cortex  left_thalamus  left_caudate  left_putamen  ...  \
# 0             57680.249053    9353.952522   3530.841820   5551.797716  ...
# 1             59855.554942    8980.768541   3789.120806   6437.423671  ...
# 2             58847.820993    9972.381491   3826.850804   5503.777719  ...
# 3             52332.879326    9134.775533   3359.684828   5333.992727  ...
# 4             51317.256378    9420.837519   3508.546821   5645.436712  ...
# ..                     ...            ...           ...           ...  ...
# 87            58872.173992    8658.691558   3958.905798   5358.688726  ...
# 88            50876.158401    8162.713583   3048.926844   4686.751761  ...
# 89            54601.138210    8448.432568   3275.992833   5180.328735  ...
# 90            54326.395224    8385.663572   3306.862831   5238.295732  ...
# 91            58177.599028   10004.623489   3823.420805   5496.231719  ...
#
#        cerebellum  cerebellum_white_matter  cerebellum_cortex  \
# 0   141950.542748             26640.122639      115310.420109
# 1   152043.660232             30363.387449      121680.272783
# 2   150253.543324             33036.729312      117216.814011
# 3   132186.019247             27829.303578      104356.715668
# 4   127885.485466             26116.361666      101769.123801
# ..            ...                      ...                ...
# 87  147704.367454             30475.205443      117229.162011
# 88  128631.510428             27067.500617      101564.009811
# 89  136435.789030             27728.804583      108706.984446
# 90  136187.114042             27941.464572      108245.649470
# 91  149128.503381             32728.029328      116400.474053
#
#     lateral_ventricle  inf_lat_vent  total_lateral_ventricle  \
# 0        10541.418461    915.466953             11456.885415
# 1        14813.826243   1264.297935             16078.124179
# 2         9559.066512   1270.814935             10829.881447
# 3         6748.181655    796.445959              7544.627615
# 4         7271.599628   1370.627930              8642.227558
# ..                ...           ...                      ...
# 87       14201.914274   1386.748929             15588.663204
# 88       14674.911250    831.088958             15506.000208
# 89        7437.954620   1022.825948              8460.780568
# 90        7424.234621   1039.975947              8464.210568
# 91        9507.959514   1304.428933             10812.388448
#
#     wm_hypointensities  HippocampusOccupancyScore  HippocampusAsymmetryIndex  \
# 0          1107.889943                   0.902688                   0.009746
# 1          1024.197948                   0.873138                   0.033573
# 2          1361.366930                   0.881496                   0.012642
# 3          1208.045938                   0.911262                   0.019369
# 4          1071.874945                   0.845898                   0.094129
# ..                 ...                        ...                        ...
# 87          925.756953                   0.845056                   0.012950
# 88          869.161956                   0.902210                   0.042133
# 89          984.409950                   0.885830                   0.007313
# 90          969.317950                   0.884677                   0.006196
# 91         1386.748929                   0.877425                   0.007960
#
#                      subject
# 0   0027221_session_2_anat_2
# 1   0027222_session_1_anat_2
# 2   0027203_session_1_anat_1
# 3   0027206_session_2_anat_1
# 4   0027212_session_1_anat_2
# ..                       ...
# 87  0027220_session_2_anat_1
# 88  0027210_session_1_anat_1
# 89  0027215_session_1_anat_2
# 90  0027215_session_2_anat_1
# 91  0027203_session_2_anat_2
#
# [92 rows x 144 columns]

# %%
root_path1 = "/home/limseoyoung/drwelly1/SeoyoungLim/drwelly-debug/drwelly_simence_SWU3_before"
volumes_files = find_volumes_files(root_path1)
df1 = compile_data(volumes_files)

# %%
df1['subject'] = df1['subject'].str.replace('_Tag_pr100_sr100_ppf100_spf100_ipf100_sipf143', '')

# %%
df1
# Out:
#     total_intracranial_volume       unknown  left_cerebral_white_matter  \
# 0                1.555781e+06  1.431424e+07               231259.849185
# 1                1.851387e+06  1.401863e+07               261932.965618
# 2                1.617235e+06  1.425278e+07               236451.153920
# 3                1.749064e+06  1.412095e+07               253498.253049
# 4                1.851387e+06  1.401863e+07               261932.965618
# 5                1.455643e+06  1.441438e+07               227633.996370
# 6                1.748305e+06  1.412171e+07               253411.817053
# 7                1.455643e+06  1.441438e+07               227633.996370
# 8                1.387557e+06  1.448246e+07               206279.846461
# 9                1.572097e+06  1.429792e+07               247099.588376
# 10               1.574003e+06  1.429602e+07               224315.814540
# 11               1.332069e+06  1.453795e+07               199030.198832
# 12               1.721223e+06  1.414880e+07               256393.858901
# 13               1.555247e+06  1.431477e+07               230705.218213
# 14               1.552798e+06  1.431722e+07               230774.161210
# 15               1.388957e+06  1.448106e+07               206165.284467
# 16               1.521924e+06  1.434810e+07               238637.778808
# 17               1.521924e+06  1.434810e+07               238637.778808
# 18               1.721223e+06  1.414880e+07               256393.858901
# 19               1.413086e+06  1.445693e+07               190769.730254
# 20               1.456593e+06  1.441343e+07               219945.308763
# 21               1.617235e+06  1.425278e+07               236451.153920
# 22               1.535970e+06  1.433405e+07               235965.808945
#
#     left_lateral_ventricle  left_inf_lat_vent  left_cerebellum_white_matter  \
# 0              9335.773523         589.273970                  13010.675335
# 1             33657.216280        1598.722918                  15522.121207
# 2              5439.979722         649.984967                  14921.871238
# 3             18706.190044         557.031972                  15947.098185
# 4             33657.216280        1598.722918                  15522.121207
# 5              6938.203646         404.396979                  15728.950196
# 6             18841.332037         569.036971                  15843.169191
# 7              6938.203646         404.396979                  15728.950196
# 8              3557.938818         323.448983                  13496.363310
# 9              4882.604751         706.922964                  14369.298266
# 10             9593.709510         779.295960                  12324.675370
# 11             5475.308720         394.106980                  12328.448370
# 12             8252.922578         326.878983                  15515.947207
# 13             9361.841522         576.925971                  13158.165328
# 14             6313.943677         819.083958                  15377.718214
# 15             3555.880818         287.776985                  13831.131293
# 16             9283.637526         493.576975                  12112.358381
# 17             9283.637526         493.576975                  12112.358381
# 18             8252.922578         326.878983                  15515.947207
# 19             7094.268638         380.729981                  14176.875276
# 20             5519.212718         748.082962                  13820.841294
# 21             5439.979722         649.984967                  14921.871238
# 22             5622.112713         464.421976                  15502.570208
#
#     left_cerebellum_cortex  left_thalamus  left_caudate  left_putamen  ...  \
# 0             57680.935053    8605.183560   3957.533798   5716.094708  ...
# 1             63163.446773   10013.541488   4031.621794   6052.234691  ...
# 2             60197.182925    8412.760570   4101.936790   6078.302689  ...
# 3             67228.682565    9508.302514   4625.011764   5557.971716  ...
# 4             63163.446773   10013.541488   4031.621794   6052.234691  ...
# 5             54735.251204    9322.739524   4344.437778   5704.432709  ...
# 6             67539.097549    9529.568513   4610.262764   5556.256716  ...
# 7             54735.251204    9322.739524   4344.437778   5704.432709  ...
# 8             55355.738172    8260.468578   3993.205796   5448.897722  ...
# 9             52890.254298    9192.399530   3949.644798   6529.004666  ...
# 10            54223.495230    8325.981575   3963.021798   5683.852710  ...
# 11            49572.758467    7918.154595   3568.914818   4856.879752  ...
# 12            57819.850046   10323.270473   3726.694810   5677.678710  ...
# 13            57432.946066    8559.907563   3960.277798   5755.196706  ...
# 14            59051.562983    8670.696557   4017.558795   5245.841732  ...
# 15            54902.635195    8254.294578   4047.399793   5396.761724  ...
# 16            49820.404455    8398.697571   3331.215830   4996.823745  ...
# 17            49820.404455    8398.697571   3331.215830   4996.823745  ...
# 18            57819.850046   10323.270473   3726.694810   5677.678710  ...
# 19            57011.056087    8430.939569   3590.866817   5101.781739  ...
# 20            49484.950472    8691.619556   4232.619784   5729.128707  ...
# 21            60197.182925    8412.760570   4101.936790   6078.302689  ...
# 22            61594.221853    9449.306517   3728.066810   5977.117695  ...
#
#        cerebellum  cerebellum_white_matter  cerebellum_cortex  \
# 0   140102.458842             25888.952677      114213.506165
# 1   157197.920969             30215.554456      126982.366513
# 2   151350.114268             29112.809513      122237.304755
# 3   167563.037439             31227.747405      136335.290035
# 4   157197.920969             30215.554456      126982.366513
# 5   140230.054836             30786.992427      109443.062409
# 6   167902.950422             31125.876410      136777.074012
# 7   140230.054836             30786.992427      109443.062409
# 8   137914.461954             26661.388638      111253.073316
# 9   138172.054941             28708.755533      109463.299408
# 10  133317.576189             23931.451777      109386.124411
# 11  123011.112715             24388.670754       98622.441961
# 12  148031.589437             30389.455447      117642.133990
# 13  140187.865838             26275.170658      113912.695180
# 14  147569.911461             30378.479448      117191.432013
# 15  137702.487965             27195.096611      110507.391354
# 16  122716.475730             23958.891776       98757.583955
# 17  122716.475730             23958.891776       98757.583955
# 18  148031.589437             30389.455447      117642.133990
# 19  143205.922684             27951.754572      115254.168112
# 20  125173.727605             26761.544633       98412.182972
# 21  151350.114268             29112.809513      122237.304755
# 22  152592.803204             29989.517468      122603.285736
#
#     lateral_ventricle  inf_lat_vent  total_lateral_ventricle  \
# 0        17519.067105   1025.569948             18544.637053
# 1        56993.220088   3015.998846             60009.218934
# 2        10433.030467   1206.330938             11639.361405
# 3        41261.525892   1619.645917             42881.171809
# 4        56993.220088   3015.998846             60009.218934
# 5        12398.077367    721.328963             13119.406330
# 6        41535.925878   1612.442918             43148.368796
# 7        12398.077367    721.328963             13119.406330
# 8         7098.727637    625.974968              7724.702605
# 9         9589.936510   1289.679934             10879.616444
# 10       16577.532153   1283.162934             17860.695088
# 11       11187.287428    706.236964             11893.524392
# 12       16249.281170    724.758963             16974.040133
# 13       17570.860102   1024.540948             18595.401050
# 14       14236.557273   1489.991924             15726.549197
# 15        7053.794640    571.094971              7624.889610
# 16       16483.893158    843.093957             17326.987115
# 17       16483.893158    843.093957             17326.987115
# 18       16249.281170    724.758963             16974.040133
# 19       13489.160311    738.821962             14227.982273
# 20       10765.397450   1169.286940             11934.684390
# 21       10433.030467   1206.330938             11639.361405
# 22        9733.310503    868.132956             10601.443458
#
#     wm_hypointensities  HippocampusOccupancyScore  HippocampusAsymmetryIndex  \
# 0           954.225951                   0.888589                   0.037663
# 1          1676.583914                   0.750872                   0.035166
# 2          1039.289947                   0.881035                   0.024770
# 3          1088.338944                   0.835685                   0.005074
# 4          1676.583914                   0.750872                   0.035166
# 5           720.642963                   0.918845                   0.044002
# 6          1092.111944                   0.837278                   0.002641
# 7           720.642963                   0.918845                   0.044002
# 8          1268.756935                   0.934297                   0.039397
# 9          1373.028930                   0.877968                   0.017626
# 10          848.924957                   0.870939                   0.028028
# 11         1143.904942                   0.912828                   0.005436
# 12          836.919957                   0.924550                   0.048132
# 13          942.906952                   0.889340                   0.041414
# 14          943.249952                   0.835380                   0.016789
# 15         1222.794938                   0.939849                   0.038376
# 16         1054.381946                   0.908638                   0.029103
# 17         1054.381946                   0.908638                   0.029103
# 18          836.919957                   0.924550                   0.048132
# 19          761.116961                   0.914982                   0.041050
# 20          680.854965                   0.869668                   0.038546
# 21         1039.289947                   0.881035                   0.024770
# 22         1284.534934                   0.905069                   0.034679
#
#                      subject
# 0   0027154_session_1_anat_1
# 1   0027171_session_1_anat_1
# 2   0027174_session_2_anat_1
# 3   0027157_session_2_anat_1
# 4   0027171_session_2_anat_1
# 5   0027164_session_1_anat_1
# 6   0027157_session_1_anat_1
# 7   0027164_session_2_anat_1
# 8   0027156_session_1_anat_1
# 9   0027160_session_1_anat_1
# 10  0027172_session_1_anat_1
# 11  0027152_session_1_anat_1
# 12  0027165_session_1_anat_1
# 13  0027154_session_2_anat_1
# 14  0027170_session_1_anat_1
# 15  0027156_session_2_anat_1
# 16  0027161_session_2_anat_1
# 17  0027161_session_1_anat_1
# 18  0027165_session_2_anat_1
# 19  0027158_session_1_anat_1
# 20  0027169_session_1_anat_1
# 21  0027174_session_1_anat_1
# 22  0027173_session_2_anat_1
#
# [23 rows x 144 columns]

# %%
combined_df = pd.concat([df, df1], ignore_index=True)

# %%
combined_df
# Out:
#      total_intracranial_volume       unknown  left_cerebral_white_matter  \
# 0                 1.491553e+06  1.437847e+07               228959.691303
# 1                 1.605587e+06  1.426443e+07               231578.839169
# 2                 1.562897e+06  1.430712e+07               254840.754980
# 3                 1.394619e+06  1.447540e+07               219874.307767
# 4                 1.499385e+06  1.437063e+07               227979.054353
# ..                         ...           ...                         ...
# 110               1.721223e+06  1.414880e+07               256393.858901
# 111               1.413086e+06  1.445693e+07               190769.730254
# 112               1.456593e+06  1.441343e+07               219945.308763
# 113               1.617235e+06  1.425278e+07               236451.153920
# 114               1.535970e+06  1.433405e+07               235965.808945
#
#      left_lateral_ventricle  left_inf_lat_vent  left_cerebellum_white_matter  \
# 0               6047.775691         533.021973                  13579.712306
# 1               7208.144632         646.554967                  15415.791212
# 2               3768.540807         476.426976                  16953.117134
# 3               3622.765815         397.193980                  14112.048279
# 4               4530.343769         924.727953                  13149.247328
# ..                      ...                ...                           ...
# 110             8252.922578         326.878983                  15515.947207
# 111             7094.268638         380.729981                  14176.875276
# 112             5519.212718         748.082962                  13820.841294
# 113             5439.979722         649.984967                  14921.871238
# 114             5622.112713         464.421976                  15502.570208
#
#      left_cerebellum_cortex  left_thalamus  left_caudate  left_putamen  ...  \
# 0              57680.249053    9353.952522   3530.841820   5551.797716  ...
# 1              59855.554942    8980.768541   3789.120806   6437.423671  ...
# 2              58847.820993    9972.381491   3826.850804   5503.777719  ...
# 3              52332.879326    9134.775533   3359.684828   5333.992727  ...
# 4              51317.256378    9420.837519   3508.546821   5645.436712  ...
# ..                      ...            ...           ...           ...  ...
# 110            57819.850046   10323.270473   3726.694810   5677.678710  ...
# 111            57011.056087    8430.939569   3590.866817   5101.781739  ...
# 112            49484.950472    8691.619556   4232.619784   5729.128707  ...
# 113            60197.182925    8412.760570   4101.936790   6078.302689  ...
# 114            61594.221853    9449.306517   3728.066810   5977.117695  ...
#
#         cerebellum  cerebellum_white_matter  cerebellum_cortex  \
# 0    141950.542748             26640.122639      115310.420109
# 1    152043.660232             30363.387449      121680.272783
# 2    150253.543324             33036.729312      117216.814011
# 3    132186.019247             27829.303578      104356.715668
# 4    127885.485466             26116.361666      101769.123801
# ..             ...                      ...                ...
# 110  148031.589437             30389.455447      117642.133990
# 111  143205.922684             27951.754572      115254.168112
# 112  125173.727605             26761.544633       98412.182972
# 113  151350.114268             29112.809513      122237.304755
# 114  152592.803204             29989.517468      122603.285736
#
#      lateral_ventricle  inf_lat_vent  total_lateral_ventricle  \
# 0         10541.418461    915.466953             11456.885415
# 1         14813.826243   1264.297935             16078.124179
# 2          9559.066512   1270.814935             10829.881447
# 3          6748.181655    796.445959              7544.627615
# 4          7271.599628   1370.627930              8642.227558
# ..                 ...           ...                      ...
# 110       16249.281170    724.758963             16974.040133
# 111       13489.160311    738.821962             14227.982273
# 112       10765.397450   1169.286940             11934.684390
# 113       10433.030467   1206.330938             11639.361405
# 114        9733.310503    868.132956             10601.443458
#
#      wm_hypointensities  HippocampusOccupancyScore  HippocampusAsymmetryIndex  \
# 0           1107.889943                   0.902688                   0.009746
# 1           1024.197948                   0.873138                   0.033573
# 2           1361.366930                   0.881496                   0.012642
# 3           1208.045938                   0.911262                   0.019369
# 4           1071.874945                   0.845898                   0.094129
# ..                  ...                        ...                        ...
# 110          836.919957                   0.924550                   0.048132
# 111          761.116961                   0.914982                   0.041050
# 112          680.854965                   0.869668                   0.038546
# 113         1039.289947                   0.881035                   0.024770
# 114         1284.534934                   0.905069                   0.034679
#
#                       subject
# 0    0027221_session_2_anat_2
# 1    0027222_session_1_anat_2
# 2    0027203_session_1_anat_1
# 3    0027206_session_2_anat_1
# 4    0027212_session_1_anat_2
# ..                        ...
# 110  0027165_session_2_anat_1
# 111  0027158_session_1_anat_1
# 112  0027169_session_1_anat_1
# 113  0027174_session_1_anat_1
# 114  0027173_session_2_anat_1
#
# [115 rows x 144 columns]

# %%
columns_to_include = [
   'whole_brain',	'cortical_gm',	'combined_cerebral_wm',	'frontal','temporal','parietal'	,'occipital','insula'	,'thalamus'	,'caudate','putamen','pallidum','hippocampus','amygdala', 'accumbens_area'	, 'ventraldc' ,'cingulate' ,'cerebellum', 'cerebellum_white_matter' ,'cerebellum_cortex','lateral_ventricle', 'inf_lat_vent',	'total_lateral_ventricle', 	'HippocampusOccupancyScore',	
    'subject'  # 'subject' 컬럼 추가
]

final_df = combined_df[columns_to_include].copy()

# %%
final_df
# Out:
#       whole_brain    cortical_gm  combined_cerebral_wm        frontal  \
# 0    1.178102e+06  502398.591333         461040.339446  178822.697864
# 1    1.225951e+06  533876.385724         464113.962289  191769.918203
# 2    1.283321e+06  546539.602077         511007.204893  188784.446355
# 3    1.145587e+06  505091.827195         439413.161551  182331.587685
# 4    1.208249e+06  557485.074518         453120.126850  198892.312839
# ..            ...            ...                   ...            ...
# 110  1.344219e+06  608230.892926         511909.980847  206114.520470
# 111  1.086556e+06  493566.341784         382657.640450  170188.359305
# 112  1.180632e+06  544917.212160         441685.193434  191155.262234
# 113  1.297593e+06  597096.770495         475059.434729  220788.059720
# 114  1.247746e+06  551452.390826         470576.767958  193378.931120
#
#           temporal       parietal     occipital        insula      thalamus  \
# 0    130740.617321  105753.411597  48534.154520  12768.174348  18503.477055
# 1    135334.073086  109325.413415  56681.433104  13823.928294  17439.148109
# 2    138072.241946  125334.251597  53922.341245  13641.452303  19168.554021
# 3    123082.113712  116703.000038  44651.737719  12319.187371  17407.935111
# 4    134777.384114  131292.161292  50301.633430  13529.291309  18546.352052
# ..             ...            ...           ...           ...           ...
# 110  149594.297357  143978.358644  62230.486821  15254.581221  19959.168980
# 111  130717.636322  109350.795413  47682.142564  12079.773383  16276.378168
# 112  141748.515758  125408.339593  46420.588628  14479.401260  16957.233134
# 113  145436.451570  128929.234413  57703.230052  15736.153196  16346.693165
# 114  138509.909924  129733.569372  46379.428630  14185.793275  18418.413059
#
#          caudate  ...    ventraldc     cingulate     cerebellum  \
# 0    7062.026639  ...  9241.105528  25779.535683  141950.542748
# 1    7753.171604  ...  9373.160521  26941.619624  152043.660232
# 2    7984.696592  ...  9340.232523  26784.868632  150253.543324
# 3    6801.346653  ...  8647.372558  26004.200671  132186.019247
# 4    7055.852640  ...  8677.556557  28692.291534  127885.485466
# ..           ...  ...          ...           ...            ...
# 110  7558.690614  ...  9406.774519  31058.648413  148031.589437
# 111  7208.830632  ...  8297.512576  23547.634797  143205.922684
# 112  8322.208575  ...  8127.041585  25705.104687  125173.727605
# 113  8241.946579  ...  9233.902528  28503.641544  151350.114268
# 114  7474.312618  ...  8915.598545  29264.758505  152592.803204
#
#      cerebellum_white_matter  cerebellum_cortex  lateral_ventricle  \
# 0               26640.122639      115310.420109       10541.418461
# 1               30363.387449      121680.272783       14813.826243
# 2               33036.729312      117216.814011        9559.066512
# 3               27829.303578      104356.715668        6748.181655
# 4               26116.361666      101769.123801        7271.599628
# ..                       ...                ...                ...
# 110             30389.455447      117642.133990       16249.281170
# 111             27951.754572      115254.168112       13489.160311
# 112             26761.544633       98412.182972       10765.397450
# 113             29112.809513      122237.304755       10433.030467
# 114             29989.517468      122603.285736        9733.310503
#
#      inf_lat_vent  total_lateral_ventricle  HippocampusOccupancyScore  \
# 0      915.466953             11456.885415                   0.902688
# 1     1264.297935             16078.124179                   0.873138
# 2     1270.814935             10829.881447                   0.881496
# 3      796.445959              7544.627615                   0.911262
# 4     1370.627930              8642.227558                   0.845898
# ..            ...                      ...                        ...
# 110    724.758963             16974.040133                   0.924550
# 111    738.821962             14227.982273                   0.914982
# 112   1169.286940             11934.684390                   0.869668
# 113   1206.330938             11639.361405                   0.881035
# 114    868.132956             10601.443458                   0.905069
#
#                       subject
# 0    0027221_session_2_anat_2
# 1    0027222_session_1_anat_2
# 2    0027203_session_1_anat_1
# 3    0027206_session_2_anat_1
# 4    0027212_session_1_anat_2
# ..                        ...
# 110  0027165_session_2_anat_1
# 111  0027158_session_1_anat_1
# 112  0027169_session_1_anat_1
# 113  0027174_session_1_anat_1
# 114  0027173_session_2_anat_1
#
# [115 rows x 25 columns]

# %%
sesson1 = final_df[final_df['subject'].str.contains('anat_1')]
sesson2 = final_df[final_df['subject'].str.contains('anat_2')]

# %%
lut_path = '/mnt/drwelly1/Team_Planning/Brain_Volumetry/Algorithms/freesurfer/FreeSurferColorLUT.txt'
# labeling 불러오면됨

# %%
def load_freesurfer_lut(lut_path):
    lut = {}
    with open(lut_path, 'r') as file:
        for line in file:
            if line.strip() and not line.startswith('#'):
                parts = line.split()
                if parts[0].isdigit():
                    lut[int(parts[0])] = ' '.join(parts[1:])
    return lut

freesurfer_lut = load_freesurfer_lut(lut_path)

# %%
def extract_number(subj):
    parts = subj.split('_')  # '_'를 기준
    if len(parts) > 1:
        number_part = parts[1]  
        # 숫자만 
        numbers = ''.join(filter(str.isdigit, number_part))
        return int(numbers) if numbers.isdigit() else None
    return None

# %%
sesson1['sort_key'] = sesson1['subject'].apply(extract_number) 
volume_df_sorted1 = sesson1.sort_values(by='sort_key').drop(columns=['sort_key'])
# Out:
# /tmp/ipykernel_3256894/2792317927.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sesson1['sort_key'] = sesson1['subject'].apply(extract_number)

# %%
sesson2['sort_key'] = sesson2['subject'].apply(extract_number)
volume_df_sorted2 = sesson2.sort_values(by='sort_key').drop(columns=['sort_key'])
# Out:
# /tmp/ipykernel_3256894/1960010514.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sesson2['sort_key'] = sesson2['subject'].apply(extract_number)

# %%
all_data = pd.concat([volume_df_sorted1,volume_df_sorted2])
all_data_long = pd.melt(all_data, id_vars=["subject"], var_name="ROI", value_name="Volume")

# %%
all_data_long['Session'] = all_data_long['subject'].str.extract(r'(anat_\d+)')


all_data_long['ROI'] = all_data_long['ROI'].str.extract(r'([a-zA-Z-_]+)')[0]

# %%
all_data_long['Subject_ID'] = all_data_long['subject'].str.extract(r'(\d+_session_\d+)')

# %%
re_long = all_data_long.dropna(subset=['Volume'])


grouped = re_long.groupby(['Subject_ID', 'ROI'])['Volume'].agg(['mean', 'var', 'std']).reset_index()

# %%
grouped['CV'] = grouped['std'] / grouped['mean']

# %%
roi_mean_cv = grouped.groupby('ROI')['CV'].mean().reset_index()
roi_mean_cv.rename(columns={'CV': 'Mean_CV'}, inplace=True)

roi_mean_cv
# Out:
#                           ROI   Mean_CV
# 0   HippocampusOccupancyScore  0.002405
# 1              accumbens_area  0.011688
# 2                    amygdala  0.008779
# 3                     caudate  0.003441
# 4                  cerebellum  0.002129
# 5           cerebellum_cortex  0.002506
# 6     cerebellum_white_matter  0.005542
# 7                   cingulate  0.003381
# 8        combined_cerebral_wm  0.001625
# 9                 cortical_gm  0.002640
# 10                    frontal  0.003121
# 11                hippocampus  0.003385
# 12               inf_lat_vent  0.021133
# 13                     insula  0.003797
# 14          lateral_ventricle  0.006947
# 15                  occipital  0.005194
# 16                   pallidum  0.007082
# 17                   parietal  0.003320
# 18                    putamen  0.003767
# 19                   temporal  0.002904
# 20                   thalamus  0.002992
# 21    total_lateral_ventricle  0.007298
# 22                  ventraldc  0.005100
# 23                whole_brain  0.001499

# %%
grouped
# Out:
#              Subject_ID                        ROI          mean  \
# 0     0027152_session_1  HippocampusOccupancyScore  9.128282e-01
# 1     0027152_session_1             accumbens_area  8.821960e+02
# 2     0027152_session_1                   amygdala  3.212881e+03
# 3     0027152_session_1                    caudate  7.162526e+03
# 4     0027152_session_1                 cerebellum  1.230111e+05
# ...                 ...                        ...           ...
# 1699  0027222_session_3                   temporal  1.349940e+05
# 1700  0027222_session_3                   thalamus  1.738050e+04
# 1701  0027222_session_3    total_lateral_ventricle  1.597042e+04
# 1702  0027222_session_3                  ventraldc  9.381221e+03
# 1703  0027222_session_3                whole_brain  1.225785e+06
#
#                 var         std        CV
# 0               NaN         NaN       NaN
# 1               NaN         NaN       NaN
# 2               NaN         NaN       NaN
# 3               NaN         NaN       NaN
# 4               NaN         NaN       NaN
# ...             ...         ...       ...
# 1699  216624.787410  465.429680  0.003448
# 1700      76.236544    8.731354  0.000502
# 1701      11.529601    3.395527  0.000213
# 1702       9.941339    3.152989  0.000336
# 1703  273436.013093  522.911095  0.000427
#
# [1704 rows x 6 columns]

# %%
grouped
# Out:
#              Subject_ID                        ROI          mean  \
# 0     0027152_session_1  HippocampusOccupancyScore  9.128282e-01
# 1     0027152_session_1             accumbens_area  8.821960e+02
# 2     0027152_session_1                   amygdala  3.212881e+03
# 3     0027152_session_1                    caudate  7.162526e+03
# 4     0027152_session_1                 cerebellum  1.230111e+05
# ...                 ...                        ...           ...
# 1699  0027222_session_3                   temporal  1.349940e+05
# 1700  0027222_session_3                   thalamus  1.738050e+04
# 1701  0027222_session_3    total_lateral_ventricle  1.597042e+04
# 1702  0027222_session_3                  ventraldc  9.381221e+03
# 1703  0027222_session_3                whole_brain  1.225785e+06
#
#                 var         std        CV
# 0               NaN         NaN       NaN
# 1               NaN         NaN       NaN
# 2               NaN         NaN       NaN
# 3               NaN         NaN       NaN
# 4               NaN         NaN       NaN
# ...             ...         ...       ...
# 1699  216624.787410  465.429680  0.003448
# 1700      76.236544    8.731354  0.000502
# 1701      11.529601    3.395527  0.000213
# 1702       9.941339    3.152989  0.000336
# 1703  273436.013093  522.911095  0.000427
#
# [1704 rows x 6 columns]

# %%
grouped = grouped.dropna()
grouped
# Out:
#              Subject_ID                        ROI          mean  \
# 552   0027203_session_1  HippocampusOccupancyScore  8.801692e-01
# 553   0027203_session_1             accumbens_area  1.012536e+03
# 554   0027203_session_1                   amygdala  3.629797e+03
# 555   0027203_session_1                    caudate  7.996359e+03
# 556   0027203_session_1                 cerebellum  1.500522e+05
# ...                 ...                        ...           ...
# 1699  0027222_session_3                   temporal  1.349940e+05
# 1700  0027222_session_3                   thalamus  1.738050e+04
# 1701  0027222_session_3    total_lateral_ventricle  1.597042e+04
# 1702  0027222_session_3                  ventraldc  9.381221e+03
# 1703  0027222_session_3                whole_brain  1.225785e+06
#
#                 var         std        CV
# 552        0.000004    0.001877  0.002132
# 553      171.532224   13.097031  0.012935
# 554     1072.076403   32.742578  0.009020
# 555      272.004460   16.492558  0.002063
# 556    81076.388278  284.739158  0.001898
# ...             ...         ...       ...
# 1699  216624.787410  465.429680  0.003448
# 1700      76.236544    8.731354  0.000502
# 1701      11.529601    3.395527  0.000213
# 1702       9.941339    3.152989  0.000336
# 1703  273436.013093  522.911095  0.000427
#
# [1056 rows x 6 columns]

# %%
grouped.to_csv("drwelly_scan_repetition_before_simen.csv")
