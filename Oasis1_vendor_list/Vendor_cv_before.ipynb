# %%
combined_roi_dict = {
    'Left-Cingulate': {
        'ctx-lh-caudalanteriorcingulate',
        'ctx-lh-rostralanteriorcingulate',
        'ctx-lh-isthmuscingulate',
        'ctx-lh-posteriorcingulate',
    },
    'Right-Cingulate': {
        'ctx-rh-caudalanteriorcingulate',
        'ctx-rh-rostralanteriorcingulate',
        'ctx-rh-isthmuscingulate',
        'ctx-rh-posteriorcingulate',
    },
    'Left-Frontal': {
        'ctx-lh-caudalmiddlefrontal',
        'ctx-lh-lateralorbitofrontal',
        'ctx-lh-medialorbitofrontal',
        'ctx-lh-parsopercularis',
        'ctx-lh-parsorbitalis',
        'ctx-lh-parstriangularis',
        'ctx-lh-precentral',
        'ctx-lh-rostralmiddlefrontal',
        'ctx-lh-superiorfrontal',
        'ctx-lh-paracentral'
    },
    'Right-Frontal': {
        'ctx-rh-caudalmiddlefrontal',
        'ctx-rh-lateralorbitofrontal',
        'ctx-rh-medialorbitofrontal',
        'ctx-rh-parsopercularis',
        'ctx-rh-parsorbitalis',
        'ctx-rh-parstriangularis',
        'ctx-rh-precentral',
        'ctx-rh-rostralmiddlefrontal',
        'ctx-rh-superiorfrontal',
        'ctx-rh-paracentral'
    },
    'Left-Temporal': {
        'ctx-lh-entorhinal',
        'ctx-lh-fusiform',
        'ctx-lh-inferiortemporal',
        'ctx-lh-middletemporal',
        'ctx-lh-superiortemporal',
        'ctx-lh-transversetemporal',
        'ctx-lh-parahippocampal',
        
    },
    'Right-Temporal': {
        'ctx-rh-entorhinal',
        'ctx-rh-fusiform',
        'ctx-rh-inferiortemporal',
        'ctx-rh-middletemporal',
        'ctx-rh-superiortemporal',
        'ctx-rh-transversetemporal',
        'ctx-rh-parahippocampal',
     
    },
    'Left-Parietal': {
        'ctx-lh-inferiorparietal',
        'ctx-lh-postcentral',
        'ctx-lh-superiorparietal',
        'ctx-lh-supramarginal',
        'ctx-lh-precuneus'
    },
    'Right-Parietal': {
        'ctx-rh-inferiorparietal',
        'ctx-rh-postcentral',
        'ctx-rh-superiorparietal',
        'ctx-rh-supramarginal',
        'ctx-rh-precuneus'
    },
    'Left-Occipital': {
        'ctx-lh-cuneus',
        'ctx-lh-lateraloccipital',
        'ctx-lh-lingual',
        'ctx-lh-pericalcarine'
    },
    'Right-Occipital': {
        'ctx-rh-cuneus',
        'ctx-rh-lateraloccipital',
        'ctx-rh-lingual',
        'ctx-rh-pericalcarine'
    },
    'Left-Insula':{
        'ctx-lh-insula'
    },
    'Right-Insula': {
        'ctx-rh-insula'
    },
    'Left-Cerebellum':{
        'Left-Cerebellum-White-Matter',
        'Left-Cerebellum-Cortex'
    },
    'Right-Cerebellum': {
        'Right-Cerebellum-White-Matter',
        'Right-Cerebellum-Cortex'
    },
    'Left-Combined-Cerebral-WM': {
        'Left-Cerebral-White-Matter',
        'Left-WM-hypointensities'
    },
    'Right-Combined-Cerebral-WM': {
        'Right-Cerebral-White-Matter',
        'Right-WM-hypointensities'
    },
    'Left-Total-Lateral-Ventricle': {
        'Left-Lateral-Ventricle',
        'Left-Inf-Lat-Vent'
    },
    'Right-Total-Lateral-Ventricle': {
        'Right-Lateral-Ventricle',
        'Right-Inf-Lat-Vent'
    },
}
gray_matter_index = {
    'left_cortical_gm': {
        'left_cingulate',
        'left_frontal',
        'left_temporal',
        'left_parietal',
        'left_occipital',
        'left_insula'
    },
    'right_cortical_gm': {
        'right_cingulate',
        'right_frontal',
        'right_temporal',
        'right_parietal',
        'right_occipital',
        'right_insula'
    }
}

combined_roi_display_dict = {
    'Left-Cingulate': {
        'ctx-lh-caudalanteriorcingulate',
        'ctx-lh-rostralanteriorcingulate',
        'ctx-lh-isthmuscingulate',
        'ctx-lh-posteriorcingulate',
    },
    'Right-Cingulate': {
        'ctx-rh-caudalanteriorcingulate',
        'ctx-rh-rostralanteriorcingulate',
        'ctx-rh-isthmuscingulate',
        'ctx-rh-posteriorcingulate',
    },
    'Left-Frontal': {
        'ctx-lh-caudalmiddlefrontal',
        'ctx-lh-lateralorbitofrontal',
        'ctx-lh-medialorbitofrontal',
        'ctx-lh-parsopercularis',
        'ctx-lh-parsorbitalis',
        'ctx-lh-parstriangularis',
        'ctx-lh-precentral',
        'ctx-lh-rostralmiddlefrontal',
        'ctx-lh-superiorfrontal',
        'ctx-lh-paracentral'
    },
    'Right-Frontal': {
        'ctx-rh-caudalmiddlefrontal',
        'ctx-rh-lateralorbitofrontal',
        'ctx-rh-medialorbitofrontal',
        'ctx-rh-parsopercularis',
        'ctx-rh-parsorbitalis',
        'ctx-rh-parstriangularis',
        'ctx-rh-precentral',
        'ctx-rh-rostralmiddlefrontal',
        'ctx-rh-superiorfrontal',
        'ctx-rh-paracentral'
    },
    'Left-Temporal': {
        'ctx-lh-entorhinal',
        'ctx-lh-fusiform',
        'ctx-lh-inferiortemporal',
        'ctx-lh-middletemporal',
        'ctx-lh-superiortemporal',
        'ctx-lh-transversetemporal',
        'ctx-lh-parahippocampal',
    },
    'Right-Temporal': {
        'ctx-rh-entorhinal',
        'ctx-rh-fusiform',
        'ctx-rh-inferiortemporal',
        'ctx-rh-middletemporal',
        'ctx-rh-superiortemporal',
        'ctx-rh-transversetemporal',
        'ctx-rh-parahippocampal',
    },
    'Left-Parietal': {
        'ctx-lh-inferiorparietal',
        'ctx-lh-postcentral',
        'ctx-lh-superiorparietal',
        'ctx-lh-supramarginal',
        'ctx-lh-precuneus'
    },
    'Right-Parietal': {
        'ctx-rh-inferiorparietal',
        'ctx-rh-postcentral',
        'ctx-rh-superiorparietal',
        'ctx-rh-supramarginal',
        'ctx-rh-precuneus'
    },
    'Left-Occipital': {
        'ctx-lh-cuneus',
        'ctx-lh-lateraloccipital',
        'ctx-lh-lingual',
        'ctx-lh-pericalcarine'
    },
    'Right-Occipital': {
        'ctx-rh-cuneus',
        'ctx-rh-lateraloccipital',
        'ctx-rh-lingual',
        'ctx-rh-pericalcarine'
    },
    'Left-Insula':{
        'ctx-lh-insula'
    },
    'Right-Insula': {
        'ctx-rh-insula'
    },
    'Left-Cerebellum':{
        'Left-Cerebellum-White-Matter',
        'Left-Cerebellum-Cortex'
    },
    'Right-Cerebellum': {
        'Right-Cerebellum-White-Matter',
        'Right-Cerebellum-Cortex'
    },
    'Left-Combined-Cerebral-WM': {
        'Left-Cerebral-White-Matter',
        'Left-WM-hypointensities'
    },
    'Right-Combined-Cerebral-WM': {
        'Right-Cerebral-White-Matter',
        'Right-WM-hypointensities'
    }
}

# %%
import nibabel as nib
import numpy as np
import pandas as pd
import os
import glob
# Out:
# /tmp/ipykernel_3189673/1034284564.py:3: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
# 경로만 지정!
base_dir = '/home/limseoyoung/drwelly1/Team_Planning/Brain_Volumetry/oasis_vendor_before/NII/GE/HNU'


def calculate_volume(nii_path):
    img = nib.load(nii_path) 
    data = img.get_fdata()
    header = img.header
    voxel_volume = np.prod(header.get_zooms())
    unique_elements, counts_elements = np.unique(data, return_counts=True)
    volumes = counts_elements * voxel_volume
    return dict(zip(unique_elements.astype(int), volumes))

# %%
import os
import pandas as pd



volume_data = []

for subject_dir in os.listdir(base_dir):
    full_subject_dir = os.path.join(base_dir, subject_dir)
    if not os.path.isdir(full_subject_dir) or 'FS222' not in subject_dir:
        continue
    
    double_subject_dir = os.path.join(full_subject_dir, subject_dir)
    if not os.path.isdir(double_subject_dir):
        continue
    
    mri_dir = os.path.join(double_subject_dir, 'mri')
    nii_path = os.path.join(mri_dir, 'aparc.DKTatlas+aseg.deep.nii.gz')
    
    if os.path.isfile(nii_path):
        try:
            vol_data = calculate_volume(nii_path)
            vol_data["subject"] = subject_dir
            volume_data.append(vol_data)
        except OSError as e:
            print(f"Error processing file {nii_path}, skipped  Error: {e}")
    else:
        print(f"File not found, skipped: {nii_path}")

volume_df = pd.DataFrame(volume_data)
# Out:
# File not found, skipped: /home/limseoyoung/drwelly1/Team_Planning/Brain_Volumetry/oasis_vendor_before/NII/GE/HNU/0025431_session_8_anat_1_Tag_pr100_sr100_ppf100_spf100_ipf100_sipf143_FS222/0025431_session_8_anat_1_Tag_pr100_sr100_ppf100_spf100_ipf100_sipf143_FS222/mri/aparc.DKTatlas+aseg.deep.nii.gz
# File not found, skipped: /home/limseoyoung/drwelly1/Team_Planning/Brain_Volumetry/oasis_vendor_before/NII/GE/HNU/0025428_session_2_anat_1_Tag_pr100_sr100_ppf100_spf100_ipf100_sipf143_FS222/0025428_session_2_anat_1_Tag_pr100_sr100_ppf100_spf100_ipf100_sipf143_FS222/mri/aparc.DKTatlas+aseg.deep.nii.gz
# File not found, skipped: /home/limseoyoung/drwelly1/Team_Planning/Brain_Volumetry/oasis_vendor_before/NII/GE/HNU/0025429_session_2_anat_1_Tag_pr100_sr100_ppf100_spf100_ipf100_sipf143_FS222/0025429_session_2_anat_1_Tag_pr100_sr100_ppf100_spf100_ipf100_sipf143_FS222/mri/aparc.DKTatlas+aseg.deep.nii.gz
# File not found, skipped: /home/limseoyoung/drwelly1/Team_Planning/Brain_Volumetry/oasis_vendor_before/NII/GE/HNU/0025436_session_1_anat_1_Tag_pr100_sr100_ppf100_spf100_ipf100_sipf143_FS222/0025436_session_1_anat_1_Tag_pr100_sr100_ppf100_spf100_ipf100_sipf143_FS222/mri/aparc.DKTatlas+aseg.deep.nii.gz
# File not found, skipped: /home/limseoyoung/drwelly1/Team_Planning/Brain_Volumetry/oasis_vendor_before/NII/GE/HNU/0025430_session_6_anat_1_Tag_pr100_sr100_ppf100_spf100_ipf100_sipf143_FS222/0025430_session_6_anat_1_Tag_pr100_sr100_ppf100_spf100_ipf100_sipf143_FS222/mri/aparc.DKTatlas+aseg.deep.nii.gz
# File not found, skipped: /home/limseoyoung/drwelly1/Team_Planning/Brain_Volumetry/oasis_vendor_before/NII/GE/HNU/0025433_session_8_anat_1_Tag_pr100_sr100_ppf100_spf100_ipf100_sipf143_FS222/0025433_session_8_anat_1_Tag_pr100_sr100_ppf100_spf100_ipf100_sipf143_FS222/mri/aparc.DKTatlas+aseg.deep.nii.gz
# File not found, skipped: /home/limseoyoung/drwelly1/Team_Planning/Brain_Volumetry/oasis_vendor_before/NII/GE/HNU/0025437_session_10_anat_1_Tag_pr100_sr100_ppf100_spf100_ipf100_sipf143_FS222/0025437_session_10_anat_1_Tag_pr100_sr100_ppf100_spf100_ipf100_sipf143_FS222/mri/aparc.DKTatlas+aseg.deep.nii.gz
# File not found, skipped: /home/limseoyoung/drwelly1/Team_Planning/Brain_Volumetry/oasis_vendor_before/NII/GE/HNU/0025429_session_1_anat_1_Tag_pr100_sr100_ppf100_spf100_ipf100_sipf143_FS222/0025429_session_1_anat_1_Tag_pr100_sr100_ppf100_spf100_ipf100_sipf143_FS222/mri/aparc.DKTatlas+aseg.deep.nii.gz
# File not found, skipped: /home/limseoyoung/drwelly1/Team_Planning/Brain_Volumetry/oasis_vendor_before/NII/GE/HNU/0025434_session_10_anat_1_Tag_pr100_sr100_ppf100_spf100_ipf100_sipf143_FS222/0025434_session_10_anat_1_Tag_pr100_sr100_ppf100_spf100_ipf100_sipf143_FS222/mri/aparc.DKTatlas+aseg.deep.nii.gz
# File not found, skipped: /home/limseoyoung/drwelly1/Team_Planning/Brain_Volumetry/oasis_vendor_before/NII/GE/HNU/0025436_session_7_anat_1_Tag_pr100_sr100_ppf100_spf100_ipf100_sipf143_FS222/0025436_session_7_anat_1_Tag_pr100_sr100_ppf100_spf100_ipf100_sipf143_FS222/mri/aparc.DKTatlas+aseg.deep.nii.gz
# File not found, skipped: /home/limseoyoung/drwelly1/Team_Planning/Brain_Volumetry/oasis_vendor_before/NII/GE/HNU/0025435_session_8_anat_1_Tag_pr100_sr100_ppf100_spf100_ipf100_sipf143_FS222/0025435_session_8_anat_1_Tag_pr100_sr100_ppf100_spf100_ipf100_sipf143_FS222/mri/aparc.DKTatlas+aseg.deep.nii.gz
# File not found, skipped: /home/limseoyoung/drwelly1/Team_Planning/Brain_Volumetry/oasis_vendor_before/NII/GE/HNU/0025434_session_3_anat_1_Tag_pr100_sr100_ppf100_spf100_ipf100_sipf143_FS222/0025434_session_3_anat_1_Tag_pr100_sr100_ppf100_spf100_ipf100_sipf143_FS222/mri/aparc.DKTatlas+aseg.deep.nii.gz
# File not found, skipped: /home/limseoyoung/drwelly1/Team_Planning/Brain_Volumetry/oasis_vendor_before/NII/GE/HNU/0025434_session_6_anat_1_Tag_pr100_sr100_ppf100_spf100_ipf100_sipf143_FS222/0025434_session_6_anat_1_Tag_pr100_sr100_ppf100_spf100_ipf100_sipf143_FS222/mri/aparc.DKTatlas+aseg.deep.nii.gz
# File not found, skipped: /home/limseoyoung/drwelly1/Team_Planning/Brain_Volumetry/oasis_vendor_before/NII/GE/HNU/0025430_session_10_anat_1_Tag_pr100_sr100_ppf100_spf100_ipf100_sipf143_FS222/0025430_session_10_anat_1_Tag_pr100_sr100_ppf100_spf100_ipf100_sipf143_FS222/mri/aparc.DKTatlas+aseg.deep.nii.gz
# File not found, skipped: /home/limseoyoung/drwelly1/Team_Planning/Brain_Volumetry/oasis_vendor_before/NII/GE/HNU/0025434_session_1_anat_1_Tag_pr100_sr100_ppf100_spf100_ipf100_sipf143_FS222/0025434_session_1_anat_1_Tag_pr100_sr100_ppf100_spf100_ipf100_sipf143_FS222/mri/aparc.DKTatlas+aseg.deep.nii.gz
# File not found, skipped: /home/limseoyoung/drwelly1/Team_Planning/Brain_Volumetry/oasis_vendor_before/NII/GE/HNU/0025431_session_9_anat_1_Tag_pr100_sr100_ppf100_spf100_ipf100_sipf143_FS222/0025431_session_9_anat_1_Tag_pr100_sr100_ppf100_spf100_ipf100_sipf143_FS222/mri/aparc.DKTatlas+aseg.deep.nii.gz
# File not found, skipped: /home/limseoyoung/drwelly1/Team_Planning/Brain_Volumetry/oasis_vendor_before/NII/GE/HNU/0025429_session_6_anat_1_Tag_pr100_sr100_ppf100_spf100_ipf100_sipf143_FS222/0025429_session_6_anat_1_Tag_pr100_sr100_ppf100_spf100_ipf100_sipf143_FS222/mri/aparc.DKTatlas+aseg.deep.nii.gz
# File not found, skipped: /home/limseoyoung/drwelly1/Team_Planning/Brain_Volumetry/oasis_vendor_before/NII/GE/HNU/0025428_session_8_anat_1_Tag_pr100_sr100_ppf100_spf100_ipf100_sipf143_FS222/0025428_session_8_anat_1_Tag_pr100_sr100_ppf100_spf100_ipf100_sipf143_FS222/mri/aparc.DKTatlas+aseg.deep.nii.gz
# File not found, skipped: /home/limseoyoung/drwelly1/Team_Planning/Brain_Volumetry/oasis_vendor_before/NII/GE/HNU/0025431_session_3_anat_1_Tag_pr100_sr100_ppf100_spf100_ipf100_sipf143_FS222/0025431_session_3_anat_1_Tag_pr100_sr100_ppf100_spf100_ipf100_sipf143_FS222/mri/aparc.DKTatlas+aseg.deep.nii.gz
# File not found, skipped: /home/limseoyoung/drwelly1/Team_Planning/Brain_Volumetry/oasis_vendor_before/NII/GE/HNU/0025430_session_2_anat_1_Tag_pr100_sr100_ppf100_spf100_ipf100_sipf143_FS222/0025430_session_2_anat_1_Tag_pr100_sr100_ppf100_spf100_ipf100_sipf143_FS222/mri/aparc.DKTatlas+aseg.deep.nii.gz
# File not found, skipped: /home/limseoyoung/drwelly1/Team_Planning/Brain_Volumetry/oasis_vendor_before/NII/GE/HNU/0025428_session_3_anat_1_Tag_pr100_sr100_ppf100_spf100_ipf100_sipf143_FS222/0025428_session_3_anat_1_Tag_pr100_sr100_ppf100_spf100_ipf100_sipf143_FS222/mri/aparc.DKTatlas+aseg.deep.nii.gz
# File not found, skipped: /home/limseoyoung/drwelly1/Team_Planning/Brain_Volumetry/oasis_vendor_before/NII/GE/HNU/0025429_session_4_anat_1_Tag_pr100_sr100_ppf100_spf100_ipf100_sipf143_FS222/0025429_session_4_anat_1_Tag_pr100_sr100_ppf100_spf100_ipf100_sipf143_FS222/mri/aparc.DKTatlas+aseg.deep.nii.gz
# File not found, skipped: /home/limseoyoung/drwelly1/Team_Planning/Brain_Volumetry/oasis_vendor_before/NII/GE/HNU/0025428_session_4_anat_1_Tag_pr100_sr100_ppf100_spf100_ipf100_sipf143_FS222/0025428_session_4_anat_1_Tag_pr100_sr100_ppf100_spf100_ipf100_sipf143_FS222/mri/aparc.DKTatlas+aseg.deep.nii.gz
# File not found, skipped: /home/limseoyoung/drwelly1/Team_Planning/Brain_Volumetry/oasis_vendor_before/NII/GE/HNU/0025428_session_7_anat_1_Tag_pr100_sr100_ppf100_spf100_ipf100_sipf143_FS222/0025428_session_7_anat_1_Tag_pr100_sr100_ppf100_spf100_ipf100_sipf143_FS222/mri/aparc.DKTatlas+aseg.deep.nii.gz
# File not found, skipped: /home/limseoyoung/drwelly1/Team_Planning/Brain_Volumetry/oasis_vendor_before/NII/GE/HNU/0025429_session_5_anat_1_Tag_pr100_sr100_ppf100_spf100_ipf100_sipf143_FS222/0025429_session_5_anat_1_Tag_pr100_sr100_ppf100_spf100_ipf100_sipf143_FS222/mri/aparc.DKTatlas+aseg.deep.nii.gz
# File not found, skipped: /home/limseoyoung/drwelly1/Team_Planning/Brain_Volumetry/oasis_vendor_before/NII/GE/HNU/0025437_session_6_anat_1_Tag_pr100_sr100_ppf100_spf100_ipf100_sipf143_FS222/0025437_session_6_anat_1_Tag_pr100_sr100_ppf100_spf100_ipf100_sipf143_FS222/mri/aparc.DKTatlas+aseg.deep.nii.gz
# File not found, skipped: /home/limseoyoung/drwelly1/Team_Planning/Brain_Volumetry/oasis_vendor_before/NII/GE/HNU/0025427_session_9_anat_1_Tag_pr100_sr100_ppf100_spf100_ipf100_sipf143_FS222/0025427_session_9_anat_1_Tag_pr100_sr100_ppf100_spf100_ipf100_sipf143_FS222/mri/aparc.DKTatlas+aseg.deep.nii.gz
# File not found, skipped: /home/limseoyoung/drwelly1/Team_Planning/Brain_Volumetry/oasis_vendor_before/NII/GE/HNU/0025427_session_8_anat_1_Tag_pr100_sr100_ppf100_spf100_ipf100_sipf143_FS222/0025427_session_8_anat_1_Tag_pr100_sr100_ppf100_spf100_ipf100_sipf143_FS222/mri/aparc.DKTatlas+aseg.deep.nii.gz
# File not found, skipped: /home/limseoyoung/drwelly1/Team_Planning/Brain_Volumetry/oasis_vendor_before/NII/GE/HNU/0025432_session_5_anat_1_Tag_pr100_sr100_ppf100_spf100_ipf100_sipf143_FS222/0025432_session_5_anat_1_Tag_pr100_sr100_ppf100_spf100_ipf100_sipf143_FS222/mri/aparc.DKTatlas+aseg.deep.nii.gz
# File not found, skipped: /home/limseoyoung/drwelly1/Team_Planning/Brain_Volumetry/oasis_vendor_before/NII/GE/HNU/0025433_session_2_anat_1_Tag_pr100_sr100_ppf100_spf100_ipf100_sipf143_FS222/0025433_session_2_anat_1_Tag_pr100_sr100_ppf100_spf100_ipf100_sipf143_FS222/mri/aparc.DKTatlas+aseg.deep.nii.gz
# File not found, skipped: /home/limseoyoung/drwelly1/Team_Planning/Brain_Volumetry/oasis_vendor_before/NII/GE/HNU/0025430_session_7_anat_1_Tag_pr100_sr100_ppf100_spf100_ipf100_sipf143_FS222/0025430_session_7_anat_1_Tag_pr100_sr100_ppf100_spf100_ipf100_sipf143_FS222/mri/aparc.DKTatlas+aseg.deep.nii.gz
# File not found, skipped: /home/limseoyoung/drwelly1/Team_Planning/Brain_Volumetry/oasis_vendor_before/NII/GE/HNU/0025428_session_6_anat_1_Tag_pr100_sr100_ppf100_spf100_ipf100_sipf143_FS222/0025428_session_6_anat_1_Tag_pr100_sr100_ppf100_spf100_ipf100_sipf143_FS222/mri/aparc.DKTatlas+aseg.deep.nii.gz
# File not found, skipped: /home/limseoyoung/drwelly1/Team_Planning/Brain_Volumetry/oasis_vendor_before/NII/GE/HNU/0025436_session_9_anat_1_Tag_pr100_sr100_ppf100_spf100_ipf100_sipf143_FS222/0025436_session_9_anat_1_Tag_pr100_sr100_ppf100_spf100_ipf100_sipf143_FS222/mri/aparc.DKTatlas+aseg.deep.nii.gz
# File not found, skipped: /home/limseoyoung/drwelly1/Team_Planning/Brain_Volumetry/oasis_vendor_before/NII/GE/HNU/0025436_session_2_anat_1_Tag_pr100_sr100_ppf100_spf100_ipf100_sipf143_FS222/0025436_session_2_anat_1_Tag_pr100_sr100_ppf100_spf100_ipf100_sipf143_FS222/mri/aparc.DKTatlas+aseg.deep.nii.gz
# File not found, skipped: /home/limseoyoung/drwelly1/Team_Planning/Brain_Volumetry/oasis_vendor_before/NII/GE/HNU/0025437_session_2_anat_1_Tag_pr100_sr100_ppf100_spf100_ipf100_sipf143_FS222/0025437_session_2_anat_1_Tag_pr100_sr100_ppf100_spf100_ipf100_sipf143_FS222/mri/aparc.DKTatlas+aseg.deep.nii.gz
# File not found, skipped: /home/limseoyoung/drwelly1/Team_Planning/Brain_Volumetry/oasis_vendor_before/NII/GE/HNU/0025435_session_1_anat_1_Tag_pr100_sr100_ppf100_spf100_ipf100_sipf143_FS222/0025435_session_1_anat_1_Tag_pr100_sr100_ppf100_spf100_ipf100_sipf143_FS222/mri/aparc.DKTatlas+aseg.deep.nii.gz
# File not found, skipped: /home/limseoyoung/drwelly1/Team_Planning/Brain_Volumetry/oasis_vendor_before/NII/GE/HNU/0025437_session_7_anat_1_Tag_pr100_sr100_ppf100_spf100_ipf100_sipf143_FS222/0025437_session_7_anat_1_Tag_pr100_sr100_ppf100_spf100_ipf100_sipf143_FS222/mri/aparc.DKTatlas+aseg.deep.nii.gz
# File not found, skipped: /home/limseoyoung/drwelly1/Team_Planning/Brain_Volumetry/oasis_vendor_before/NII/GE/HNU/0025428_session_10_anat_1_Tag_pr100_sr100_ppf100_spf100_ipf100_sipf143_FS222/0025428_session_10_anat_1_Tag_pr100_sr100_ppf100_spf100_ipf100_sipf143_FS222/mri/aparc.DKTatlas+aseg.deep.nii.gz
# File not found, skipped: /home/limseoyoung/drwelly1/Team_Planning/Brain_Volumetry/oasis_vendor_before/NII/GE/HNU/0025435_session_4_anat_1_Tag_pr100_sr100_ppf100_spf100_ipf100_sipf143_FS222/0025435_session_4_anat_1_Tag_pr100_sr100_ppf100_spf100_ipf100_sipf143_FS222/mri/aparc.DKTatlas+aseg.deep.nii.gz
# File not found, skipped: /home/limseoyoung/drwelly1/Team_Planning/Brain_Volumetry/oasis_vendor_before/NII/GE/HNU/0025434_session_8_anat_1_Tag_pr100_sr100_ppf100_spf100_ipf100_sipf143_FS222/0025434_session_8_anat_1_Tag_pr100_sr100_ppf100_spf100_ipf100_sipf143_FS222/mri/aparc.DKTatlas+aseg.deep.nii.gz
# File not found, skipped: /home/limseoyoung/drwelly1/Team_Planning/Brain_Volumetry/oasis_vendor_before/NII/GE/HNU/0025429_session_8_anat_1_Tag_pr100_sr100_ppf100_spf100_ipf100_sipf143_FS222/0025429_session_8_anat_1_Tag_pr100_sr100_ppf100_spf100_ipf100_sipf143_FS222/mri/aparc.DKTatlas+aseg.deep.nii.gz
# File not found, skipped: /home/limseoyoung/drwelly1/Team_Planning/Brain_Volumetry/oasis_vendor_before/NII/GE/HNU/0025430_session_3_anat_1_Tag_pr100_sr100_ppf100_spf100_ipf100_sipf143_FS222/0025430_session_3_anat_1_Tag_pr100_sr100_ppf100_spf100_ipf100_sipf143_FS222/mri/aparc.DKTatlas+aseg.deep.nii.gz
# File not found, skipped: /home/limseoyoung/drwelly1/Team_Planning/Brain_Volumetry/oasis_vendor_before/NII/GE/HNU/0025427_session_10_anat_1_Tag_pr100_sr100_ppf100_spf100_ipf100_sipf143_FS222/0025427_session_10_anat_1_Tag_pr100_sr100_ppf100_spf100_ipf100_sipf143_FS222/mri/aparc.DKTatlas+aseg.deep.nii.gz
# File not found, skipped: /home/limseoyoung/drwelly1/Team_Planning/Brain_Volumetry/oasis_vendor_before/NII/GE/HNU/0025431_session_4_anat_1_Tag_pr100_sr100_ppf100_spf100_ipf100_sipf143_FS222/0025431_session_4_anat_1_Tag_pr100_sr100_ppf100_spf100_ipf100_sipf143_FS222/mri/aparc.DKTatlas+aseg.deep.nii.gz
# File not found, skipped: /home/limseoyoung/drwelly1/Team_Planning/Brain_Volumetry/oasis_vendor_before/NII/GE/HNU/0025433_session_1_anat_1_Tag_pr100_sr100_ppf100_spf100_ipf100_sipf143_FS222/0025433_session_1_anat_1_Tag_pr100_sr100_ppf100_spf100_ipf100_sipf143_FS222/mri/aparc.DKTatlas+aseg.deep.nii.gz
# File not found, skipped: /home/limseoyoung/drwelly1/Team_Planning/Brain_Volumetry/oasis_vendor_before/NII/GE/HNU/0025431_session_2_anat_1_Tag_pr100_sr100_ppf100_spf100_ipf100_sipf143_FS222/0025431_session_2_anat_1_Tag_pr100_sr100_ppf100_spf100_ipf100_sipf143_FS222/mri/aparc.DKTatlas+aseg.deep.nii.gz
# File not found, skipped: /home/limseoyoung/drwelly1/Team_Planning/Brain_Volumetry/oasis_vendor_before/NII/GE/HNU/0025433_session_4_anat_1_Tag_pr100_sr100_ppf100_spf100_ipf100_sipf143_FS222/0025433_session_4_anat_1_Tag_pr100_sr100_ppf100_spf100_ipf100_sipf143_FS222/mri/aparc.DKTatlas+aseg.deep.nii.gz
# File not found, skipped: /home/limseoyoung/drwelly1/Team_Planning/Brain_Volumetry/oasis_vendor_before/NII/GE/HNU/0025434_session_4_anat_1_Tag_pr100_sr100_ppf100_spf100_ipf100_sipf143_FS222/0025434_session_4_anat_1_Tag_pr100_sr100_ppf100_spf100_ipf100_sipf143_FS222/mri/aparc.DKTatlas+aseg.deep.nii.gz
# File not found, skipped: /home/limseoyoung/drwelly1/Team_Planning/Brain_Volumetry/oasis_vendor_before/NII/GE/HNU/0025434_session_9_anat_1_Tag_pr100_sr100_ppf100_spf100_ipf100_sipf143_FS222/0025434_session_9_anat_1_Tag_pr100_sr100_ppf100_spf100_ipf100_sipf143_FS222/mri/aparc.DKTatlas+aseg.deep.nii.gz
# File not found, skipped: /home/limseoyoung/drwelly1/Team_Planning/Brain_Volumetry/oasis_vendor_before/NII/GE/HNU/0025436_session_4_anat_1_Tag_pr100_sr100_ppf100_spf100_ipf100_sipf143_FS222/0025436_session_4_anat_1_Tag_pr100_sr100_ppf100_spf100_ipf100_sipf143_FS222/mri/aparc.DKTatlas+aseg.deep.nii.gz
# File not found, skipped: /home/limseoyoung/drwelly1/Team_Planning/Brain_Volumetry/oasis_vendor_before/NII/GE/HNU/0025433_session_7_anat_1_Tag_pr100_sr100_ppf100_spf100_ipf100_sipf143_FS222/0025433_session_7_anat_1_Tag_pr100_sr100_ppf100_spf100_ipf100_sipf143_FS222/mri/aparc.DKTatlas+aseg.deep.nii.gz
# File not found, skipped: /home/limseoyoung/drwelly1/Team_Planning/Brain_Volumetry/oasis_vendor_before/NII/GE/HNU/0025437_session_4_anat_1_Tag_pr100_sr100_ppf100_spf100_ipf100_sipf143_FS222/0025437_session_4_anat_1_Tag_pr100_sr100_ppf100_spf100_ipf100_sipf143_FS222/mri/aparc.DKTatlas+aseg.deep.nii.gz
# File not found, skipped: /home/limseoyoung/drwelly1/Team_Planning/Brain_Volumetry/oasis_vendor_before/NII/GE/HNU/0025432_session_10_anat_1_Tag_pr100_sr100_ppf100_spf100_ipf100_sipf143_FS222/0025432_session_10_anat_1_Tag_pr100_sr100_ppf100_spf100_ipf100_sipf143_FS222/mri/aparc.DKTatlas+aseg.deep.nii.gz
# File not found, skipped: /home/limseoyoung/drwelly1/Team_Planning/Brain_Volumetry/oasis_vendor_before/NII/GE/HNU/0025430_session_8_anat_1_Tag_pr100_sr100_ppf100_spf100_ipf100_sipf143_FS222/0025430_session_8_anat_1_Tag_pr100_sr100_ppf100_spf100_ipf100_sipf143_FS222/mri/aparc.DKTatlas+aseg.deep.nii.gz
# File not found, skipped: /home/limseoyoung/drwelly1/Team_Planning/Brain_Volumetry/oasis_vendor_before/NII/GE/HNU/0025435_session_3_anat_1_Tag_pr100_sr100_ppf100_spf100_ipf100_sipf143_FS222/0025435_session_3_anat_1_Tag_pr100_sr100_ppf100_spf100_ipf100_sipf143_FS222/mri/aparc.DKTatlas+aseg.deep.nii.gz
# File not found, skipped: /home/limseoyoung/drwelly1/Team_Planning/Brain_Volumetry/oasis_vendor_before/NII/GE/HNU/0025432_session_2_anat_1_Tag_pr100_sr100_ppf100_spf100_ipf100_sipf143_FS222/0025432_session_2_anat_1_Tag_pr100_sr100_ppf100_spf100_ipf100_sipf143_FS222/mri/aparc.DKTatlas+aseg.deep.nii.gz
# File not found, skipped: /home/limseoyoung/drwelly1/Team_Planning/Brain_Volumetry/oasis_vendor_before/NII/GE/HNU/0025436_session_5_anat_1_Tag_pr100_sr100_ppf100_spf100_ipf100_sipf143_FS222/0025436_session_5_anat_1_Tag_pr100_sr100_ppf100_spf100_ipf100_sipf143_FS222/mri/aparc.DKTatlas+aseg.deep.nii.gz

# %%
volume_df
# Out:
#                 0              2             4            5             7  \
# 0    1.468286e+07  253785.353119  17100.607738   777.237988  10536.273839
# 1    1.484521e+07  208279.886815   4986.533924   291.549996  10810.330835
# 2    1.470141e+07  234506.009414   7206.086890   644.496990  11966.240817
# 3    1.472612e+07  231834.039455   7582.357884   727.502989  12038.270816
# 4    1.474965e+07  230444.203476   4224.387935   302.182995  11302.535827
# ..            ...            ...           ...          ...           ...
# 238  1.470591e+07  226945.603530   8228.912874   422.918994  14167.614783
# 239  1.461176e+07  249717.716181   8280.362873   440.754993  14635.123776
# 240  1.457939e+07  266340.867927   8871.351864   940.505986  16275.006751
# 241  1.462731e+07  249790.089180  10907.742833  1013.564985   9043.194862
# 242  1.486060e+07  191681.088069   7328.880888   396.164994  10479.678840
#
#                 8            10           11           12           13  ...  \
# 0    38808.391407   7714.069882  4899.068925  6241.570905  2497.039962  ...
# 1    38287.031415   7643.068883  3705.771943  5347.369918  1922.514971  ...
# 2    47029.415281   9331.657857  3687.249944  5714.036913  2218.866966  ...
# 3    43165.863340   9213.665859  3698.911943  5634.460914  2225.383966  ...
# 4    48432.285259   8703.624867  4733.399928  6110.201907  2431.526963  ...
# ..            ...           ...          ...          ...          ...  ...
# 238  55684.677148   8619.589868  3814.159942  6631.561899  2311.819965  ...
# 239  54915.328160   9175.249860  4069.008938  5645.093914  2091.956968  ...
# 240  58592.288104  10155.200845  4497.072931  5966.827909  2428.096963  ...
# 241  42613.290348   8871.694864  4372.906933  6352.359903  2170.160967  ...
# 242  45045.846311   7396.108887  3475.618947  4968.697924  2032.617969  ...
#
#              2025         2026          2027          2028          2029  \
# 0     8896.733864  1926.630971  11915.476818  26458.333595  10650.149837
# 1     9707.585852  2066.231968  11092.619830  23891.664635  10862.466834
# 2    11163.963829  2534.083961   9987.130847  23088.015647  12563.746808
# 3    11030.193831  2145.121967   8836.708865  22140.992661  12071.884815
# 4    10882.017834  2013.752969  11447.624825  25585.398609  11928.853818
# ..            ...          ...           ...           ...           ...
# 238  10720.807836  2168.102967  10853.548834  24809.532621  12697.859806
# 239  11982.018817  1748.270973  12477.653809  29538.816548  11914.790818
# 240  12566.833808  1154.194982  13542.325793  27356.993582  13123.522799
# 241  13737.835790  2269.973965  13160.909799  30584.280532  13705.936790
# 242   9839.640850  1786.000973   8702.252867  23756.865637  10802.098835
#
#              2030          2031         2034         2035  \
# 0    14050.994785  10570.230838  1010.134985  5584.382915
# 1    11543.664823   8562.651869   727.845989  4634.272929
# 2    15926.861756   9534.713854  1209.417982  6372.596903
# 3    15498.111763   9589.593853  1171.001982  6653.513898
# 4    13822.899789   9698.667852   930.215986  5286.315919
# ..            ...           ...          ...          ...
# 238  14395.366780  10067.049846   973.776985  6411.355902
# 239  14982.925771  10278.337843  1074.618984  6453.887901
# 240  13937.804787  11530.287824  1162.426982  5658.127913
# 241  15028.201770  10797.982835  1003.274985  5993.581908
# 242  13025.767801   7641.353883   876.707987  5915.034910
#
#                                                subject
# 0    0025441_session_10_anat_1_Tag_pr100_sr100_ppf1...
# 1    0025453_session_8_anat_1_Tag_pr100_sr100_ppf10...
# 2    0025455_session_1_anat_1_Tag_pr100_sr100_ppf10...
# 3    0025455_session_4_anat_1_Tag_pr100_sr100_ppf10...
# 4    0025439_session_1_anat_1_Tag_pr100_sr100_ppf10...
# ..                                                 ...
# 238  0025451_session_2_anat_1_Tag_pr100_sr100_ppf10...
# 239  0025436_session_6_anat_1_Tag_pr100_sr100_ppf10...
# 240  0025449_session_8_anat_1_Tag_pr100_sr100_ppf10...
# 241  0025447_session_10_anat_1_Tag_pr100_sr100_ppf1...
# 242  0025450_session_8_anat_1_Tag_pr100_sr100_ppf10...
#
# [243 rows x 97 columns]

# %%
volume_df['subject'] = volume_df['subject'].str.replace('anat_1_Tag_pr100_sr100_ppf100_spf100_ipf100_sipf143_FS222', '')

# %%
# 경로만 지정!
base_dir1 = '/mnt/drwelly1/Team_Planning/Brain_Volumetry/oasis_vendor_before/NII/GE/IACAS'


def calculate_volume(nii_path):
    img = nib.load(nii_path) 
    data = img.get_fdata()
    header = img.header
    voxel_volume = np.prod(header.get_zooms())
    unique_elements, counts_elements = np.unique(data, return_counts=True)
    volumes = counts_elements * voxel_volume
    return dict(zip(unique_elements.astype(int), volumes))

# %%
volume_data1 = []

for subject_dir in os.listdir(base_dir1):
    full_subject_dir = os.path.join(base_dir1, subject_dir)
    if not os.path.isdir(full_subject_dir) or 'FS222' not in subject_dir:
        continue
    
    double_subject_dir = os.path.join(full_subject_dir, subject_dir)
    if not os.path.isdir(double_subject_dir):
        continue
    
    mri_dir = os.path.join(double_subject_dir, 'mri')
    nii_path = os.path.join(mri_dir, 'aparc.DKTatlas+aseg.deep.nii.gz')
    
    if os.path.isfile(nii_path):
        try:
            vol_data = calculate_volume(nii_path)
            vol_data["subject"] = subject_dir
            volume_data1.append(vol_data)
        except OSError as e:
            print(f"Error processing file {nii_path}, skipped  Error: {e}")
    else:
        print(f"File not found, skipped: {nii_path}")

volume_df1 = pd.DataFrame(volume_data1)
# Out:
# File not found, skipped: /mnt/drwelly1/Team_Planning/Brain_Volumetry/oasis_vendor_before/NII/GE/IACAS/0025459_session_2_anat_1_Tag_pr100_sr100_ppf100_spf100_ipf100_sipf143_FS222/0025459_session_2_anat_1_Tag_pr100_sr100_ppf100_spf100_ipf100_sipf143_FS222/mri/aparc.DKTatlas+aseg.deep.nii.gz
# File not found, skipped: /mnt/drwelly1/Team_Planning/Brain_Volumetry/oasis_vendor_before/NII/GE/IACAS/0025462_session_1_anat_1_Tag_pr100_sr100_ppf100_spf100_ipf100_sipf143_FS222/0025462_session_1_anat_1_Tag_pr100_sr100_ppf100_spf100_ipf100_sipf143_FS222/mri/aparc.DKTatlas+aseg.deep.nii.gz
# File not found, skipped: /mnt/drwelly1/Team_Planning/Brain_Volumetry/oasis_vendor_before/NII/GE/IACAS/0025460_session_2_anat_1_Tag_pr100_sr100_ppf100_spf100_ipf100_sipf143_FS222/0025460_session_2_anat_1_Tag_pr100_sr100_ppf100_spf100_ipf100_sipf143_FS222/mri/aparc.DKTatlas+aseg.deep.nii.gz
# File not found, skipped: /mnt/drwelly1/Team_Planning/Brain_Volumetry/oasis_vendor_before/NII/GE/IACAS/0025462_session_2_anat_1_Tag_pr100_sr100_ppf100_spf100_ipf100_sipf143_FS222/0025462_session_2_anat_1_Tag_pr100_sr100_ppf100_spf100_ipf100_sipf143_FS222/mri/aparc.DKTatlas+aseg.deep.nii.gz
# File not found, skipped: /mnt/drwelly1/Team_Planning/Brain_Volumetry/oasis_vendor_before/NII/GE/IACAS/0025464_session_1_anat_1_Tag_pr100_sr100_ppf100_spf100_ipf100_sipf143_FS222/0025464_session_1_anat_1_Tag_pr100_sr100_ppf100_spf100_ipf100_sipf143_FS222/mri/aparc.DKTatlas+aseg.deep.nii.gz

# %%
volume_df1
# Out:
#                0              2             4           5             7  \
# 0   1.565805e+07  242435.826293   6950.551894  298.066995  17544.792732
# 1   1.564695e+07  242586.403290   6774.249896  254.162996  14594.992777
# 2   1.555197e+07  251451.581155   9700.725852  618.085991  17867.555727
# 3   1.556117e+07  244829.623256  13319.032796  428.063993  13397.579795
# 4   1.553914e+07  255986.041085   5307.924919  205.113997  13707.308790
# 5   1.548743e+07  279134.424731   4505.647931  389.647994  15066.617770
# 6   1.543936e+07  280689.929708   5294.547919  266.510996  17454.926733
# 7   1.567507e+07  247358.562217   3111.352952  137.542998  15125.613769
# 8   1.556814e+07  233607.692428  13603.036792  450.701993  12942.418802
# 9   1.565587e+07  255260.253097   3244.093950  137.885998  15296.770766
# 10  1.564658e+07  237431.456369   4926.165925  216.775997  13486.759794
# 11  1.562797e+07  241206.514311   4809.202926  214.031997  13558.103793
# 12  1.547410e+07  278581.165740   8052.267877  348.487995  14659.819776
# 13  1.550427e+07  274920.669796   4534.459931  343.342995  15225.426767
# 14  1.578820e+07  212789.993746   4611.634929  239.070996  13072.758800
# 15  1.559948e+07  240713.623319  10566.800838   87.464999  14906.779772
# 16  1.554715e+07  260366.837018   3556.909946  278.515996  15406.187764
# 17  1.561927e+07  231260.200464  10694.396836  107.358998  14443.729779
# 18  1.554445e+07  257733.626059   5347.026918  231.181996  15154.082768
# 19  1.546465e+07  276991.017764   7851.612880  512.784992  15496.053763
# 20  1.574747e+07  215656.444702   5400.534917  235.297996  14797.362774
# 21  1.548525e+07  282642.285678   8168.544875  518.615992  15796.864758
# 22  1.573868e+07  213943.159728  12194.335814  248.674996  14063.342785
# 23  1.549711e+07  272359.831835   7982.295878  334.767995  14726.361775
# 24  1.562756e+07  241724.444304   5524.014916  251.075996  15261.784767
# 25  1.578046e+07  214043.658727   4434.303932  236.669996  11708.990821
# 26  1.561760e+07  253810.392119   5879.705910  330.308995  15674.070760
# 27  1.555979e+07  265810.589935   3433.429947  271.655996  15669.268760
# 28  1.572027e+07  210048.737788   5614.566914  267.196996  14875.223773
#
#                8            10           11           12           13  ...  \
Tag_pr100_sr100_ppf100_spf100_ipf100_sipf143_FS222', '')

# %%
sesson1 = combined_df[combined_df['subject'].str.contains(r'_session_1[^0-9]')]
sesson2 = combined_df[combined_df['subject'].str.contains('_session_2')]
sesson3 = combined_df[combined_df['subject'].str.contains('_session_3')]
sesson4 = combined_df[combined_df['subject'].str.contains('_session_4')]

# %%
lut_path = '/mnt/drwelly1/Team_Planning/Brain_Volumetry/Algorithms/freesurfer/FreeSurferColorLUT.txt'
# labeling 불러오면됨

# %%
def load_freesurfer_lut(lut_path):
    lut = {}
    with open(lut_path, 'r') as file:
        for line in file:
            if line.strip() and not line.startswith('#'):
                parts = line.split()
                if parts[0].isdigit():
                    lut[int(parts[0])] = ' '.join(parts[1:])
    return lut

freesurfer_lut = load_freesurfer_lut(lut_path)

# %%
# 모든 컬럼 이름을 변경
new_columns = [freesurfer_lut.get(int(col), 'Unknown') if col != 'subject' else 'subject' for col in sesson1.columns]


sesson1.columns = new_columns

# %%
def extract_number(subj):
    parts = subj.split('_')  # '_'를 기준
    if len(parts) > 1:
        number_part = parts[1]  
        # 숫자만 
        numbers = ''.join(filter(str.isdigit, number_part))
        return int(numbers) if numbers.isdigit() else None
    return None

# %%
sesson1['sort_key'] = sesson1['subject'].apply(extract_number) 
volume_df_sorted1 = sesson1.sort_values(by='sort_key').drop(columns=['sort_key'])
# Out:
# /tmp/ipykernel_3189673/2792317927.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sesson1['sort_key'] = sesson1['subject'].apply(extract_number)

# %%
# 모든 컬럼 이름을 변경
new_columns = [freesurfer_lut.get(int(col), 'Unknown') if col != 'subject' else 'subject' for col in sesson2.columns]


sesson2.columns = new_columns

# %%
sesson2['sort_key'] = sesson2['subject'].apply(extract_number)
volume_df_sorted2 = sesson2.sort_values(by='sort_key').drop(columns=['sort_key'])
# Out:
# /tmp/ipykernel_3189673/1960010514.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sesson2['sort_key'] = sesson2['subject'].apply(extract_number)

# %%
def update_df_columns_keep_others(df, roi_dict):
    # 합쳐진 컬럼들의 원본 컬럼 이름을 저장할 리스트
    columns_to_remove = []
    
    # ROI 딕셔너리에 기반하여 합치는 작업을 수행
    for roi, sub_columns in roi_dict.items():
        # 해당 ROI에 속하는 데이터프레임의 컬럼들 찾기
        relevant_columns = [col for col in df.columns if col.split(' ')[0] in sub_columns]
        
        # 해당 컬럼들이 데이터프레임에 있는 경우, 합쳐진 컬럼 생성
        if relevant_columns:
            # 합산 전에 NaN 값을 0으로 변환
            df[roi] = df[relevant_columns].fillna(0).sum(axis=1)
            # 원본 컬럼 이름을 제거 리스트에 추가
            columns_to_remove.extend(relevant_columns)
    
    # 모든 ROI 컬럼들을 포함하는 리스트 생성
    all_roi_columns = set()
    for sub_columns in roi_dict.values():
        all_roi_columns.update(sub_columns)
    
    # 제거할 컬럼 리스트에서, 딕셔너리에 정의된 컬럼만 실제로 제거
    columns_to_remove = set([col for col in columns_to_remove if col.split(' ')[0] in all_roi_columns])
    
    # 실제로 제거할 컬럼들을 제거
    df.drop(columns=columns_to_remove, inplace=True, errors='ignore')
    
    return df

# 함수 실행하여 데이터프레임 업데이트
new_df1 = update_df_columns_keep_others(volume_df_sorted1.copy(), combined_roi_dict)
new_df2 = update_df_columns_keep_others(volume_df_sorted2.copy(), combined_roi_dict)

# %%
brain_areas = set()
left_right_columns = []

for col in new_df1.columns:
    if col.startswith('Left-') or col.startswith('Right-'):
        left_right_columns.append(col)
        brain_area = col.split('-', 1)[1]
        brain_areas.add(brain_area)


for area in brain_areas:
    left_col = f'Left-{area}'
    right_col = f'Right-{area}'
    new_df1[area] = new_df1.get(left_col, 0) + new_df1.get(right_col, 0)

volume_df_sorted1_final = new_df1.drop(columns=[col for col in left_right_columns if col not in ['subject']])

# %%
volume_df_sorted1_final= volume_df_sorted1_final.drop(columns = ['Unknown 0 0 0 0','choroid-plexus 0 200 200 0','choroid-plexus 0 200 221 0','WM-hypointensities 200 70 255 0'])

# %%
brain_areas = set()
left_right_columns = []

for col in new_df2.columns:
    if col.startswith('Left-') or col.startswith('Right-'):
        left_right_columns.append(col)
        brain_area = col.split('-', 1)[1]
        brain_areas.add(brain_area)


for area in brain_areas:
    left_col = f'Left-{area}'
    right_col = f'Right-{area}'
    new_df2[area] = new_df2.get(left_col, 0) + new_df2.get(right_col, 0)

volume_df_sorted2_final = new_df2.drop(columns=[col for col in left_right_columns if col not in ['subject']])

# %%
volume_df_sorted2_final= volume_df_sorted2_final.drop(columns = ['Unknown 0 0 0 0','choroid-plexus 0 200 200 0','choroid-plexus 0 200 221 0','WM-hypointensities 200 70 255 0'])

# %%
all_data = pd.concat([volume_df_sorted1_final,volume_df_sorted2_final])
all_data_long = pd.melt(all_data, id_vars=["subject"], var_name="ROI", value_name="Volume")

# %%
all_data_long['Session'] = all_data_long['subject'].str.extract(r'(session_\d+)')


all_data_long['ROI'] = all_data_long['ROI'].str.extract(r'([a-zA-Z-_]+)')[0]

# %%
all_data_long['Subject_ID'] = all_data_long['subject'].str.extract(r'(\d+)')

# %%
re_long = all_data_long.dropna(subset=['Volume'])


grouped = re_long.groupby(['Subject_ID', 'ROI'])['Volume'].agg(['mean', 'var', 'std']).reset_index()

# %%
grouped['CV'] = grouped['std'] / grouped['mean']

# %%
grouped['CV'] = grouped['std'] / grouped['mean']

# %%
roi_mean_cv = grouped.groupby('ROI')['CV'].mean().reset_index()
roi_mean_cv.rename(columns={'CV': 'Mean_CV'}, inplace=True)

roi_mean_cv
# Out:
#                         ROI   Mean_CV
# 0            Accumbens-area  0.018245
# 1                  Amygdala  0.026337
# 2                Brain-Stem  0.012540
# 3                       CSF  0.021864
# 4                   Caudate  0.005761
# 5                Cerebellum  0.016949
# 6                 Cingulate  0.027236
# 7      Combined-Cerebral-WM  0.005018
# 8                   Frontal  0.012925
# 9               Hippocampus  0.007007
# 10                   Insula  0.027185
# 11                Occipital  0.007992
# 12                 Pallidum  0.030860
# 13                 Parietal  0.011021
# 14                  Putamen  0.007033
# 15                 Temporal  0.023821
# 16                 Thalamus  0.004840
# 17  Total-Lateral-Ventricle  0.020551
# 18                VentralDC  0.011149
# 19             rd-Ventricle  0.020549
# 20             th-Ventricle  0.025076

# %%
#roi_mean_cv.to_csv("GE_before_cv_fastsurfer.csv")

# %%
#grouped.to_csv("GE_before_CV_individual_freesurfer.csv")
