# %%
combined_roi_dict = {
    'Left-Cingulate': {
        'ctx-lh-caudalanteriorcingulate',
        'ctx-lh-rostralanteriorcingulate',
        'ctx-lh-isthmuscingulate',
        'ctx-lh-posteriorcingulate',
    },
    'Right-Cingulate': {
        'ctx-rh-caudalanteriorcingulate',
        'ctx-rh-rostralanteriorcingulate',
        'ctx-rh-isthmuscingulate',
        'ctx-rh-posteriorcingulate',
    },
    'Left-Frontal': {
        'ctx-lh-caudalmiddlefrontal',
        'ctx-lh-lateralorbitofrontal',
        'ctx-lh-medialorbitofrontal',
        'ctx-lh-parsopercularis',
        'ctx-lh-parsorbitalis',
        'ctx-lh-parstriangularis',
        'ctx-lh-precentral',
        'ctx-lh-rostralmiddlefrontal',
        'ctx-lh-superiorfrontal',
        'ctx-lh-paracentral'
    },
    'Right-Frontal': {
        'ctx-rh-caudalmiddlefrontal',
        'ctx-rh-lateralorbitofrontal',
        'ctx-rh-medialorbitofrontal',
        'ctx-rh-parsopercularis',
        'ctx-rh-parsorbitalis',
        'ctx-rh-parstriangularis',
        'ctx-rh-precentral',
        'ctx-rh-rostralmiddlefrontal',
        'ctx-rh-superiorfrontal',
        'ctx-rh-paracentral'
    },
    'Left-Temporal': {
        'ctx-lh-entorhinal',
        'ctx-lh-fusiform',
        'ctx-lh-inferiortemporal',
        'ctx-lh-middletemporal',
        'ctx-lh-superiortemporal',
        'ctx-lh-transversetemporal',
        'ctx-lh-parahippocampal',
        
    },
    'Right-Temporal': {
        'ctx-rh-entorhinal',
        'ctx-rh-fusiform',
        'ctx-rh-inferiortemporal',
        'ctx-rh-middletemporal',
        'ctx-rh-superiortemporal',
        'ctx-rh-transversetemporal',
        'ctx-rh-parahippocampal',
     
    },
    'Left-Parietal': {
        'ctx-lh-inferiorparietal',
        'ctx-lh-postcentral',
        'ctx-lh-superiorparietal',
        'ctx-lh-supramarginal',
        'ctx-lh-precuneus'
    },
    'Right-Parietal': {
        'ctx-rh-inferiorparietal',
        'ctx-rh-postcentral',
        'ctx-rh-superiorparietal',
        'ctx-rh-supramarginal',
        'ctx-rh-precuneus'
    },
    'Left-Occipital': {
        'ctx-lh-cuneus',
        'ctx-lh-lateraloccipital',
        'ctx-lh-lingual',
        'ctx-lh-pericalcarine'
    },
    'Right-Occipital': {
        'ctx-rh-cuneus',
        'ctx-rh-lateraloccipital',
        'ctx-rh-lingual',
        'ctx-rh-pericalcarine'
    },
    'Left-Insula':{
        'ctx-lh-insula'
    },
    'Right-Insula': {
        'ctx-rh-insula'
    },
    'Left-Cerebellum':{
        'Left-Cerebellum-White-Matter',
        'Left-Cerebellum-Cortex'
    },
    'Right-Cerebellum': {
        'Right-Cerebellum-White-Matter',
        'Right-Cerebellum-Cortex'
    },
    'Left-Combined-Cerebral-WM': {
        'Left-Cerebral-White-Matter',
        'Left-WM-hypointensities'
    },
    'Right-Combined-Cerebral-WM': {
        'Right-Cerebral-White-Matter',
        'Right-WM-hypointensities'
    },
    'Left-Total-Lateral-Ventricle': {
        'Left-Lateral-Ventricle',
        'Left-Inf-Lat-Vent'
    },
    'Right-Total-Lateral-Ventricle': {
        'Right-Lateral-Ventricle',
        'Right-Inf-Lat-Vent'
    },
}
gray_matter_index = {
    'left_cortical_gm': {
        'left_cingulate',
        'left_frontal',
        'left_temporal',
        'left_parietal',
        'left_occipital',
        'left_insula'
    },
    'right_cortical_gm': {
        'right_cingulate',
        'right_frontal',
        'right_temporal',
        'right_parietal',
        'right_occipital',
        'right_insula'
    }
}

combined_roi_display_dict = {
    'Left-Cingulate': {
        'ctx-lh-caudalanteriorcingulate',
        'ctx-lh-rostralanteriorcingulate',
        'ctx-lh-isthmuscingulate',
        'ctx-lh-posteriorcingulate',
    },
    'Right-Cingulate': {
        'ctx-rh-caudalanteriorcingulate',
        'ctx-rh-rostralanteriorcingulate',
        'ctx-rh-isthmuscingulate',
        'ctx-rh-posteriorcingulate',
    },
    'Left-Frontal': {
        'ctx-lh-caudalmiddlefrontal',
        'ctx-lh-lateralorbitofrontal',
        'ctx-lh-medialorbitofrontal',
        'ctx-lh-parsopercularis',
        'ctx-lh-parsorbitalis',
        'ctx-lh-parstriangularis',
        'ctx-lh-precentral',
        'ctx-lh-rostralmiddlefrontal',
        'ctx-lh-superiorfrontal',
        'ctx-lh-paracentral'
    },
    'Right-Frontal': {
        'ctx-rh-caudalmiddlefrontal',
        'ctx-rh-lateralorbitofrontal',
        'ctx-rh-medialorbitofrontal',
        'ctx-rh-parsopercularis',
        'ctx-rh-parsorbitalis',
        'ctx-rh-parstriangularis',
        'ctx-rh-precentral',
        'ctx-rh-rostralmiddlefrontal',
        'ctx-rh-superiorfrontal',
        'ctx-rh-paracentral'
    },
    'Left-Temporal': {
        'ctx-lh-entorhinal',
        'ctx-lh-fusiform',
        'ctx-lh-inferiortemporal',
        'ctx-lh-middletemporal',
        'ctx-lh-superiortemporal',
        'ctx-lh-transversetemporal',
        'ctx-lh-parahippocampal',
    },
    'Right-Temporal': {
        'ctx-rh-entorhinal',
        'ctx-rh-fusiform',
        'ctx-rh-inferiortemporal',
        'ctx-rh-middletemporal',
        'ctx-rh-superiortemporal',
        'ctx-rh-transversetemporal',
        'ctx-rh-parahippocampal',
    },
    'Left-Parietal': {
        'ctx-lh-inferiorparietal',
        'ctx-lh-postcentral',
        'ctx-lh-superiorparietal',
        'ctx-lh-supramarginal',
        'ctx-lh-precuneus'
    },
    'Right-Parietal': {
        'ctx-rh-inferiorparietal',
        'ctx-rh-postcentral',
        'ctx-rh-superiorparietal',
        'ctx-rh-supramarginal',
        'ctx-rh-precuneus'
    },
    'Left-Occipital': {
        'ctx-lh-cuneus',
        'ctx-lh-lateraloccipital',
        'ctx-lh-lingual',
        'ctx-lh-pericalcarine'
    },
    'Right-Occipital': {
        'ctx-rh-cuneus',
        'ctx-rh-lateraloccipital',
        'ctx-rh-lingual',
        'ctx-rh-pericalcarine'
    },
    'Left-Insula':{
        'ctx-lh-insula'
    },
    'Right-Insula': {
        'ctx-rh-insula'
    },
    'Left-Cerebellum':{
        'Left-Cerebellum-White-Matter',
        'Left-Cerebellum-Cortex'
    },
    'Right-Cerebellum': {
        'Right-Cerebellum-White-Matter',
        'Right-Cerebellum-Cortex'
    },
    'Left-Combined-Cerebral-WM': {
        'Left-Cerebral-White-Matter',
        'Left-WM-hypointensities'
    },
    'Right-Combined-Cerebral-WM': {
        'Right-Cerebral-White-Matter',
        'Right-WM-hypointensities'
    }
}

# %%
import nibabel as nib
import numpy as np
import pandas as pd
import os
import glob
# Out:
# /tmp/ipykernel_3196241/1034284564.py:3: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
# 경로만 지정!
base_dir = '/home/limseoyoung/drwelly1/Team_Planning/Brain_Volumetry/oasis_vendor_before/NII/Simen/BNU_1'


def calculate_volume(nii_path):
    img = nib.load(nii_path) 
    data = img.get_fdata()
    header = img.header
    voxel_volume = np.prod(header.get_zooms())
    unique_elements, counts_elements = np.unique(data, return_counts=True)
    volumes = counts_elements * voxel_volume
    return dict(zip(unique_elements.astype(int), volumes))

# %%
import os
import pandas as pd



volume_data = []

for subject_dir in os.listdir(base_dir):
    full_subject_dir = os.path.join(base_dir, subject_dir)
    if not os.path.isdir(full_subject_dir) or 'FS222' not in subject_dir:
        continue
    
    double_subject_dir = os.path.join(full_subject_dir, subject_dir)
    if not os.path.isdir(double_subject_dir):
        continue
    
    mri_dir = os.path.join(double_subject_dir, 'mri')
    nii_path = os.path.join(mri_dir, 'aparc.DKTatlas+aseg.deep.nii.gz')
    
    if os.path.isfile(nii_path):
        try:
            vol_data = calculate_volume(nii_path)
            vol_data["subject"] = subject_dir
            volume_data.append(vol_data)
        except OSError as e:
            print(f"Error processing file {nii_path}, skipped  Error: {e}")
    else:
        print(f"File not found, skipped: {nii_path}")

volume_df = pd.DataFrame(volume_data)

# %%
volume_df
# Out:
#                 0              2             4           5             7  \
# 0    1.555047e+07  249988.343177   6043.659908  407.483994  15173.290768
# 1    1.548573e+07  263927.176964   5024.949923  524.446992  15661.379761
# 2    1.563429e+07  233799.772425   4875.744925  423.947994  15210.677767
# 3    1.559718e+07  244699.283258   7283.947889  645.525990  13120.435799
# 4    1.571795e+07  207454.971828   4458.656932  463.049993  12321.931812
# ..            ...            ...           ...         ...           ...
# 96   1.574530e+07  202802.519899  12872.446803  349.859995  12235.838813
# 97   1.558161e+07  235975.764391   8381.547872  363.236994  13763.903790
# 98   1.559242e+07  227068.054528  11033.280831  568.007991  15381.834765
# 99   1.558729e+07  227042.672528  11524.456824  585.157991  15291.282766
# 100  1.552957e+07  254878.151102   5556.599915  306.298995  15883.986757
#
#                 8           10           11           12           13  ...  \
# 0    55571.144150  9096.702861  4646.963929  5723.983912  2335.486964  ...
# 1    60457.522075  9213.322859  3940.383940  6724.171897  2445.246963  ...
# 2    54900.922160  8918.685864  3698.911943  5622.455914  2393.453963  ...
# 3    54744.857163  8568.139869  3541.131946  5908.174910  2144.778967  ...
# 4    47496.581274  7724.016882  4043.969938  5752.109912  2347.491964  ...
# ..            ...          ...          ...          ...          ...  ...
# 96   47022.555281  7259.937889  3885.160941  5150.487921  2103.618968  ...
# 97   59972.863083  8817.500865  4818.806926  6888.125895  2551.919961  ...
# 98   57494.002121  8643.942868  4148.927937  5387.500918  2269.630965  ...
# 99   57229.206125  8748.214866  4186.314936  5304.837919  2287.466965  ...
# 100  57503.263121  9839.640850  4001.094939  6142.786906  2337.201964  ...
#
#              2025         2026          2027          2028          2029  \
# 0    12621.713807  2870.909956  12504.407809  31540.221518  11792.339820
# 1    11598.201823  3162.802952  13109.459800  31692.170515  11079.928831
# 2    10862.466834  2509.387962  12349.028811  27318.234582  10934.496833
# 3    11601.288823  2108.077968  12054.391816  26971.118588  10190.872844
# 4    11466.146825  2936.422955  11144.069830  26771.492591  10479.678840
# ..            ...          ...           ...           ...           ...
# 96   10463.900840  1799.720972   9771.040851  25605.635608  11267.549828
# 97   12814.136804  2293.640965  12475.252809  29613.590547  12393.618810
# 98   11419.841825  2033.646969   9666.425852  30126.032539  12009.801816
# 99   11619.467822  2102.932968   9931.221848  30339.035536  12098.981815
# 100  12660.472806  2775.212958  11547.437823  29319.982552  11912.389818
#
#              2030          2031         2034         2035  \
# 0    16664.997745   9445.876856   919.239986  6910.420894
# 1    17971.141725  11023.676831  1309.573980  6992.054893
# 2    14860.474773   8782.514866  1021.796984  6131.467906
# 3    15360.568765   9651.676852   909.635986  5797.728911
# 4    15147.222768  10369.232841   961.085985  6298.508904
# ..            ...           ...          ...          ...
# 96   13422.961795  10602.129838   941.191986  6235.739905
# 97   16577.532746  10189.843844  1217.306981  7262.338889
# 98   16955.861741  10169.263844   935.017986  6419.587902
# 99   16926.020741   9917.844848   919.582986  6438.795902
# 100  19229.265706  11170.137829  1463.923978  7400.567887
#
#                                                subject
# 0    0025920_session_1_anat_1_Tag_pr100_sr100_ppf10...
# 1    0025867_session_2_anat_1_Tag_pr100_sr100_ppf10...
# 2    0025906_session_2_anat_1_Tag_pr100_sr100_ppf10...
# 3    0025905_session_1_anat_1_Tag_pr100_sr100_ppf10...
# 4    0025889_session_2_anat_1_Tag_pr100_sr100_ppf10...
# ..                                                 ...
# 96   0025869_session_1_anat_1_Tag_pr100_sr100_ppf10...
# 97   0025899_session_1_anat_1_Tag_pr100_sr100_ppf10...
# 98   0025868_session_2_anat_1_Tag_pr100_sr100_ppf10...
# 99   0025868_session_1_anat_1_Tag_pr100_sr100_ppf10...
# 100  0025908_session_2_anat_1_Tag_pr100_sr100_ppf10...
#
# [101 rows x 97 columns]

# %%
volume_df['subject'] = volume_df['subject'].str.replace('_Tag_pr100_sr100_ppf100_spf100_ipf100_sipf190_FS222', '')

# %%
# 경로만 지정!
base_dir1 = '/home/limseoyoung/drwelly1/Team_Planning/Brain_Volumetry/oasis_vendor_before/NII/Simen/IBATRT'


def calculate_volume(nii_path):
    img = nib.load(nii_path) 
    data = img.get_fdata()
    header = img.header
    voxel_volume = np.prod(header.get_zooms())
    unique_elements, counts_elements = np.unique(data, return_counts=True)
    volumes = counts_elements * voxel_volume
    return dict(zip(unique_elements.astype(int), volumes))

# %%
volume_data1 = []

for subject_dir in os.listdir(base_dir1):
    full_subject_dir = os.path.join(base_dir1, subject_dir)
    if not os.path.isdir(full_subject_dir) or 'FS222' not in subject_dir:
        continue
    
    double_subject_dir = os.path.join(full_subject_dir, subject_dir)
    if not os.path.isdir(double_subject_dir):
        continue
    
    mri_dir = os.path.join(double_subject_dir, 'mri')
    nii_path = os.path.join(mri_dir, 'aparc.DKTatlas+aseg.deep.nii.gz')
    
    if os.path.isfile(nii_path):
        try:
            vol_data = calculate_volume(nii_path)
            vol_data["subject"] = subject_dir
            volume_data1.append(vol_data)
        except OSError as e:
            print(f"Error processing file {nii_path}, skipped  Error: {e}")
    else:
        print(f"File not found, skipped: {nii_path}")

volume_df1 = pd.DataFrame(volume_data1)

# %%
#volume_df1

# %%
volume_df1['subject'] = volume_df1['subject'].str.replace('_Tag_pr100_sr100_ppf75_spf100_ipf100_sipf143_FS222', '')

# %%
#volume_df1

# %%
# 경로만 지정!
base_dir2 = '/home/limseoyoung/drwelly1/Team_Planning/Brain_Volumetry/oasis_vendor_before/NII/Simen/IPCAS_1'


def calculate_volume(nii_path):
    img = nib.load(nii_path) 
    data = img.get_fdata()
    header = img.header
    voxel_volume = np.prod(header.get_zooms())
    unique_elements, counts_elements = np.unique(data, return_counts=True)
    volumes = counts_elements * voxel_volume
    return dict(zip(unique_elements.astype(int), volumes))

# %%
volume_data2 = []#고치기

for subject_dir in os.listdir(base_dir2):# 고치기
    full_subject_dir = os.path.join(base_dir2, subject_dir)#고치기
    if not os.path.isdir(full_subject_dir) or 'FS222' not in subject_dir:
        continue
    
    double_subject_dir = os.path.join(full_subject_dir, subject_dir)
    if not os.path.isdir(double_subject_dir):
        continue
    
    mri_dir = os.path.join(double_subject_dir, 'mri')
    nii_path = os.path.join(mri_dir, 'aparc.DKTatlas+aseg.deep.nii.gz')
    
    if os.path.isfile(nii_path):
        try:
            vol_data = calculate_volume(nii_path)
            vol_data["subject"] = subject_dir
            volume_data2.append(vol_data) #고치기 
        except OSError as e:
            print(f"Error processing file {nii_path}, skipped  Error: {e}")
    else:
        print(f"File not found, skipped: {nii_path}")

volume_df2 = pd.DataFrame(volume_data2)

# %%
volume_df2
# Out:
#                0              2             4           5             7  \
# 0   1.580929e+07  186035.651155   3991.147939  215.746997  13076.874800
# 1   1.574101e+07  211049.611773   5406.365917  218.147997  12184.731814
# 2   1.566102e+07  229969.491483   6830.158896  349.859995  13585.200792
# 3   1.583252e+07  182859.814204   3497.913947  204.427997  12098.638815
# 4   1.551177e+07  248302.155203   6286.503904  455.846993  16533.628747
# 5   1.567326e+07  216945.438682   5747.307912  360.149994  13542.325793
# 6   1.571189e+07  206970.998835   8441.229871  237.355996  13545.412793
# 7   1.572723e+07  205568.814856   5575.464915  364.951994  13309.085796
# 8   1.558884e+07  226051.059543  11154.016829  655.472990  15618.504761
# 9   1.574661e+07  196351.718997   4485.753931  217.461997  11835.900819
# 10  1.562788e+07  220177.527633   6327.663903  464.421993  14695.834775
# 11  1.565235e+07  215872.534699   5501.033916  258.621996  13913.108787
# 12  1.550602e+07  260333.566019  10241.636843  306.298995  15786.231759
# 13  1.576062e+07  201386.615920   2945.340955  261.365996  14349.404781
# 14  1.566444e+07  217430.097675   5739.075912  375.927994  13323.491796
# 93  13588.287792  2868.508956  11552.239823  28065.288571  13094.710800
# 94  11431.846825  2773.840958  12628.916807  27363.853582  11262.404828
#
#             2030          2031         2034         2035  \
# 0   14191.624783   8995.517862  1104.802983  6131.467906
# 1   18619.411715   8887.129864  1129.498983  7025.668893
# 2   18869.115711   9853.703849  1003.274985  6037.828908
# 3   17323.214735  10517.408839  1048.893984  6543.753900
# 4   17825.709727  10646.719837  1444.372978  6296.450904
# ..           ...           ...          ...          ...
# 90  17467.960733  10320.869842  1083.193983  6627.788899
# 91  16001.978755   8730.378866   986.810985  6961.184894
# 92  17822.965727  12671.791806  1276.645980  6482.699901
# 93  17981.088725  12056.792816  1084.222983  7077.461892
# 94  17463.844733  10920.090833  1007.047985  6455.945901
#
#                                               subject
# 0   0027208_session_3_anat_2_Tag_pr100_sr100_ppf10...
# 1   0027222_session_2_anat_2_Tag_pr100_sr100_ppf10...
# 2   0027209_session_3_anat_1_Tag_pr100_sr100_ppf10...
# 3   0027221_session_3_anat_1_Tag_pr100_sr100_ppf10...
# 4   0027214_session_2_anat_2_Tag_pr100_sr100_ppf10...
# ..                                                ...
# 90  0027221_session_2_anat_2_Tag_pr100_sr100_ppf10...
# 91  0027215_session_1_anat_2_Tag_pr100_sr100_ppf10...
# 92  0027212_session_3_anat_2_Tag_pr100_sr100_ppf10...
# 93  0027216_session_1_anat_1_Tag_pr100_sr100_ppf10...
# 94  0027220_session_1_anat_2_Tag_pr100_sr100_ppf10...
#
# [95 rows x 97 columns]

# %%
volume_df3['subject'] = volume_df3['subject'].str.replace('_Tag_pr100_sr100_ppf100_spf100_ipf100_sipf143_FS222', '')

# %%
# 경로만 지정!
base_dir4 = '/home/limseoyoung/drwelly1/Team_Planning/Brain_Volumetry/oasis_vendor_before/NII/Simen/SWU_3'


def calculate_volume(nii_path):
    img = nib.load(nii_path) 
    data = img.get_fdata()
    header = img.header
    voxel_volume = np.prod(header.get_zooms())
    unique_elements, counts_elements = np.unique(data, return_counts=True)
    volumes = counts_elements * voxel_volume
    return dict(zip(unique_elements.astype(int), volumes))

# %%
volume_data4 = []#고치기

for subject_dir in os.listdir(base_dir4):# 고치기
    full_subject_dir = os.path.join(base_dir4, subject_dir)#고치기
    if not os.path.isdir(full_subject_dir) or 'FS222' not in subject_dir:
        continue
    
    double_subject_dir = os.path.join(full_subject_dir, subject_dir)
    if not os.path.isdir(double_subject_dir):
        continue
    
    mri_dir = os.path.join(double_subject_dir, 'mri')
    nii_path = os.path.join(mri_dir, 'aparc.DKTatlas+aseg.deep.nii.gz')
    
    if os.path.isfile(nii_path):
        try:
            vol_data = calculate_volume(nii_path)
            vol_data["subject"] = subject_dir
            volume_data4.append(vol_data) #고치기 
        except OSError as e:
            print(f"Error processing file {nii_path}, skipped  Error: {e}")
    else:
        print(f"File not found, skipped: {nii_path}")

volume_df4 = pd.DataFrame(volume_data4)

# %%
volume_df4['subject'] = volume_df4['subject'].str.replace('_Tag_pr100_sr100_ppf100_spf100_ipf100_sipf143_FS222', '')

# %%
# 경로만 지정!
base_dir5 = '/home/limseoyoung/drwelly1/Team_Planning/Brain_Volumetry/oasis_vendor_before/NII/Simen/XHCUMS'


def calculate_volume(nii_path):
    img = nib.load(nii_path) 
    data = img.get_fdata()
    header = img.header
    voxel_volume = np.prod(header.get_zooms())
    unique_elements, counts_elements = np.unique(data, return_counts=True)
    volumes = counts_elements * voxel_volume
    return dict(zip(unique_elements.astype(int), volumes))

# %%
volume_data5 = []#고치기

for subject_dir in os.listdir(base_dir5):# 고치기
    full_subject_dir = os.path.join(base_dir5, subject_dir)#고치기
    if not os.path.isdir(full_subject_dir) or 'FS222' not in subject_dir:
        continue
    
    double_subject_dir = os.path.join(full_subject_dir, subject_dir)
    if not os.path.isdir(double_subject_dir):
        continue
    
    mri_dir = os.path.join(double_subject_dir, 'mri')
    nii_path = os.path.join(mri_dir, 'aparc.DKTatlas+aseg.deep.nii.gz')
    
    if os.path.isfile(nii_path):
        try:
            vol_data = calculate_volume(nii_path)
            vol_data["subject"] = subject_dir
            volume_data5.append(vol_data) #고치기 
        except OSError as e:
# 455  10500.601839  2212.006966  14110.333784  29334.045551  11047.000831
# 457  10972.912832  2403.400963  10788.378835  25835.788605  11255.201828
# 458  11130.349830  2593.765960  10592.182838  25169.682615   9870.510849
# 462   9225.327859  2964.891955  11005.154832  23853.591635  11079.928831
#
#              2030          2031         2034         2035  \
# 0    16664.997745   9445.876856   919.239986  6910.420894
# 3    15360.568765   9651.676852   909.635986  5797.728911
# 5    16206.749752  10536.273839   884.596986  6803.061896
# 7    17280.339736  10275.593843  1014.936984  6853.139895
# 8    16151.526753  12679.337806  1322.264980  7092.210892
# ..            ...           ...          ...          ...
# 439  16039.022755  10717.720836   905.862986  6391.461902
# 455  15776.627759   9073.035861   921.983986  6733.089897
# 457  15888.445757   9030.160862  1014.936984  5647.151914
# 458  17100.607738   9609.144853  1009.448985  6999.600893
# 462  18546.695716   8471.070870  1268.070981  6160.965906
#
#                                                subject
# 0                                    0025920_session_1
# 3                                    0025905_session_1
# 5                                    0025879_session_1
# 7                                    0025919_session_1
# 8                                    0025870_session_1
# ..                                                 ...
# 439  0025983_session_1_anat_1_Tag_pr100_sr88_ppf75_...
# 455  0026004_session_1_anat_1_Tag_pr100_sr88_ppf75_...
# 457  0026002_session_1_anat_1_Tag_pr100_sr88_ppf75_...
# 458                                  0026006_session_1
# 462                                  0026003_session_1
#
# [178 rows x 97 columns]

# %%
lut_path = '/mnt/drwelly1/Team_Planning/Brain_Volumetry/Algorithms/freesurfer/FreeSurferColorLUT.txt'
# labeling 불러오면됨

# %%
def load_freesurfer_lut(lut_path):
    lut = {}
    with open(lut_path, 'r') as file:
        for line in file:
            if line.strip() and not line.startswith('#'):
                parts = line.split()
                if parts[0].isdigit():
                    lut[int(parts[0])] = ' '.join(parts[1:])
    return lut

freesurfer_lut = load_freesurfer_lut(lut_path)

# %%
# 모든 컬럼 이름을 변경
new_columns = [freesurfer_lut.get(int(col), 'Unknown') if col != 'subject' else 'subject' for col in sesson1.columns]


sesson1.columns = new_columns

# %%
def extract_number(subj):
    parts = subj.split('_')  # '_'를 기준
    if len(parts) > 1:
        number_part = parts[1]  
        # 숫자만 
        numbers = ''.join(filter(str.isdigit, number_part))
        return int(numbers) if numbers.isdigit() else None
    return None

# %%
sesson1['sort_key'] = sesson1['subject'].apply(extract_number) 
volume_df_sorted1 = sesson1.sort_values(by='sort_key').drop(columns=['sort_key'])
# Out:
# /tmp/ipykernel_3196241/2792317927.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sesson1['sort_key'] = sesson1['subject'].apply(extract_number)

# %%
# 모든 컬럼 이름을 변경
new_columns = [freesurfer_lut.get(int(col), 'Unknown') if col != 'subject' else 'subject' for col in sesson2.columns]


sesson2.columns = new_columns

# %%
sesson2['sort_key'] = sesson2['subject'].apply(extract_number)
volume_df_sorted2 = sesson2.sort_values(by='sort_key').drop(columns=['sort_key'])
# Out:
# /tmp/ipykernel_3196241/1960010514.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sesson2['sort_key'] = sesson2['subject'].apply(extract_number)

# %%
def update_df_columns_keep_others(df, roi_dict):
    # 합쳐진 컬럼들의 원본 컬럼 이름을 저장할 리스트
    columns_to_remove = []
    
    # ROI 딕셔너리에 기반하여 합치는 작업을 수행
    for roi, sub_columns in roi_dict.items():
        # 해당 ROI에 속하는 데이터프레임의 컬럼들 찾기
        relevant_columns = [col for col in df.columns if col.split(' ')[0] in sub_columns]
        
        # 해당 컬럼들이 데이터프레임에 있는 경우, 합쳐진 컬럼 생성
        if relevant_columns:
            # 합산 전에 NaN 값을 0으로 변환
            df[roi] = df[relevant_columns].fillna(0).sum(axis=1)
            # 원본 컬럼 이름을 제거 리스트에 추가
            columns_to_remove.extend(relevant_columns)
    
    # 모든 ROI 컬럼들을 포함하는 리스트 생성
    all_roi_columns = set()
    for sub_columns in roi_dict.values():
        all_roi_columns.update(sub_columns)
    
    # 제거할 컬럼 리스트에서, 딕셔너리에 정의된 컬럼만 실제로 제거
    columns_to_remove = set([col for col in columns_to_remove if col.split(' ')[0] in all_roi_columns])
    
    # 실제로 제거할 컬럼들을 제거
    df.drop(columns=columns_to_remove, inplace=True, errors='ignore')
    
    return df

# 함수 실행하여 데이터프레임 업데이트
new_df1 = update_df_columns_keep_others(volume_df_sorted1.copy(), combined_roi_dict)
new_df2 = update_df_columns_keep_others(volume_df_sorted2.copy(), combined_roi_dict)

# %%
brain_areas = set()
left_right_columns = []

for col in new_df1.columns:
    if col.startswith('Left-') or col.startswith('Right-'):
        left_right_columns.append(col)
        brain_area = col.split('-', 1)[1]
        brain_areas.add(brain_area)


for area in brain_areas:
    left_col = f'Left-{area}'
    right_col = f'Right-{area}'
    new_df1[area] = new_df1.get(left_col, 0) + new_df1.get(right_col, 0)

volume_df_sorted1_final = new_df1.drop(columns=[col for col in left_right_columns if col not in ['subject']])

# %%
volume_df_sorted1_final= volume_df_sorted1_final.drop(columns = ['Unknown 0 0 0 0','choroid-plexus 0 200 200 0','choroid-plexus 0 200 221 0','WM-hypointensities 200 70 255 0'])

# %%
brain_areas = set()
left_right_columns = []

for col in new_df2.columns:
    if col.startswith('Left-') or col.startswith('Right-'):
        left_right_columns.append(col)
        brain_area = col.split('-', 1)[1]
        brain_areas.add(brain_area)


for area in brain_areas:
    left_col = f'Left-{area}'
    right_col = f'Right-{area}'
    new_df2[area] = new_df2.get(left_col, 0) + new_df2.get(right_col, 0)

volume_df_sorted2_final = new_df2.drop(columns=[col for col in left_right_columns if col not in ['subject']])

# %%
volume_df_sorted2_final= volume_df_sorted2_final.drop(columns = ['Unknown 0 0 0 0','choroid-plexus 0 200 200 0','choroid-plexus 0 200 221 0','WM-hypointensities 200 70 255 0'])

# %%
all_data = pd.concat([volume_df_sorted1_final,volume_df_sorted2_final])
all_data_long = pd.melt(all_data, id_vars=["subject"], var_name="ROI", value_name="Volume")

# %%
all_data_long
# Out:
#                                                 subject  \
# 0                                     0025920_session_1
# 1                                     0025905_session_1
# 2                                     0025879_session_1
# 3                                     0025919_session_1
# 4                                     0025870_session_1
# ...                                                 ...
# 7651  0025995_session_2_anat_1_Tag_pr100_sr88_ppf75_...
# 7652                                  0025993_session_2
# 7653  0026001_session_2_anat_1_Tag_pr100_sr88_ppf75_...
# 7654                                  0025994_session_2
# 7655  0026003_session_2_anat_1_Tag_pr100_sr88_ppf75_...
#
#                               ROI         Volume
# 0     3rd-Ventricle 204 182 142 0    1048.207984
# 1     3rd-Ventricle 204 182 142 0     884.939986
# 2     3rd-Ventricle 204 182 142 0    1443.686978
# 3     3rd-Ventricle 204 182 142 0    1517.431977
# 4     3rd-Ventricle 204 182 142 0    1169.286982
# ...                           ...            ...
# 7651                     Temporal   92407.971587
# 7652                     Temporal   95009.626547
# 7653                     Temporal  108028.191348
# 7654                     Temporal  125793.533076
# 7655                     Temporal  112340.044282
#
# [7656 rows x 3 columns]

# %%
all_data_long['Session'] = all_data_long['subject'].str.extract(r'(session_\d+)')


all_data_long['ROI'] = all_data_long['ROI'].str.extract(r'([a-zA-Z-_]+)')[0]

# %%
all_data_long['Subject_ID'] = all_data_long['subject'].str.extract(r'(\d+)')

# %%
re_long = all_data_long.dropna(subset=['Volume'])


grouped = re_long.groupby(['Subject_ID', 'ROI'])['Volume'].agg(['mean', 'var', 'std']).reset_index()

# %%
grouped['CV'] = grouped['std'] / grouped['mean']

# %%
grouped
# Out:
#      Subject_ID                      ROI          mean           var  \
# 0       0025485           Accumbens-area   1014.593984     19.059137
# 1       0025485                 Amygdala   3405.989948      0.941192
# 2       0025485               Brain-Stem  17434.003733  16648.744779
# 3       0025485                      CSF   1179.748482     25.941604
# 4       0025485                  Caudate   7176.931890   1088.017919
# ...         ...                      ...           ...           ...
# 2914    0027256                 Thalamus  15627.079761    904.485484
# 2915    0027256  Total-Lateral-Ventricle  23987.018633  21318.233446
# 2916    0027256                VentralDC   8640.512868   7539.182987
# 2917    0027256             rd-Ventricle    790.443488      1.470612
# 2918    0027256             th-Ventricle   1600.609476    948.780331
#
#              std        CV
# 0       4.365677  0.004303
# 1       0.970150  0.000285
# 2     129.030015  0.007401
# 3       5.093290  0.004317
# 4      32.985117  0.004596
# ...          ...       ...
# 2914   30.074665  0.001925
# 2915  146.007649  0.006087
# 2916   86.828469  0.010049
# 2917    1.212688  0.001534
# 2918   30.802278  0.019244
#
# [2919 rows x 6 columns]

# %%
roi_mean_cv = grouped.groupby('ROI')['CV'].mean().reset_index()
roi_mean_cv.rename(columns={'CV': 'Mean_CV'}, inplace=True)

roi_mean_cv
# Out:
#                         ROI   Mean_CV
# 0            Accumbens-area  0.012112
# 1                  Amygdala  0.009670
# 2                Brain-Stem  0.006494
# 3                       CSF  0.017062
# 4                   Caudate  0.008172
# 5                Cerebellum  0.006991
# 6                 Cingulate  0.011856
# 7      Combined-Cerebral-WM  0.005706
# 8                   Frontal  0.012935
# 9               Hippocampus  0.008480
# 10                   Insula  0.009296
# 11                Occipital  0.010489
# 12                 Pallidum  0.022232
# 13                 Parietal  0.011743
# 14                  Putamen  0.004088
# 15                 Temporal  0.010695
# 16                 Thalamus  0.007793
# 17  Total-Lateral-Ventricle  0.018920
# 18                VentralDC  0.008770
# 19             rd-Ventricle  0.016210
# 20             th-Ventricle  0.017367

# %%
#grouped.to_csv("Simen_before_CV_individual_freesurfer_session.csv")
